# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Generate random latitude and longitude
lats = np.random.uniform(-90, 90, size=1000)
lngs = np.random.uniform(-180, 180, size=1000)


cities = []

# Use citipy to determine the nearest city for each lat-lng combination
for lat, lng in zip(lats, lngs):
    city = citipy.nearest_city(lat, lng).city_name
    if city not in cities:
        cities.append(city)

print(f"Generated {len(cities)} unique cities.")
# Out:
# Generated 463 unique cities.

# %%
# Base URL for OpenWeatherMap
air_quality_url = "http://api.openweathermap.org/data/2.5/air_pollution"

valid_cities = []

for city in cities:
    try:
        # Fetch city coordinates using the weather endpoint
        query_url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}"
        response = requests.get(query_url)

        # Check if the request was successful
        if response.status_code != 200:
            print(f"City {city} not found (Status Code: {response.status_code}). Skipping...")
            continue

        # Parse JSON response
        data = response.json()
        lat = data['coord']['lat']
        lon = data['coord']['lon']
        country = data['sys']['country']
        # Make an API call to the Air Pollution endpoint
        pollution_response = requests.get(
            f"{air_quality_url}?lat={lat}&lon={lon}&appid={weather_api_key}"
        )

        # Append a dictionary with detailed information


        # Check pollution API response
        if pollution_response.status_code == 200:
            valid_cities.append({
                'City': city,
                'Latitude': lat,
                'Longitude': lon,
                'Country': country
            })
        else:
            print(f"Air pollution data not found for {city}. Skipping...")

    except KeyError as key_err:
        print(f"KeyError: {key_err} for {city}. Skipping...")
    except requests.exceptions.RequestException as req_err:
        print(f"Request error: {req_err} for {city}. Skipping...")

    # Pause to avoid rate limiting
    time.sleep(1)

print(f"Valid cities with air quality data: {len(valid_cities)}")
# Out:
# City cable beach not found (Status Code: 404). Skipping...
# City nkurenkuru not found (Status Code: 404). Skipping...
# City taiohae not found (Status Code: 404). Skipping...
# City hayma' not found (Status Code: 404). Skipping...
# City tranovaho not found (Status Code: 404). Skipping...
# City nalerigu not found (Status Code: 404). Skipping...
# City fuvahmulah not found (Status Code: 404). Skipping...
# City ain beni mathar not found (Status Code: 404). Skipping...
# City kulia village not found (Status Code: 404). Skipping...
# City 'ohonua not found (Status Code: 404). Skipping...
# City fonadhoo not found (Status Code: 404). Skipping...
# City ho not found (Status Code: 404). Skipping...
# City ahau not found (Status Code: 404). Skipping...
# City puerto san carlos not found (Status Code: 404). Skipping...
# City gueltat zemmour not found (Status Code: 404). Skipping...
# City kataragama not found (Status Code: 404). Skipping...
# City devinuwara not found (Status Code: 404). Skipping...
# City satupa'itea not found (Status Code: 404). Skipping...
# Valid cities with air quality data: 445

# %%
print(valid_cities)
# Out:
# [{'City': 'san vincenzo', 'Latitude': 43.0928, 'Longitude': 10.5408, 'Country': 'IT'}, {'City': 'san patricio', 'Latitude': 28.017, 'Longitude': -97.5169, 'Country': 'US'}, {'City': 'beira', 'Latitude': -19.8436, 'Longitude': 34.8389, 'Country': 'MZ'}, {'City': 'yeppoon', 'Latitude': -23.1333, 'Longitude': 150.7333, 'Country': 'AU'}, {'City': 'anak', 'Latitude': 38.5108, 'Longitude': 125.4942, 'Country': 'KP'}, {'City': 'constantia', 'Latitude': 44.1833, 'Longitude': 28.65, 'Country': 'RO'}, {'City': 'kodiak', 'Latitude': 57.79, 'Longitude': -152.4072, 'Country': 'US'}, {'City': 'guerrero negro', 'Latitude': 27.9769, 'Longitude': -114.0611, 'Country': 'MX'}, {'City': 'tiksi', 'Latitude': 71.6872, 'Longitude': 128.8694, 'Country': 'RU'}, {'City': 'margaret river', 'Latitude': -33.95, 'Longitude': 115.0667, 'Country': 'AU'}, {'City': 'port-aux-francais', 'Latitude': -49.35, 'Longitude': 70.2167, 'Country': 'TF'}, {'City': 'bilibino', 'Latitude': 68.0546, 'Longitude': 166.4372, 'Country': 'RU'}, {'City': 'taunggyi', 'Latitude': 20.7833, 'Longitude': 97.0333, 'Country': 'MM'}, {'City': 'aykhal', 'Latitude': 66, 'Longitude': 111.5, 'Country': 'RU'}, {'City': 'pacific grove', 'Latitude': 36.6177, 'Longitude': -121.9166, 'Country': 'US'}, {'City': 'inongo', 'Latitude': -1.95, 'Longitude': 18.2667, 'Country': 'CD'}, {'City': 'college', 'Latitude': 64.8569, 'Longitude': -147.8028, 'Country': 'US'}, {'City': 'ushuaia', 'Latitude': -54.8, 'Longitude': -68.3, 'Country': 'AR'}, {'City': 'hawkesbury', 'Latitude': 45.6001, 'Longitude': -74.616, 'Country': 'CA'}, {'City': 'knyaze-volkonskoye', 'Latitude': 48.4642, 'Longitude': 135.4567, 'Country': 'RU'}, {'City': 'selkirk', 'Latitude': 50.1436, 'Longitude': -96.8845, 'Country': 'CA'}, {'City': 'west end', 'Latitude': 26.6833, 'Longitude': -78.9667, 'Country': 'BS'}, {'City': 'ust-nera', 'Latitude': 64.5667, 'Longitude': 143.2, 'Country': 'RU'}, {'City': 'eraan', 'Latitude': 9.0629, 'Longitude': 117.7016, 'Country': 'PH'}, {'City': 'puerto natales', 'Latitude': -51.7236, 'Longitude': -72.4875, 'Country': 'CL'}, {'City': 'punta arenas', 'Latitude': -53.15, 'Longitude': -70.9167, 'Country': 'CL'}, {'City': 'san antonio de pale', 'Latitude': -1.4014, 'Longitude': 5.6325, 'Country': 'GQ'}, {'City': 'bethel', 'Latitude': 41.3712, 'Longitude': -73.414, 'Country': 'US'}, {'City': 'santa rosa de copan', 'Latitude': 14.7667, 'Longitude': -88.7833, 'Country': 'HN'}, {'City': 'caleta de carquin', 'Latitude': -11.0925, 'Longitude': -77.6267, 'Country': 'PE'}, {'City': 'adamstown', 'Latitude': -25.066, 'Longitude': -130.1015, 'Country': 'PN'}, {'City': 'haiku-pauwela', 'Latitude': 20.9219, 'Longitude': -156.3051, 'Country': 'US'}, {'City': 'olonkinbyen', 'Latitude': 70.9221, 'Longitude': -8.7187, 'Country': 'SJ'}, {'City': 'puerto ayora', 'Latitude': -0.7393, 'Longitude': -90.3518, 'Country': 'EC'}, {'City': "podporozh'ye", 'Latitude': 60.9112, 'Longitude': 34.1706, 'Country': 'RU'}, {'City': 'massenya', 'Latitude': 11.4039, 'Longitude': 16.1705, 'Country': 'TD'}, {'City': 'gwadar', 'Latitude': 25.1216, 'Longitude': 62.3254, 'Country': 'PK'}, {'City': 'blackmans bay', 'Latitude': -43.0167, 'Longitude': 147.3167, 'Country': 'AU'}, {'City': 'invercargill', 'Latitude': -46.4, 'Longitude': 168.35, 'Country': 'NZ'}, {'City': 'papatowai', 'Latitude': -46.5619, 'Longitude': 169.4708, 'Country': 'NZ'}, {'City': 'hermanus', 'Latitude': -34.4187, 'Longitude': 19.2345, 'Country': 'ZA'}, {'City': 'qaqortoq', 'Latitude': 60.7167, 'Longitude': -46.0333, 'Country': 'GL'}, {'City': 'port moresby', 'Latitude': -9.4431, 'Longitude': 147.1797, 'Country': 'PG'}, {'City': 'port elizabeth', 'Latitude': -33.918, 'Longitude': 25.5701, 'Country': 'ZA'}, {'City': 'grytviken', 'Latitude': -54.2811, 'Longitude': -36.5092, 'Country': 'GS'}, {'City': 'thompson', 'Latitude': 55.7435, 'Longitude': -97.8558, 'Country': 'CA'}, {'City': 'lapy', 'Latitude': 52.9911, 'Longitude': 22.8842, 'Country': 'PL'}, {'City': 'galveston', 'Latitude': 29 ...

# %%
# Create a dictionary to store city-country pairs
city_country_map = {}

# Use existing data from valid_cities
for city_info in valid_cities:
    try:
        # Extract the city name and country code from the existing data
        city = city_info['City']
        country = city_info['Country']

        # Store the city and corresponding country code
        city_country_map[city] = country

        # Print city and country
        print(f"City: {city}, Country: {country}")

    except KeyError as key_err:
        print(f"KeyError: {key_err} for {city_info}. Skipping...")

print(city_country_map)
# Out:
# City: san vincenzo, Country: IT
# City: san patricio, Country: US
# City: beira, Country: MZ
# City: yeppoon, Country: AU
# City: anak, Country: KP
# City: constantia, Country: RO
# City: kodiak, Country: US
# City: guerrero negro, Country: MX
# City: tiksi, Country: RU
# City: margaret river, Country: AU
# City: port-aux-francais, Country: TF
# City: bilibino, Country: RU
# City: taunggyi, Country: MM
# City: aykhal, Country: RU
# City: pacific grove, Country: US
# City: inongo, Country: CD
# City: college, Country: US
# City: ushuaia, Country: AR
# City: hawkesbury, Country: CA
# City: knyaze-volkonskoye, Country: RU
# City: selkirk, Country: CA
# City: west end, Country: BS
# City: ust-nera, Country: RU
# City: eraan, Country: PH
# City: puerto natales, Country: CL
# City: punta arenas, Country: CL
# City: san antonio de pale, Country: GQ
# City: bethel, Country: US
# City: santa rosa de copan, Country: HN
# City: caleta de carquin, Country: PE
# City: adamstown, Country: PN
# City: haiku-pauwela, Country: US
# City: olonkinbyen, Country: SJ
# City: puerto ayora, Country: EC
# City: podporozh'ye, Country: RU
# City: massenya, Country: TD
# City: gwadar, Country: PK
# City: blackmans bay, Country: AU
# City: invercargill, Country: NZ
# City: papatowai, Country: NZ
# City: hermanus, Country: ZA
# City: qaqortoq, Country: GL
# City: port moresby, Country: PG
# City: port elizabeth, Country: ZA
# City: grytviken, Country: GS
# City: thompson, Country: CA
# City: lapy, Country: PL
# City: galveston, Country: US
# City: ponta delgada, Country: PT
# City: carloforte, Country: IT
# City: st. john's, Country: CA
# City: nagrota, Country: IN
# City: hamilton, Country: US
# City: mareeba, Country: AU
# City: holualoa, Country: US
# City: grootfontein, Country: NA
# City: lihue, Country: US
# City: el granada, Country: US
# City: keflavik, Country: IS
# City: ribeira grande, Country: PT
# City: wailua homesteads, Country: US
# City: iqaluit, Country: CA
# City: west island, Country: CC
# City: aromashevo, Country: RU
# City: vorgashor, Country: RU
# City: freetown, Country: SL
# City: quepos, Country: CR
# City: yellowknife, Country: CA
# City: perevolotskiy, Country: RU
# City: longyearbyen, Country: SJ
# City: iquique, Country: CL
# City: badger, Country: US
# City: polyarnyy, Country: RU
# City: sao felix do xingu, Country: BR
# City: gazipasa, Country: TR
# City: laguna, Country: US
# City: ilulissat, Country: GL
# City: albany, Country: US
# City: santa terezinha, Country: BR
# City: arafo, Country: ES
# City: togur, Country: RU
# City: chos malal, Country: AR
# City: vila franca do campo, Country: PT
# City: howard springs, Country: AU
# City: waitangi, Country: NZ
# City: yemetsk, Country: RU
# City: general conesa, Country: AR
# City: talnakh, Country: RU
# City: mayya, Country: RU
# City: nemuro, Country: JP
# City: pamanukan, Country: ID
# City: fortuna, Country: US
# City: yichun, Country: CN
# City: morehead city, Country: US
# City: strelka, Country: RU
# City: dudinka, Country: RU
# City: tura, Country: IN
# City: kisangani, Country: CD
# City: port mathurin, Country: MU
# City: bredasdorp, Country: ZA
# City: akrehamn, Country: NO
# City: edinburgh of the seven seas, Country: SH
# City: saint-francois, Country: FR
# City: lebu, Country: CL
# City: fortaleza, Country: BR
# City: atafu village, Country: TK
# City: manay, Country: PH
# City: valparaiso, Country: CL
# City: stanley, Country: GB
# City: waingapu, Country: ID
# City: ust'-ilimsk, Country: RU
# City: kargasok, Country: RU
# City: fort st. john, Country: CA
# City: tazovsky, Country: RU
# City: kokopo, Country: PG
# City: shasta lake, Country: US
# City: bikenibeu village, Country: KI
# City: namibe, Country: AO
# City: susuman, Country: RU
# City: mogadishu, Country: SO
# City: ryotsu-minato, Country: JP
# City: pustoshka, Country: RU
# City: alice springs, Country: AU
# City: san antonio, Country: US
# City: georgetown, Country: MY
# City: garoowe, Country: SO
# City: yigo village, Country: GU
# City: patnongon, Country: PH
# City: sirte, Country: LY
# City: cabedelo, Country: BR
# City: hithadhoo, Country: MV
# City: tangalle, Country: LK
# City: nar'yan-mar, Country: RU
# City: mount gambier, Country: AU
# City: luwuk, Country: ID
# City: sultanah, Country: SA
# City: avarua, Country: CK
# City: lompoc, Country: US
# City: gadzhiyevo, Country: RU
# City: kavaratti, Country: IN
# City: takestan, Country: IR
# City: dhidhdhoo, Country: MV
# City: queenstown, Country: ZA
# City: chinchilla, Country: AU
# City: esme, Country: TR
# City: odzak, Country: BA
# City: san jose, Country: US
# City: prince rupert, Country: CA
# City: howrah, Country: IN
# City: undurkhaan, Country: MN
# City: cockburn town, Country: TC
# City: yeniseysk, Country: RU
# City: kangiwa, Country: NG
# City: wau, Country: SS
# City: male, Country: MV
# City: ouadda, Country: CF
# City: zapata, Country: US
# City: klaksvik, Country: FO
# City: aasiaat, Country: GL
# City: tome acu, Country: BR
# City: vila velha, Country: BR
# City: petropavlovsk-kamchatsky, Country: RU
# City: goure, Country: NE
# City: isafjordur, Country: IS
# City: utrik, Country: MH
# City: sena madureira, Country: BR
# City: katsuura, Country: JP
# City: uliastay, Country: MN
# City: jamestown, Country: US
# City: newman, Country: US
# City: beidaihehaibin, Country: CN
# City: kabalo, Country: CD
# City: yerofey pavlovich, Country: RU
# City: puerto aysen, Country: CL
# City: praia da vitoria, Country: PT
# City: hauterive, Country: FR
# City: imuris, Country: MX
# City: minas de marcona, Country: PE
# City: piacabucu, Country: BR
# City: bandon, Country: IE
# City: hangu, Country: CN
# City: san julian, Country: MX
# City: mhamid, Country: MA
# City: uturoa, Country: PF
# City: sandnessjoen, Country: NO
# City: slavyanka, Country: RU
# City: saint-felicien, Country: CA
# City: prado, Country: BR
# City: mingyue, Country: CN
# City: uyuni, Country: BO
# City: alvaraes, Country: BR
# City: severoural'sk, Country: RU
# City: anadyr, Country: RU
# City: angaur state, Country: PW
# City: lossiemouth, Country: GB
# City: le grazie di ancona, Country: IT
# City: marathon, Country: US
# City: kingston, Country: JM
# City: yarmouth, Country: US
# City: sibi, Country: PK
# City: bengkulu, Country: ID
# City: ambovombe, Country: MG
# City: chernyshevskiy, Country: RU
# City: sola, Country: VU
# City: borogontsy, Country: RU
# City: coahuayana de hidalgo, Country: MX
# City: port alfred, Country: ZA
# City: udachny, Country: RU
# City: coquimbo, Country: CL
# City: barra de santo antonio, Country: BR
# City: la ronge, Country: CA
# City: sinabang, Country: ID
# City: port douglas, Country: AU
# City: mount isa, Country: AU
# City: al bardiyah, Country: LY
# City: enewetak, Country: MH
# City: codrington, Country: AU
# City: barclayville, Country: LR
# City: miracema do tocantins, Country: BR
# City: tarawa, Country: KI
# City: ancud, Country: CL
# City: nadi, Country: FJ
# City: el calafate, Country: AR
# City: lagoa, Country: PT
# City: olyokminsk, Country: RU
# City: watsa, Country: CD
# City: kruisfontein, Country: ZA
# City: fuyu, Country: CN
# City: hasaki, Country: JP
# City: mana, Country: GF
# City: suva, Country: FJ
# City: yuzhno-kurilsk, Country: RU
# City: flying fish cove, Country: CX
# City: awash, Country: ET
# City: bel ombre, Country: SC
# City: touros, Country: BR
# City: vorkuta, Country: RU
# City: kabare, Country: CD
# City: aripuana, Country: BR
# City: vernon, Country: CA
# City: arraial do cabo, Country: BR
# City: luba, Country: GQ
# City: la leonesa, Country: AR
# City: kismayo, Country: SO
# City: koungou, Country: YT
# City: east london, Country: ZA
# City: sunne, Country: SE
# City: saint-philippe, Country: RE
# City: rumbek, Country: SS
# City: tham phannara, Country: TH
# City: whakatane, Country: NZ
# City: goderich, Country: CA
# City: saipan, Country: MP
# City: bubaque, Country: GW
# City: mata-utu, Country: WF
# City: nova sintra, Country: CV
# City: kenora, Country: CA
# City: nabire, Country: ID
# City: haicheng, Country: CN
# City: melfort, Country: CA
# City: binnish, Country: SY
# City: saldanha, Country: ZA
# City: qina, Country: EG
# City: murzuq, Country: LY
# City: ola, Country: RU
# City: cabo san lucas, Country: MX
# City: tofol, Country: FM
# City: anloga, Country: GH
# City: bandar lampung, Country: ID
# City: hawaiian paradise park, Country: US
# City: delijan, Country: IR
# City: whitehorse, Country: CA
# City: serowe, Country: BW
# City: colonia, Country: DE
# City: seaside, Country: US
# City: tommot, Country: RU
# City: kembe, Country: CF
# City: nhamunda, Country: BR
# City: natal, Country: BR
# City: al matariyah, Country: EG
# City: hell-ville, Country: MG
# City: kourou, Country: GF
# City: shortandy, Country: KZ
# City: escarcega, Country: MX
# City: kapuskasing, Country: CA
# City: musanze, Country: RW
# City: nadym, Country: RU
# City: camana, Country: PE
# City: dzhalagash, Country: KZ
# City: lawas, Country: PH
# City: gosaba, Country: IN
# City: siuna, Country: NI
# City: port lincoln, Country: AU
# City: noshiro, Country: JP
# City: pahrump, Country: US
# City: inhambane, Country: MZ
# City: sorokino, Country: RU
# City: carutapera, Country: BR
# City: sur, Country: OM
# City: didymoteicho, Country: GR
# City: kearney, Country: US
# City: larbaa, Country: DZ
# City: grenville, Country: GD
# City: nuku'alofa, Country: TO
# City: pangody, Country: RU
# City: tromso, Country: NO
# City: labytnangi, Country: RU
# City: toliara, Country: MG
# City: shagonar, Country: RU
# City: valdivia, Country: CL
# City: sao joao da barra, Country: BR
# City: antofagasta, Country: CL
# City: general pico, Country: AR
# City: burgos, Country: ES
# City: crane, Country: US
# City: cascais, Country: PT
# City: ma'rib, Country: YE
# City: lata, Country: PT
# City: pontes e lacerda, Country: BR
# City: port saint john's, Country: ZA
# City: nguigmi, Country: NE
# City: hillsboro, Country: US
# City: itoman, Country: JP
# City: bijapur, Country: IN
# City: nouadhibou, Country: MR
# City: kuta, Country: ID
# City: shimoda, Country: JP
# City: kone, Country: NC
# City: egilsstadir, Country: IS
# City: pisco, Country: PE
# City: gorontalo, Country: ID
# City: hegang, Country: CN
# City: kashgar, Country: CN
# City: san pedro pochutla, Country: MX
# City: dunedin, Country: NZ
# City: heinola, Country: FI
# City: newnham, Country: AU
# City: okha, Country: RU
# City: carnarvon, Country: AU
# City: grand-bassam, Country: CI
# City: happy valley-goose bay, Country: CA
# City: sitka, Country: US
# City: murun-kuren, Country: MN
# City: bavly, Country: RU
# City: yurga, Country: RU
# City: aldinga beach, Country: AU
# City: kapa'a, Country: US
# City: dryden, Country: CA
# City: rudsar, Country: IR
# City: revda, Country: RU
# City: la sarre, Country: CA
# City: kamikawa, Country: JP
# City: harstad, Country: NO
# City: chinde, Country: NP
# City: neiafu, Country: TO
# City: jiagedaqi, Country: CN
# City: lancaster, Country: US
# City: tolanaro, Country: MG
# City: sokcho, Country: KR
# City: aras-asan, Country: PH
# City: kitami, Country: JP
# City: alofi, Country: NU
# City: papao, Country: PF
# City: wenchang, Country: CN
# City: aral, Country: CN
# City: mount pleasant, Country: US
# City: kirensk, Country: RU
# City: nogliki, Country: RU
# City: dabakala, Country: CI
# City: shalqar, Country: KZ
# City: mitu, Country: CO
# City: guidel-plage, Country: FR
# City: tvoroyri, Country: FO
# City: nyaunglebin, Country: MM
# City: xai-xai, Country: MZ
# City: soio, Country: AO
# City: hadibu, Country: YE
# City: tsetserleg, Country: MN
# City: homer, Country: US
# City: san carlos centro, Country: AR
# City: sao miguel do araguaia, Country: BR
# City: samdrup jongkhar, Country: BT
# City: lodja, Country: CD
# City: argo, Country: GR
# City: lincoln city, Country: US
# City: castillos, Country: UY
# City: repelon, Country: CO
# City: realico, Country: AR
# City: hami, Country: CN
# City: pambujan, Country: PH
# City: geraldton, Country: AU
# City: katsuren-haebaru, Country: JP
# City: yanchep, Country: AU
# City: ndele, Country: CF
# City: meadow lake, Country: US
# City: arno, Country: SE
# City: kristiansund, Country: NO
# City: charlotte amalie, Country: VI
# City: anguillara sabazia, Country: IT
# City: leer, Country: DE
# City: afaahiti, Country: PF
# City: naga, Country: PH
# City: urangan, Country: AU
# City: piatykhatky, Country: UA
# City: celestun, Country: MX
# City: new norfolk, Country: AU
# City: manokwari, Country: ID
# City: nipomo, Country: US
# City: rongelap, Country: MH
# City: abadeh, Country: IR
# City: taiynsha, Country: KZ
# City: bairnsdale, Country: AU
# City: wanning, Country: CN
# City: ashoknagar, Country: IN
# City: gokwe, Country: ZW
# City: bridgetown, Country: BB
# City: ruteng, Country: ID
# City: kanniyakumari, Country: IN
# City: mikhaylovskoye, Country: RU
# City: anna regina, Country: GY
# City: harlingen, Country: US
# City: chibougamau, Country: CA
# City: djenne, Country: ML
# City: bardai, Country: NG
# City: serdar, Country: TM
# City: glace bay, Country: CA
# City: sechura, Country: PE
# City: mufumbwe, Country: ZM
# City: abbeville, Country: FR
# City: grand falls-windsor, Country: CA
# City: bathsheba, Country: BB
# City: bonthe, Country: SL
# City: lorengau, Country: PG
# City: malvan, Country: IN
# City: villa gesell, Country: AR
# City: leninskiy, Country: RU
# City: didim, Country: TR
# City: suntar, Country: RU
# City: antsiranana, Country: MG
# City: ghat, Country: LY
# City: mont-laurier, Country: CA
# City: qarqaraly, Country: KZ
# City: fort bragg, Country: US
# City: bodo, Country: NO
# City: saudarkrokur, Country: IS
# {'san vincenzo': 'IT', 'san patricio': 'US', 'beira': 'MZ', 'yeppoon': 'AU', 'anak': 'KP', 'constantia': 'RO', 'kodiak': 'US', 'guerrero negro': 'MX', 'tiksi': 'RU', 'margaret river': 'AU', 'port-aux-francais': 'TF', 'bilibino': 'RU', 'taunggyi': 'MM', 'aykhal': 'RU', 'pacific grove': 'US', 'inongo': 'CD', 'college': 'US', 'ushuaia': 'AR', 'hawkesbury': 'CA', 'knyaze-volkonskoye': 'RU', 'selkirk': 'CA', 'west end': 'BS', 'ust-nera': 'RU', 'eraan': 'PH', 'puerto natales': 'CL', 'punta arenas': 'CL', 'san antonio de pale': 'GQ', 'bethel': 'US', 'santa rosa de copan': 'HN', 'caleta de carquin': 'PE', 'adamstown': 'PN', 'haiku-pauwela': 'US', 'olonkinbyen': 'SJ', 'puerto ayora': 'EC', "podporozh'ye": 'RU', 'massenya': 'TD', 'gwadar': 'PK', 'blackmans bay': 'AU', 'invercargill': 'NZ', 'papatowai': 'NZ', 'hermanus': 'ZA', 'qaqortoq': 'GL', 'port moresby': 'PG', 'port elizabeth': 'ZA', 'grytviken': 'GS', 'thompson': 'CA', 'lapy': 'PL', 'galveston': 'US', 'ponta delgada': 'PT', 'carloforte': 'IT', "st. john's": 'CA', 'nagrota': 'IN', 'hamilton': 'US', 'mareeba': 'AU', 'holualoa': 'US', 'grootfontein': 'NA', 'lihue': 'US', 'el granada': 'US', 'keflavik': 'IS', 'ribeira grande': 'PT', 'wailua homesteads': 'US', 'iqaluit': 'CA', 'west island': 'CC', 'aromashevo': 'RU', 'vorgashor': 'RU', 'freetown': 'SL', 'quepos': 'CR', 'yellowknife': 'CA', 'perevolotskiy': 'RU', 'longyearbyen': 'SJ', 'iquique': 'CL', 'badger': 'US', 'polyarnyy': 'RU', 'sao felix do xingu': 'BR', 'gazipasa': 'TR', 'laguna': 'US', 'ilulissat': 'GL', 'albany': 'US', 'santa terezinha': 'BR', 'arafo': 'ES', 'togur': 'RU', 'chos malal': 'AR', 'vila franca do campo': 'PT', 'howard springs': 'AU', 'waitangi': 'NZ', 'yemetsk': 'RU', 'general conesa': 'AR', 'talnakh': 'RU', 'mayya': 'RU', 'nemuro': 'JP', 'pamanukan': 'ID', 'fortuna': 'US', 'yichun': 'CN', 'morehead city': 'US', 'strelka': 'RU', 'dudinka': 'RU', 'tura': 'IN', 'kisangani': 'CD', 'port mathurin': 'MU', 'bredasdorp': 'ZA', 'akrehamn': 'NO', 'edinburgh of the seven seas': 'SH', 'saint-francois': 'FR', 'lebu': 'CL', 'fortaleza': 'BR', 'atafu village': 'TK', 'manay': 'PH', 'valparaiso': 'CL', 'stanley': 'GB', 'waingapu': 'ID', "ust'-ilimsk": 'RU', 'kargasok': 'RU', 'fort st. john': 'CA', 'tazovsky': 'RU', 'kokopo': 'PG', 'shasta lake': 'US', 'bikenibeu village': 'KI', 'namibe': 'AO', 'susuman': 'RU', 'mogadishu': 'SO', 'ryotsu-minato': 'JP', 'pustoshka': 'RU', 'alice springs': 'AU', 'san antonio': 'US', 'georgetown': 'MY', 'garoowe': 'SO', 'yigo village': 'GU', 'patnongon': 'PH', 'sirte': 'LY', 'cabedelo': 'BR', 'hithadhoo': 'MV', 'tangalle': 'LK', "nar'yan-mar": 'RU', 'mount gambier': 'AU', 'luwuk': 'ID', 'sultanah': 'SA', 'avarua': 'CK', 'lompoc': 'US', 'gadzhiyevo': 'RU', 'kavaratti': 'IN', 'takestan': 'IR', 'dhidhdhoo': 'MV', 'queenstown': 'ZA', 'chinchilla': 'AU', 'esme': 'TR', 'odzak': 'BA', 'san jose': 'US', 'prince rupert': 'CA', 'howrah': 'IN', 'undurkhaan': 'MN', 'cockburn town': 'TC', 'yeniseysk': 'RU', 'kangiwa': 'NG', 'wau': 'SS', 'male': 'MV', 'ouadda': 'CF', 'zapata': 'US', 'klaksvik': 'FO', 'aasiaat': 'GL', 'tome acu': 'BR', 'vila velha': 'BR', 'petropavlovsk-kamchatsky': 'RU', 'goure': 'NE', 'isafjordur': 'IS', 'utrik': 'MH', 'sena madureira': 'BR', 'katsuura': 'JP', 'uliastay': 'MN', 'jamestown': 'US', 'newman': 'US', 'beidaihehaibin': 'CN', 'kabalo': 'CD', 'yerofey pavlovich': 'RU', 'puerto aysen': 'CL', 'praia da vitoria': 'PT', 'hauterive': 'FR', 'imuris': 'MX', 'minas de marcona': 'PE', 'piacabucu': 'BR', 'bandon': 'IE', 'hangu': 'CN', 'san julian': 'MX', 'mhamid': 'MA', 'uturoa': 'PF', 'sandnessjoen': 'NO', 'slavyanka': 'RU', 'saint-felicien': 'CA', 'prado': 'BR', 'mingyue': 'CN', 'uyuni': 'BO', 'alvaraes': 'BR', "severoural'sk": 'RU', 'anadyr': 'RU', 'angaur state': 'PW', 'lossiemouth': 'GB', 'le grazie di ancona': 'IT', 'marathon': 'US', 'kingston': 'JM', 'yarmouth': 'US', 'sibi': 'PK', 'bengkulu': 'ID', 'ambovombe': 'MG', 'chernyshevskiy': 'RU', 'sola': 'VU', 'borogontsy': 'RU', 'coahuayana de ...

# %%
print(f"Total cities: {len(city_country_map)}")
# Out:
# Total cities: 445

# %%
data = list(city_country_map.items())

# Create the DataFrame
df = pd.DataFrame(data, columns=['City', 'Country'])

# Save the DataFrame to a CSV file
df.to_csv('Resources/city_country_map.csv', index=False, encoding='utf-8')

# %%
# Get all the unique countries from the city-country map
unique_countries = set(city_country_map.values())

# Print the count and the list of unique countries
print(f"Total unique countries: {len(unique_countries)}")
print(unique_countries)
# Out:
# Total unique countries: 124
# {'PG', 'MN', 'MA', 'CL', 'PF', 'VI', 'IT', 'SS', 'GD', 'YT', 'CI', 'BS', 'EG', 'MU', 'KP', 'BW', 'TK', 'ES', 'MY', 'GY', 'GF', 'NU', 'OM', 'PT', 'BO', 'SJ', 'CD', 'ET', 'PH', 'LK', 'RU', 'NI', 'JM', 'NG', 'NE', 'AU', 'PN', 'GR', 'CX', 'UY', 'IN', 'UA', 'MH', 'TO', 'FJ', 'GS', 'NA', 'SE', 'AR', 'MR', 'SY', 'CK', 'SO', 'BB', 'NZ', 'ID', 'CO', 'ZA', 'CV', 'ZW', 'GL', 'DE', 'MX', 'PW', 'AO', 'SH', 'DZ', 'FR', 'MM', 'NC', 'CA', 'ZM', 'BT', 'TM', 'KR', 'RE', 'MZ', 'CR', 'JP', 'IR', 'TR', 'IS', 'GH', 'TC', 'RW', 'MG', 'MV', 'KZ', 'GW', 'CN', 'YE', 'PL', 'SL', 'WF', 'PE', 'ML', 'GQ', 'SA', 'IE', 'RO', 'TD', 'FO', 'LY', 'TF', 'BA', 'VU', 'SC', 'EC', 'CC', 'CF', 'GU', 'US', 'NP', 'MP', 'FM', 'PK', 'FI', 'HN', 'BR', 'NO', 'GB', 'TH', 'LR', 'KI'}

# %%
import pycountry

# WHO API: Get all available countries and their alpha-3 codes
who_url = "https://ghoapi.azureedge.net/api/DIMENSION/COUNTRY/DimensionValues"
who_response = requests.get(who_url).json()

# Convert WHO countries from alpha-3 to alpha-2 codes to be matched withOpenWeather Country Code
who_countries_alpha2 = {}

for entry in who_response['value']:
    alpha_3 = entry['Code']
    country_name = entry['Title']

    # Convert alpha-3 to alpha-2 code using pycountry
    try:
        alpha_2 = pycountry.countries.get(alpha_3=alpha_3).alpha_2
        who_countries_alpha2[alpha_2] = country_name
    except AttributeError:
        print(f"Skipping {alpha_3} - No matching alpha-2 code found.")

print(f"WHO Countries (alpha-2): {who_countries_alpha2}")

who_country_codes = who_countries_alpha2.keys()
print(f"WHO Country Codes: {list(who_country_codes)}")
# Out:
# Skipping CHI - No matching alpha-2 code found.
# Skipping ME1 - No matching alpha-2 code found.
# Skipping SDN736 - No matching alpha-2 code found.
# Skipping XKX - No matching alpha-2 code found.
# WHO Countries (alpha-2): {'AW': 'Aruba', 'AF': 'Afghanistan', 'AO': 'Angola', 'AI': 'Anguilla', 'AL': 'Albania', 'AD': 'Andorra', 'AE': 'United Arab Emirates', 'AR': 'Argentina', 'AM': 'Armenia', 'AS': 'American Samoa', 'AG': 'Antigua and Barbuda', 'AU': 'Australia', 'AT': 'Austria', 'AZ': 'Azerbaijan', 'BI': 'Burundi', 'BE': 'Belgium', 'BJ': 'Benin', 'BQ': 'Bonaire, Saint Eustatius and Saba', 'BF': 'Burkina Faso', 'BD': 'Bangladesh', 'BG': 'Bulgaria', 'BH': 'Bahrain', 'BS': 'Bahamas', 'BA': 'Bosnia and Herzegovina', 'BY': 'Belarus', 'BZ': 'Belize', 'BM': 'Bermuda', 'BO': 'Bolivia (Plurinational State of)', 'BR': 'Brazil', 'BB': 'Barbados', 'BN': 'Brunei Darussalam', 'BT': 'Bhutan', 'BW': 'Botswana', 'CF': 'Central African Republic', 'CA': 'Canada', 'CH': 'Switzerland', 'CL': 'Chile', 'CN': 'China', 'CI': "Cote d'Ivoire", 'CM': 'Cameroon', 'CD': 'Democratic Republic of the Congo', 'CG': 'Congo', 'CK': 'Cook Islands', 'CO': 'Colombia', 'KM': 'Comoros', 'CV': 'Cabo Verde', 'CR': 'Costa Rica', 'CU': 'Cuba', 'CW': 'Curaçao', 'KY': 'Cayman Islands', 'CY': 'Cyprus', 'CZ': 'Czechia', 'DE': 'Germany', 'DJ': 'Djibouti', 'DM': 'Dominica', 'DK': 'Denmark', 'DO': 'Dominican Republic', 'DZ': 'Algeria', 'EC': 'Ecuador', 'EG': 'Egypt', 'ER': 'Eritrea', 'ES': 'Spain', 'EE': 'Estonia', 'ET': 'Ethiopia', 'FI': 'Finland', 'FJ': 'Fiji', 'FK': 'Falkland Islands (Malvinas)', 'FR': 'France', 'FO': 'Faroe Islands', 'FM': 'Micronesia (Federated States of)', 'GA': 'Gabon', 'GB': 'United Kingdom of Great Britain and Northern Ireland', 'GE': 'Georgia', 'GH': 'Ghana', 'GI': 'Gibraltar', 'GN': 'Guinea', 'GP': 'Guadeloupe', 'GM': 'Gambia', 'GW': 'Guinea-Bissau', 'GQ': 'Equatorial Guinea', 'GR': 'Greece', 'GD': 'Grenada', 'GL': 'Greenland', 'GT': 'Guatemala', 'GF': 'French Guiana', 'GU': 'Guam', 'GY': 'Guyana', 'HK': 'China, Hong Kong Special Administrative Region', 'HN': 'Honduras', 'HR': 'Croatia', 'HT': 'Haiti', 'HU': 'Hungary', 'ID': 'Indonesia', 'IM': 'Isle of Man', 'IN': 'India', 'IE': 'Ireland', 'IR': 'Iran (Islamic Republic of)', 'IQ': 'Iraq', 'IS': 'Iceland', 'IL': 'Israel', 'IT': 'Italy', 'JM': 'Jamaica', 'JO': 'Jordan', 'JP': 'Japan', 'KZ': 'Kazakhstan', 'KE': 'Kenya', 'KG': 'Kyrgyzstan', 'KH': 'Cambodia', 'KI': 'Kiribati', 'KN': 'Saint Kitts and Nevis', 'KR': 'Republic of Korea', 'KW': 'Kuwait', 'LA': "Lao People's Democratic Republic", 'LB': 'Lebanon', 'LR': 'Liberia', 'LY': 'Libya', 'LC': 'Saint Lucia', 'LI': 'Liechtenstein', 'LK': 'Sri Lanka', 'LS': 'Lesotho', 'LT': 'Lithuania', 'LU': 'Luxembourg', 'LV': 'Latvia', 'MO': 'China, Macao Special Administrative Region', 'MA': 'Morocco', 'MC': 'Monaco', 'MD': 'Republic of Moldova', 'MG': 'Madagascar', 'MV': 'Maldives', 'MX': 'Mexico', 'MH': 'Marshall Islands', 'MK': 'North Macedonia', 'ML': 'Mali', 'MT': 'Malta', 'MM': 'Myanmar', 'ME': 'Montenegro', 'MN': 'Mongolia', 'MP': 'Northern Mariana Islands', 'MZ': 'Mozambique', 'MR': 'Mauritania', 'MS': 'Montserrat', 'MQ': 'Martinique', 'MU': 'Mauritius', 'MW': 'Malawi', 'MY': 'Malaysia', 'YT': 'Mayotte', 'NA': 'Namibia', 'NC': 'New Caledonia', 'NE': 'Niger', 'NG': 'Nigeria', 'NI': 'Nicaragua', 'NU': 'Niue', 'NL': 'Netherlands (Kingdom of the)', 'NO': 'Norway', 'NP': 'Nepal', 'NR': 'Nauru', 'NZ': 'New Zealand', 'OM': 'Oman', 'PK': 'Pakistan', 'PA': 'Panama', 'PE': 'Peru', 'PH': 'Philippines', 'PW': 'Palau', 'PG': 'Papua New Guinea', 'PL': 'Poland', 'PR': 'Puerto Rico', 'KP': "Democratic People's Republic of Korea", 'PT': 'Portugal', 'PY': 'Paraguay', 'PS': 'occupied Palestinian territory, including east Jerusalem', 'PF': 'French Polynesia', 'QA': 'Qatar', 'RE': 'Reunion', 'RO': 'Romania', 'RU': 'Russian Federation', 'RW': 'Rwanda', 'SA': 'Saudi Arabia', 'SD': 'Sudan', 'SN': 'Senegal', 'SG': 'Singapore', 'SH': 'Saint Helena', 'SB': 'Solomon Islands', 'SL': 'Sierra Leone', 'SV': 'El Salvador', 'SM': 'San Marino', 'SO': 'Somalia', 'PM': 'Saint Pierre and Miquelon', 'RS': 'Serbia', 'SS': 'South Sudan', 'ST': 'Sao Tome and Principe', 'SR': 'Suriname', 'SK': 'Slo ...
# WHO Country Codes: ['AW', 'AF', 'AO', 'AI', 'AL', 'AD', 'AE', 'AR', 'AM', 'AS', 'AG', 'AU', 'AT', 'AZ', 'BI', 'BE', 'BJ', 'BQ', 'BF', 'BD', 'BG', 'BH', 'BS', 'BA', 'BY', 'BZ', 'BM', 'BO', 'BR', 'BB', 'BN', 'BT', 'BW', 'CF', 'CA', 'CH', 'CL', 'CN', 'CI', 'CM', 'CD', 'CG', 'CK', 'CO', 'KM', 'CV', 'CR', 'CU', 'CW', 'KY', 'CY', 'CZ', 'DE', 'DJ', 'DM', 'DK', 'DO', 'DZ', 'EC', 'EG', 'ER', 'ES', 'EE', 'ET', 'FI', 'FJ', 'FK', 'FR', 'FO', 'FM', 'GA', 'GB', 'GE', 'GH', 'GI', 'GN', 'GP', 'GM', 'GW', 'GQ', 'GR', 'GD', 'GL', 'GT', 'GF', 'GU', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IM', 'IN', 'IE', 'IR', 'IQ', 'IS', 'IL', 'IT', 'JM', 'JO', 'JP', 'KZ', 'KE', 'KG', 'KH', 'KI', 'KN', 'KR', 'KW', 'LA', 'LB', 'LR', 'LY', 'LC', 'LI', 'LK', 'LS', 'LT', 'LU', 'LV', 'MO', 'MA', 'MC', 'MD', 'MG', 'MV', 'MX', 'MH', 'MK', 'ML', 'MT', 'MM', 'ME', 'MN', 'MP', 'MZ', 'MR', 'MS', 'MQ', 'MU', 'MW', 'MY', 'YT', 'NA', 'NC', 'NE', 'NG', 'NI', 'NU', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PK', 'PA', 'PE', 'PH', 'PW', 'PG', 'PL', 'PR', 'KP', 'PT', 'PY', 'PS', 'PF', 'QA', 'RE', 'RO', 'RU', 'RW', 'SA', 'SD', 'SN', 'SG', 'SH', 'SB', 'SL', 'SV', 'SM', 'SO', 'PM', 'RS', 'SS', 'ST', 'SR', 'SK', 'SI', 'SE', 'SZ', 'SX', 'SC', 'SY', 'TC', 'TD', 'TG', 'TH', 'TJ', 'TK', 'TM', 'TL', 'TO', 'TT', 'TN', 'TR', 'TV', 'TZ', 'UG', 'UA', 'UY', 'US', 'UZ', 'VC', 'VE', 'VG', 'VI', 'VN', 'VU', 'WF', 'WS', 'YE', 'ZA', 'ZM', 'ZW']

# %%
# Filter cities where the country code exists in the WHO data
filtered_cities = {
    city: code for city, code in city_country_map.items() if code in who_country_codes
}

print(f"Cities with matching WHO data: {len(filtered_cities)}")
print(filtered_cities)
# Out:
# Cities with matching WHO data: 438
# {'san vincenzo': 'IT', 'san patricio': 'US', 'beira': 'MZ', 'yeppoon': 'AU', 'anak': 'KP', 'constantia': 'RO', 'kodiak': 'US', 'guerrero negro': 'MX', 'tiksi': 'RU', 'margaret river': 'AU', 'bilibino': 'RU', 'taunggyi': 'MM', 'aykhal': 'RU', 'pacific grove': 'US', 'inongo': 'CD', 'college': 'US', 'ushuaia': 'AR', 'hawkesbury': 'CA', 'knyaze-volkonskoye': 'RU', 'selkirk': 'CA', 'west end': 'BS', 'ust-nera': 'RU', 'eraan': 'PH', 'puerto natales': 'CL', 'punta arenas': 'CL', 'san antonio de pale': 'GQ', 'bethel': 'US', 'santa rosa de copan': 'HN', 'caleta de carquin': 'PE', 'haiku-pauwela': 'US', 'puerto ayora': 'EC', "podporozh'ye": 'RU', 'massenya': 'TD', 'gwadar': 'PK', 'blackmans bay': 'AU', 'invercargill': 'NZ', 'papatowai': 'NZ', 'hermanus': 'ZA', 'qaqortoq': 'GL', 'port moresby': 'PG', 'port elizabeth': 'ZA', 'thompson': 'CA', 'lapy': 'PL', 'galveston': 'US', 'ponta delgada': 'PT', 'carloforte': 'IT', "st. john's": 'CA', 'nagrota': 'IN', 'hamilton': 'US', 'mareeba': 'AU', 'holualoa': 'US', 'grootfontein': 'NA', 'lihue': 'US', 'el granada': 'US', 'keflavik': 'IS', 'ribeira grande': 'PT', 'wailua homesteads': 'US', 'iqaluit': 'CA', 'aromashevo': 'RU', 'vorgashor': 'RU', 'freetown': 'SL', 'quepos': 'CR', 'yellowknife': 'CA', 'perevolotskiy': 'RU', 'iquique': 'CL', 'badger': 'US', 'polyarnyy': 'RU', 'sao felix do xingu': 'BR', 'gazipasa': 'TR', 'laguna': 'US', 'ilulissat': 'GL', 'albany': 'US', 'santa terezinha': 'BR', 'arafo': 'ES', 'togur': 'RU', 'chos malal': 'AR', 'vila franca do campo': 'PT', 'howard springs': 'AU', 'waitangi': 'NZ', 'yemetsk': 'RU', 'general conesa': 'AR', 'talnakh': 'RU', 'mayya': 'RU', 'nemuro': 'JP', 'pamanukan': 'ID', 'fortuna': 'US', 'yichun': 'CN', 'morehead city': 'US', 'strelka': 'RU', 'dudinka': 'RU', 'tura': 'IN', 'kisangani': 'CD', 'port mathurin': 'MU', 'bredasdorp': 'ZA', 'akrehamn': 'NO', 'edinburgh of the seven seas': 'SH', 'saint-francois': 'FR', 'lebu': 'CL', 'fortaleza': 'BR', 'atafu village': 'TK', 'manay': 'PH', 'valparaiso': 'CL', 'stanley': 'GB', 'waingapu': 'ID', "ust'-ilimsk": 'RU', 'kargasok': 'RU', 'fort st. john': 'CA', 'tazovsky': 'RU', 'kokopo': 'PG', 'shasta lake': 'US', 'bikenibeu village': 'KI', 'namibe': 'AO', 'susuman': 'RU', 'mogadishu': 'SO', 'ryotsu-minato': 'JP', 'pustoshka': 'RU', 'alice springs': 'AU', 'san antonio': 'US', 'georgetown': 'MY', 'garoowe': 'SO', 'yigo village': 'GU', 'patnongon': 'PH', 'sirte': 'LY', 'cabedelo': 'BR', 'hithadhoo': 'MV', 'tangalle': 'LK', "nar'yan-mar": 'RU', 'mount gambier': 'AU', 'luwuk': 'ID', 'sultanah': 'SA', 'avarua': 'CK', 'lompoc': 'US', 'gadzhiyevo': 'RU', 'kavaratti': 'IN', 'takestan': 'IR', 'dhidhdhoo': 'MV', 'queenstown': 'ZA', 'chinchilla': 'AU', 'esme': 'TR', 'odzak': 'BA', 'san jose': 'US', 'prince rupert': 'CA', 'howrah': 'IN', 'undurkhaan': 'MN', 'cockburn town': 'TC', 'yeniseysk': 'RU', 'kangiwa': 'NG', 'wau': 'SS', 'male': 'MV', 'ouadda': 'CF', 'zapata': 'US', 'klaksvik': 'FO', 'aasiaat': 'GL', 'tome acu': 'BR', 'vila velha': 'BR', 'petropavlovsk-kamchatsky': 'RU', 'goure': 'NE', 'isafjordur': 'IS', 'utrik': 'MH', 'sena madureira': 'BR', 'katsuura': 'JP', 'uliastay': 'MN', 'jamestown': 'US', 'newman': 'US', 'beidaihehaibin': 'CN', 'kabalo': 'CD', 'yerofey pavlovich': 'RU', 'puerto aysen': 'CL', 'praia da vitoria': 'PT', 'hauterive': 'FR', 'imuris': 'MX', 'minas de marcona': 'PE', 'piacabucu': 'BR', 'bandon': 'IE', 'hangu': 'CN', 'san julian': 'MX', 'mhamid': 'MA', 'uturoa': 'PF', 'sandnessjoen': 'NO', 'slavyanka': 'RU', 'saint-felicien': 'CA', 'prado': 'BR', 'mingyue': 'CN', 'uyuni': 'BO', 'alvaraes': 'BR', "severoural'sk": 'RU', 'anadyr': 'RU', 'angaur state': 'PW', 'lossiemouth': 'GB', 'le grazie di ancona': 'IT', 'marathon': 'US', 'kingston': 'JM', 'yarmouth': 'US', 'sibi': 'PK', 'bengkulu': 'ID', 'ambovombe': 'MG', 'chernyshevskiy': 'RU', 'sola': 'VU', 'borogontsy': 'RU', 'coahuayana de hidalgo': 'MX', 'port alfred': 'ZA', 'udachny': 'RU', 'coquimbo': 'CL', 'barra de santo antonio': 'BR', 'la ronge': 'CA', 'sinab ...

# %%
# Store air quality data for cities
air_quality_data = []

# Loop through each city to get pollution data
for city_info in filtered_cities:
    city = city_info['City']
    country = city_info['Country']
    lat = city_info['Latitude']
    lon = city_info['Longitude']
    
    try:
        # Query the Air Pollution API using the city's coordinates
        pollution_url = f"http://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid={weather_api_key}"
        pollution_response = requests.get(pollution_url).json()

        # Check if the response contains expected data
        if 'list' in pollution_response and pollution_response['list']:
            # Extract all pollution components
            components = pollution_response['list'][0].get('components', {})
            pm25 = components.get('pm2_5', None)
            pm10 = components.get('pm10', None)
            no2 = components.get('no2', None)
            o3 = components.get('o3', None)
            so2 = components.get('so2', None)
            co = components.get('co', None)
            nh3 = components.get('nh3', None)

            # Store the data for each city
            air_quality_data.append({
                'City': city,
                'Country': country,
                'PM2.5': pm25,
                'PM10': pm10,
                'NO2': no2,
                'O3': o3,
                'SO2': so2,
                'CO': co,
                'NH3': nh3
            })

            print(f"Retrieved pollution data for {city}, {country}")
        else:
            print(f"No data found for {city}, {country}")

    except Exception as e:
        print(f"Error retrieving data for {city}: {e}")

    # Pause to avoid API rate limits
    time.sleep(1)

# Convert the collected data into a DataFrame
air_quality_df = pd.DataFrame(air_quality_data)
print(air_quality_df.head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 6
#       4 # Loop through each city to get pollution data
#       5 for city_info in filtered_cities:
# ----> 6     city = city_info['City']
#       7     country = city_info['Country']
#       8     lat = city_info['Latitude']
#
# TypeError: string indices must be integers

# %%
san_vincenzo_data = air_quality_df[air_quality_df['City'].str.lower() == 'san vincenzo']
for index, row in san_vincenzo_data.iterrows():
    lat = row.get('Latitude')
    lon = row.get('Longitude')
    print(f"{row['City']} (Lat: {lat}, Lon: {lon}): PM2.5 = {row['PM2.5']}, PM10 = {row['PM10']}")
# Out:
# san vincenzo (Lat: None, Lon: None): PM2.5 = 0.5, PM10 = 1.52

# %%
air_quality_df.to_csv('Resources/air_quality_data.csv', index=False)

# %%
# WHO API: Air pollution attributable DALYs
who_url = "https://ghoapi.azureedge.net/api/AIR_35"
response = requests.get(who_url)

# Check for valid response
if response.status_code == 200:
    data = response.json()['value']
    # Parse the data into a DataFrame
    who_data = [
        {
            'Country': entry['SpatialDim'],
            'Year': entry['TimeDim'],
            'DALYs_per_100k': entry['NumericValue']
        }
        for entry in data
    ]
    
    df_who = pd.DataFrame(who_data)
    print(df_who.head())
    
    df_who.to_csv('Resources/who_air_pollution_dalys.csv', index=False)
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
#   Country  Year  DALYs_per_100k
# 0     BTN  2012         289.341
# 1     COG  2018        2063.071
# 2     KGZ  2017         175.166
# 3     CHN  2018       44691.668
# 4     PAN  2011          25.873

# %%
import pycountry

# Function to convert ISO-3 to ISO-2
def iso3_to_iso2(iso3_code):
    try:
        return pycountry.countries.get(alpha_3=iso3_code).alpha_2
    except AttributeError:
        return None  

df_who = pd.read_csv('Resources/who_air_pollution_dalys.csv')

# Convert WHO's ISO-3 codes to ISO-2
df_who['Country_ISO2'] = df_who['Country'].apply(iso3_to_iso2)

df_who_clean = df_who.dropna(subset=['Country_ISO2'])

df_weather = pd.read_csv('Resources/city_country_map.csv')

merged_df = pd.merge(air_quality_df, df_who_clean, left_on='Country', right_on='Country_ISO2', how='inner')

print(merged_df.head())

merged_df.to_csv('Resources/merged_air_quality_health.csv', index=False)
# Out:
#     City Country_x  PM2.5  PM10   NO2     O3   SO2     CO   NH3 Country_y  \
# 0  tiksi        RU    1.7  5.99  0.62  98.71  0.38  198.6  0.17       RUS
# 1  tiksi        RU    1.7  5.99  0.62  98.71  0.38  198.6  0.17       RUS
# 2  tiksi        RU    1.7  5.99  0.62  98.71  0.38  198.6  0.17       RUS
# 3  tiksi        RU    1.7  5.99  0.62  98.71  0.38  198.6  0.17       RUS
# 4  tiksi        RU    1.7  5.99  0.62  98.71  0.38  198.6  0.17       RUS
#
#    Year  DALYs_per_100k Country_ISO2
# 0  2010      187804.732           RU
# 1  2011      117145.137           RU
# 2  2010        4091.222           RU
# 3  2010       99488.703           RU
# 4  2017       88567.167           RU

# %%
count = len(merged_df)
count
# Out:
# 69480

# %%
# Drop redundant columns (dropping 'Country_ISO2' and 'Country_y')
merged_df = merged_df.drop(['Country_ISO2', 'Country_y'], axis=1)

# Rename columns for clarity
merged_df = merged_df.rename(columns={'Country_x': 'Country'})

# %%
merged_df.to_csv('Resources/merged_air_quality_health.csv', index=False)

# %%
# Load the merged dataset
df = pd.read_csv('Resources/merged_air_quality_health.csv')

# Group by City and Country to calculate average values across all years
grouped_df = df.groupby(['City', 'Country'], as_index=False).agg({
    'PM2.5': 'mean',
    'PM10': 'mean',
    'NO2': 'mean',
    'O3': 'mean',
    'SO2': 'mean',
    'CO': 'mean',
    'NH3': 'mean',
    'DALYs_per_100k': 'mean'
})

grouped_df['DALYs_per_100k'] = grouped_df['DALYs_per_100k'].round(1)

grouped_df.to_csv('Resources/average_air_quality_health.csv', index=False)

print(grouped_df.head(10))
# Out:
#           City Country  PM2.5  PM10   NO2     O3   SO2     CO   NH3  \
# 0  abong mbang      CM    1.7  5.99  0.62  98.71  0.38  198.6  0.17
# 1       acarau      BR    1.7  5.99  0.62  98.71  0.38  198.6  0.17
# 2    ad dindar      SD    1.7  5.99  0.62  98.71  0.38  198.6  0.17
# 3        aioun      MR    1.7  5.99  0.62  98.71  0.38  198.6  0.17
# 4        aketi      CD    1.7  5.99  0.62  98.71  0.38  198.6  0.17
# 5        aktau      KZ    1.7  5.99  0.62  98.71  0.38  198.6  0.17
# 6     akureyri      IS    1.7  5.99  0.62  98.71  0.38  198.6  0.17
# 7    al bawiti      EG    1.7  5.99  0.62  98.71  0.38  198.6  0.17
# 8     alaghsas      NE    1.7  5.99  0.62  98.71  0.38  198.6  0.17
# 9       albany      US    1.7  5.99  0.62  98.71  0.38  198.6  0.17
#
#    DALYs_per_100k
# 0          5871.4
# 1         15847.8
# 2          7159.5
# 3           627.5
# 4         20697.8
# 5          3645.7
# 6            15.0
# 7         14541.2
# 8          5487.8
# 9         22347.7
