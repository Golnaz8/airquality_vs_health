# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Generate random latitude and longitude
lats = np.random.uniform(-90, 90, size=1000)
lngs = np.random.uniform(-180, 180, size=1000)


cities = []

# Use citipy to determine the nearest city for each lat-lng combination
for lat, lng in zip(lats, lngs):
    city = citipy.nearest_city(lat, lng).city_name
    if city not in cities:
        cities.append(city)

print(f"Generated {len(cities)} unique cities.")
# Out:
# Generated 448 unique cities.

# %%
# Base URLs
weather_url = "http://api.openweathermap.org/data/2.5/weather"
air_quality_url = "http://api.openweathermap.org/data/2.5/air_pollution"

# Dictionary to store valid city data with coordinates
valid_cities = {}

for city in cities:
    try:
        # Fetch city coordinates using the weather endpoint
        query_url = f"{weather_url}?q={city}&appid={weather_api_key}"
        response = requests.get(query_url)

        if response.status_code != 200:
            print(f"City {city} not found (Status Code: {response.status_code}). Skipping...")
            continue

        # Parse JSON response for coordinates
        data = response.json()
        lat = data['coord']['lat']
        lon = data['coord']['lon']
        country = data['sys']['country']

        # Store in filtered_cities dictionary
        valid_cities[city] = {'city': city, 'lat': lat, 'lon': lon, 'country': country}

        print(f"Retrieved coordinates for {city}: ({lat}, {lon})")

    except KeyError as key_err:
        print(f"KeyError: {key_err} for {city}. Skipping...")
    except requests.exceptions.RequestException as req_err:
        print(f"Request error: {req_err} for {city}. Skipping...")

    # Pause to avoid rate limiting
    time.sleep(1)

print(f"Total valid cities with coordinates: {len(valid_cities)}")
# Out:
# Retrieved coordinates for margaret river: (-33.95, 115.0667)
# Retrieved coordinates for punta arenas: (-53.15, -70.9167)
# Retrieved coordinates for port-aux-francais: (-49.35, 70.2167)
# Retrieved coordinates for puerto natales: (-51.7236, -72.4875)
# Retrieved coordinates for adamstown: (-25.066, -130.1015)
# Retrieved coordinates for arauco: (-37.2463, -73.3175)
# Retrieved coordinates for puerto ayora: (-0.7393, -90.3518)
# Retrieved coordinates for dalandzadgad: (43.5708, 104.425)
# Retrieved coordinates for isafjordur: (66.0755, -23.124)
# Retrieved coordinates for hermanus: (-34.4187, 19.2345)
# Retrieved coordinates for qaqortoq: (60.7167, -46.0333)
# Retrieved coordinates for gierloz: (54.0813, 21.4955)
# City port glaud not found (Status Code: 404). Skipping...
# Retrieved coordinates for ribeira grande: (38.5167, -28.7)
# Retrieved coordinates for lhasa: (29.65, 91.1)
# City abraham's bay not found (Status Code: 404). Skipping...
# Retrieved coordinates for mont-dore: (-22.2833, 166.5833)
# Retrieved coordinates for kingman: (35.1894, -114.053)
# Retrieved coordinates for yuzhno-kurilsk: (44.0306, 145.8556)
# Retrieved coordinates for new norfolk: (-42.7826, 147.0587)
# Retrieved coordinates for namtsy: (62.7161, 129.6658)
# City chicxulub puerto not found (Status Code: 404). Skipping...
# Retrieved coordinates for invercargill: (-46.4, 168.35)
# Retrieved coordinates for edinburgh of the seven seas: (-37.0676, -12.3116)
# Retrieved coordinates for wenchang: (30.904, 118.4887)
# Retrieved coordinates for antsiranana: (-12.2787, 49.2917)
# Retrieved coordinates for talcahuano: (-36.7167, -73.1167)
# Retrieved coordinates for tazacorte: (28.629, -17.9293)
# Retrieved coordinates for beberibe: (-4.1797, -38.1306)
# Retrieved coordinates for albany: (42.6001, -73.9662)
# Retrieved coordinates for kirakira: (-10.4544, 161.9205)
# Retrieved coordinates for sola: (-13.8833, 167.55)
# Retrieved coordinates for winkler: (49.1817, -97.941)
# Retrieved coordinates for waitangi: (-43.9535, -176.5597)
# Retrieved coordinates for las khorey: (11.1595, 48.1967)
# Retrieved coordinates for sittwe: (20.15, 92.9)
# Retrieved coordinates for blackmans bay: (-43.0167, 147.3167)
# Retrieved coordinates for estebania: (18.4577, -70.6435)
# Retrieved coordinates for grytviken: (-54.2811, -36.5092)
# Retrieved coordinates for st. john's: (47.5649, -52.7093)
# Retrieved coordinates for tarawa: (1.419, 172.984)
# Retrieved coordinates for yellowknife: (62.456, -114.3525)
# Retrieved coordinates for kirensk: (57.7853, 108.1119)
# Retrieved coordinates for turkeli: (41.9476, 34.3386)
# Retrieved coordinates for punta del este: (-34.9667, -54.95)
# Retrieved coordinates for georgetown: (5.4112, 100.3354)
# Retrieved coordinates for labrador city: (52.9463, -66.9114)
# Retrieved coordinates for silvis: (41.5123, -90.4151)
# Retrieved coordinates for plettenberg bay: (-34.0527, 23.3716)
# Retrieved coordinates for ancud: (-41.8697, -73.8203)
# City taiohae not found (Status Code: 404). Skipping...
# Retrieved coordinates for vadso: (70.0744, 29.7487)
# Retrieved coordinates for college: (64.8569, -147.8028)
# Retrieved coordinates for whitehorse: (60.7161, -135.0538)
# Retrieved coordinates for longyearbyen: (78.2186, 15.6401)
# Retrieved coordinates for kenai: (60.5544, -151.2583)
# Retrieved coordinates for kristiansund: (63.1115, 7.732)
# Retrieved coordinates for igarka: (67.4667, 86.5833)
# Retrieved coordinates for badger: (64.8, -147.5333)
# Retrieved coordinates for san julian: (21.0167, -102.1667)
# City mulifanua not found (Status Code: 404). Skipping...
# Retrieved coordinates for kodiak: (57.79, -152.4072)
# Retrieved coordinates for iqaluit: (63.7506, -68.5145)
# Retrieved coordinates for avarua: (-21.2078, -159.775)
# Retrieved coordinates for port augusta: (-32.5, 137.7667)
# Retrieved coordinates for lazaro cardenas: (17.9583, -102.2)
# Retrieved coordinates for guatrache: (-37.6678, -63.5302)
# Retrieved coordinates for talnakh: (69.4865, 88.3972)
# Retrieved coordinates for tchintabaraden: (15.8969, 5.7985)
# Retrieved coordinates for altai: (46.3722, 96.2583)
# Retrieved coordinates for selfoss: (63.9331, -20.9971)
# Retrieved coordinates for saipan: (15.1355, 145.701)
# Retrieved coordinates for okondja: (-0.6549, 13.6753)
# Retrieved coordinates for nemuro: (43.3236, 145.575)
# Retrieved coordinates for thompson: (55.7435, -97.8558)
# Retrieved coordinates for katsuura: (35.1333, 140.3)
# Retrieved coordinates for ushuaia: (-54.8, -68.3)
# Retrieved coordinates for casablanca: (33.5928, -7.6192)
# Retrieved coordinates for rumoi: (43.9344, 141.6428)
# Retrieved coordinates for tarakan: (3.3, 117.6333)
# Retrieved coordinates for san patricio: (28.017, -97.5169)
# Retrieved coordinates for axim: (4.8699, -2.2405)
# Retrieved coordinates for praia da vitoria: (38.7333, -27.0667)
# Retrieved coordinates for lebu: (-37.6167, -73.65)
# Retrieved coordinates for atafu village: (-8.5421, -172.5159)
# Retrieved coordinates for klyuchi: (52.2667, 79.1667)
# Retrieved coordinates for weno: (7.4515, 151.8468)
# Retrieved coordinates for minas de matahambre: (22.5887, -83.9447)
# Retrieved coordinates for fort bragg: (35.139, -79.006)
# Retrieved coordinates for lata: (40.1629, -8.3327)
# Retrieved coordinates for majuro: (7.0897, 171.3803)
# Retrieved coordinates for port mathurin: (-19.6833, 63.4167)
# Retrieved coordinates for nantucket: (41.2835, -70.0995)
# Retrieved coordinates for sant lluis: (39.8526, 4.2594)
# Retrieved coordinates for hilo: (19.7297, -155.09)
# Retrieved coordinates for margate: (51.3813, 1.3862)
# Retrieved coordinates for richards bay: (-28.783, 32.0377)
# City ytyk-kyuyel' not found (Status Code: 404). Skipping...
# Retrieved coordinates for vorgashor: (67.5833, 63.95)
# Retrieved coordinates for hirara: (24.8, 125.2833)
# Retrieved coordinates for iskateley: (67.6803, 53.1512)
# Retrieved coordinates for conde-sur-noireau: (48.8488, -0.5521)
# Retrieved coordinates for boguchany: (58.3814, 97.4531)
# Retrieved coordinates for bilibino: (68.0546, 166.4372)
# Retrieved coordinates for swakopmund: (-22.6833, 14.5333)
# Retrieved coordinates for karratha: (-20.7377, 116.8463)
# Retrieved coordinates for olenino: (56.2092, 33.4889)
# Retrieved coordinates for kailua-kona: (19.6406, -155.9956)
# Retrieved coordinates for alofi: (-19.0595, -169.9187)
# Retrieved coordinates for bethel: (41.3712, -73.414)
# Retrieved coordinates for urdinarrain: (-32.6857, -58.8932)
# Retrieved coordinates for luderitz: (-26.6481, 15.1594)
# Retrieved coordinates for chonchi: (-42.6128, -73.8092)
# Retrieved coordinates for bredasdorp: (-34.5322, 20.0403)
# Retrieved coordinates for newman: (37.3138, -121.0208)
# Retrieved coordinates for saldanha: (-33.0117, 17.9442)
# Retrieved coordinates for tocopilla: (-22.092, -70.1979)
# Retrieved coordinates for anadyr: (64.75, 177.4833)
# Retrieved coordinates for kashgar: (39.4547, 75.9797)
# Retrieved coordinates for salalah: (17.0151, 54.0924)
# Retrieved coordinates for enewetak: (11.3474, 162.3373)
# Retrieved coordinates for torit: (4.4133, 32.5678)
# Retrieved coordinates for port douglas: (-16.4833, 145.4667)
# Retrieved coordinates for hithadhoo: (-0.6, 73.0833)
# Retrieved coordinates for palmer: (42.1584, -72.3287)
# Retrieved coordinates for olonkinbyen: (70.9221, -8.7187)
# Retrieved coordinates for rumphi: (-11.0186, 33.8575)
# Retrieved coordinates for inarajan village: (13.2736, 144.7484)
# Retrieved coordinates for mount isa: (-20.7333, 139.5)
# Retrieved coordinates for l'govskiy: (51.6307, 35.2775)
# Retrieved coordinates for uturoa: (-16.7333, -151.4333)
# Retrieved coordinates for betio village: (1.358, 172.9211)
# Retrieved coordinates for mizdah: (31.4451, 12.9801)
# City koneurgench not found (Status Code: 404). Skipping...
# Retrieved coordinates for williams lake: (52.1415, -122.1445)
# Retrieved coordinates for ilulissat: (69.2167, -51.1)
# Retrieved coordinates for alotau: (-10.3069, 150.4462)
# Retrieved coordinates for west island: (-12.1568, 96.8225)
# City san andros not found (Status Code: 404). Skipping...
# Retrieved coordinates for touros: (-5.1989, -35.4608)
# Retrieved coordinates for madagali: (10.8902, 13.6312)
# Retrieved coordinates for george town: (5.4112, 100.3354)
# Retrieved coordinates for ayorou: (14.7308, 0.9174)
# Retrieved coordinates for ta`u: (-14.2336, -169.5144)
# Retrieved coordinates for papatowai: (-46.5619, 169.4708)
# Retrieved coordinates for stanley: (54.868, -1.6985)
# Retrieved coordinates for tual: (-5.6667, 132.75)
# Retrieved coordinates for usinsk: (65.9939, 57.5281)
# Retrieved coordinates for hadibu: (12.65, 54.0333)
# Retrieved coordinates for yokadouma: (3.5167, 15.05)
# Retrieved coordinates for watsa: (3.0372, 29.5355)
# Retrieved coordinates for san-pedro: (4.7485, -6.6363)
# Retrieved coordinates for vila franca do campo: (37.7167, -25.4333)
# Retrieved coordinates for happy valley-goose bay: (53.3168, -60.3315)
# Retrieved coordinates for chulym: (55.0997, 80.9572)
# Retrieved coordinates for wailua homesteads: (22.0669, -159.378)
# Retrieved coordinates for kilindoni: (-7.9139, 39.6668)
# Retrieved coordinates for al kharj: (24.155, 47.3346)
# Retrieved coordinates for griffith: (41.5284, -87.4237)
# Retrieved coordinates for gadzhiyevo: (69.2551, 33.3362)
# Retrieved coordinates for konosha: (60.9736, 40.257)
# Retrieved coordinates for manta: (-0.95, -80.7333)
# Retrieved coordinates for gorelki: (54.2747, 37.6183)
# Retrieved coordinates for macas: (-2.3167, -78.1167)
# Retrieved coordinates for aasiaat: (68.7098, -52.8699)
# Retrieved coordinates for portland: (45.5234, -122.6762)
# Retrieved coordinates for hasaki: (35.7333, 140.8333)
# Retrieved coordinates for garibaldi: (-29.2561, -51.5336)
# Retrieved coordinates for teknaf: (20.8624, 92.3058)
# Retrieved coordinates for thinadhoo: (0.5333, 72.9333)
# Retrieved coordinates for minas de marcona: (-15.2119, -75.1103)
# Retrieved coordinates for tazovsky: (67.4667, 78.7)
# Retrieved coordinates for laredo: (27.5064, -99.5075)
# Retrieved coordinates for iwanai: (42.9744, 140.5089)
# Retrieved coordinates for nyurba: (63.2842, 118.3319)
# Retrieved coordinates for sancti spiritus: (21.9297, -79.4425)
# Retrieved coordinates for qamdo: (31.1667, 97.2333)
# Retrieved coordinates for lianran: (24.9227, 102.485)
# Retrieved coordinates for reynosa: (26.0833, -98.2833)
# City san antonio del estrecho not found (Status Code: 404). Skipping...
# Retrieved coordinates for wynyard: (-41, 145.7167)
# Retrieved coordinates for kzyltu: (53.6364, 72.3414)
# Retrieved coordinates for petropavlovsk-kamchatsky: (53.0452, 158.6483)
# Retrieved coordinates for dudinka: (69.4058, 86.1778)
# Retrieved coordinates for isangel: (-19.55, 169.2667)
# Retrieved coordinates for merizo village: (13.2658, 144.6691)
# Retrieved coordinates for antsohihy: (-14.8796, 47.9875)
# Retrieved coordinates for oyem: (1.5995, 11.5793)
# Retrieved coordinates for okhotsk: (59.3833, 143.3)
# Retrieved coordinates for luganville: (-15.5333, 167.1667)
# Retrieved coordinates for holualoa: (19.6228, -155.9522)
# Retrieved coordinates for port elizabeth: (-33.918, 25.5701)
# Retrieved coordinates for udachny: (66.4167, 112.4)
# Retrieved coordinates for lucapa: (-8.4192, 20.7447)
# Retrieved coordinates for intendente alvear: (-35.2338, -63.592)
# Retrieved coordinates for at taj: (24.2049, 23.2857)
# Retrieved coordinates for preobrazheniye: (42.9019, 133.9064)
# Retrieved coordinates for broome: (42.2506, -75.833)
# Retrieved coordinates for saint-philippe: (-21.3585, 55.7679)
# Retrieved coordinates for ambanja: (-13.6833, 48.45)
# Retrieved coordinates for bagua grande: (-5.7561, -78.4411)
# Retrieved coordinates for tiksi: (71.6872, 128.8694)
# Retrieved coordinates for lahan: (26.7296, 86.4951)
# Retrieved coordinates for nizhneudinsk: (54.9076, 99.0276)
# Retrieved coordinates for malaryta: (51.7905, 24.074)
# Retrieved coordinates for sao lourenco do sul: (-31.3653, -51.9783)
# Retrieved coordinates for fort st. john: (56.2499, -120.8529)
# Retrieved coordinates for yatou: (37.15, 122.3833)
# Retrieved coordinates for wright: (45.1833, -93.9502)
# Retrieved coordinates for aguadilla: (18.4275, -67.1541)
# Retrieved coordinates for chicoana: (-25.1009, -65.5331)
# Retrieved coordinates for pointe-noire: (-4.7761, 11.8635)
# Retrieved coordinates for port lincoln: (-34.7333, 135.8667)
# Retrieved coordinates for pontivy: (48, -3)
# City puerto san carlos not found (Status Code: 404). Skipping...
# Retrieved coordinates for kone: (-21.0595, 164.8658)
# Retrieved coordinates for korla: (41.7597, 86.1469)
# Retrieved coordinates for igurubi: (-4, 33.7)
# City 'ohonua not found (Status Code: 404). Skipping...
# Retrieved coordinates for alaghsas: (17.0187, 8.0168)
# Retrieved coordinates for hobyo: (5.3505, 48.5268)
# Retrieved coordinates for sisimiut: (66.9395, -53.6735)
# Retrieved coordinates for susuman: (62.7833, 148.1667)
# Retrieved coordinates for jincheng: (35.5022, 112.8328)
# Retrieved coordinates for cabo san lucas: (22.8909, -109.9124)
# Retrieved coordinates for kijang: (35.2442, 129.2139)
# City fuvahmulah not found (Status Code: 404). Skipping...
# Retrieved coordinates for dauphin: (51.1494, -100.0502)
# Retrieved coordinates for plastun: (44.7561, 136.2939)
# Retrieved coordinates for dondaicha: (21.3333, 74.5667)
# Retrieved coordinates for ferkessedougou: (9.6, -5.2)
# Retrieved coordinates for ebon: (4.582, 168.6964)
# City barka' not found (Status Code: 404). Skipping...
# Retrieved coordinates for hamilton: (39.1834, -84.5333)
# Retrieved coordinates for arroyo: (41.6096, -4.7969)
# Retrieved coordinates for camana: (-16.6228, -72.7111)
# Retrieved coordinates for villajoyosa: (38.5075, -0.2335)
# Retrieved coordinates for batroun: (34.2553, 35.6581)
# Retrieved coordinates for neiafu: (-18.65, -173.9833)
# Retrieved coordinates for aykhal: (66, 111.5)
# Retrieved coordinates for nova sintra: (14.8667, -24.7167)
# Retrieved coordinates for kaduy: (59.2, 37.15)
# City sonsorol village not found (Status Code: 404). Skipping...
# Retrieved coordinates for xiaoweizhai: (26.1903, 107.5125)
# Retrieved coordinates for ormara: (25.2088, 64.6357)
# Retrieved coordinates for lalibela: (12.0333, 39.0333)
# Retrieved coordinates for moussoro: (13.6408, 16.4901)
# Retrieved coordinates for kiruna: (67.8557, 20.2251)
# Retrieved coordinates for jamestown: (42.097, -79.2353)
# Retrieved coordinates for dapaong: (10.8639, 0.205)
# Retrieved coordinates for filadelfia: (39.9523, -75.1638)
# Retrieved coordinates for keflavik: (64.0049, -22.5624)
# Retrieved coordinates for crane: (31.3974, -102.3501)
# Retrieved coordinates for fuglafjordur: (62.244, -6.814)
# Retrieved coordinates for qionghu: (28.843, 112.3522)
# Retrieved coordinates for anapolis: (-16.3267, -48.9528)
# Retrieved coordinates for tselinnoye: (53.0833, 85.6667)
# Retrieved coordinates for tamanrasset: (22.785, 5.5228)
# City bao loc not found (Status Code: 404). Skipping...
# Retrieved coordinates for arkhangel'sk: (64.5401, 40.5433)
# Retrieved coordinates for kapuskasing: (49.4169, -82.4331)
# Retrieved coordinates for dongning: (44.0622, 131.1207)
# Retrieved coordinates for itoman: (26.1247, 127.6694)
# Retrieved coordinates for ola: (59.5833, 151.2833)
# Retrieved coordinates for brookings: (44.3114, -96.7984)
# Retrieved coordinates for ketchikan: (55.3422, -131.6461)
# Retrieved coordinates for mogocha: (53.7333, 119.7667)
# Retrieved coordinates for howrah: (22.5892, 88.3103)
# Retrieved coordinates for angaur state: (6.906, 134.13)
# City tevragh zeina not found (Status Code: 404). Skipping...
# Retrieved coordinates for conde: (-7.2597, -34.9075)
# Retrieved coordinates for frederikshavn: (57.4407, 10.5366)
# Retrieved coordinates for posse: (-14.0931, -46.3694)
# Retrieved coordinates for yanam: (16.7333, 82.2167)
# Retrieved coordinates for lugoba: (-6.45, 38.3333)
# Retrieved coordinates for hawaiian paradise park: (19.5933, -154.9731)
# Retrieved coordinates for codrington: (-38.2667, 141.9667)
# Retrieved coordinates for abashiri: (44.0213, 144.2697)
# Retrieved coordinates for glace bay: (46.1969, -59.957)
# Retrieved coordinates for alzamay: (55.5562, 98.6644)
# Retrieved coordinates for guerrero negro: (27.9769, -114.0611)
# Retrieved coordinates for capao da canoa: (-29.7456, -50.0097)
# Retrieved coordinates for ust-nera: (64.5667, 143.2)
# City jose mariano jimenez not found (Status Code: 404). Skipping...
# Retrieved coordinates for selkirk: (50.1436, -96.8845)
# Retrieved coordinates for carnarvon: (-24.8667, 113.6333)
# City qasr-e qand not found (Status Code: 404). Skipping...
# Retrieved coordinates for aracati: (-4.5617, -37.7697)
# Retrieved coordinates for floro: (61.5996, 5.0328)
# Retrieved coordinates for tiquipaya: (-17.3382, -66.2189)
# Retrieved coordinates for chibougamau: (49.9168, -74.3659)
# Retrieved coordinates for tobruk: (32.0836, 23.9764)
# Retrieved coordinates for sovetskaya gavan': (48.9723, 140.2878)
# Retrieved coordinates for mata-utu: (-13.2816, -176.1745)
# Retrieved coordinates for yangjiang: (21.85, 111.9667)
# Retrieved coordinates for la'ie: (21.6477, -157.9253)
# Retrieved coordinates for sonoita: (31.85, -112.8333)
# Retrieved coordinates for gazojak: (41.1875, 61.4036)
# Retrieved coordinates for klaksvik: (62.2266, -6.589)
# Retrieved coordinates for christchurch: (-43.5333, 172.6333)
# Retrieved coordinates for island harbour: (50.724, -1.2758)
# Retrieved coordinates for undurkhaan: (47.3194, 110.6556)
# Retrieved coordinates for bom jesus da lapa: (-13.255, -43.4181)
# Retrieved coordinates for mccook: (40.2019, -100.6257)
# Retrieved coordinates for isla mujeres: (21.2311, -86.731)
# Retrieved coordinates for flying fish cove: (-10.4217, 105.6791)
# Retrieved coordinates for byram: (32.1793, -90.2454)
# Retrieved coordinates for potam: (27.6, -110.3833)
# Retrieved coordinates for bardai: (11.65, 7.2333)
# Retrieved coordinates for timmins: (48.4669, -81.3331)
# Retrieved coordinates for calca: (-13.3333, -71.95)
# Retrieved coordinates for port alfred: (-33.5906, 26.891)
# Retrieved coordinates for quixeramobim: (-5.1992, -39.2928)
# Retrieved coordinates for constantia: (44.1833, 28.65)
# Retrieved coordinates for fiambala: (-27.6871, -67.6149)
# Retrieved coordinates for fortaleza: (-3.7227, -38.5247)
# Retrieved coordinates for whakatane: (-37.9585, 176.9854)
# Retrieved coordinates for plant city: (28.0186, -82.1129)
# Retrieved coordinates for buta: (2.7858, 24.73)
# Retrieved coordinates for kill devil hills: (36.0307, -75.676)
# Retrieved coordinates for nagqu: (31.5, 92)
# Retrieved coordinates for sena madureira: (-9.0656, -68.6569)
# Retrieved coordinates for coro: (11.4045, -69.6734)
# Retrieved coordinates for vila velha: (-20.3297, -40.2925)
# Retrieved coordinates for malabar: (-33.9667, 151.25)
# Retrieved coordinates for tolanaro: (-25.0319, 46.9987)
# Retrieved coordinates for alice springs: (-23.7, 133.8833)
# Retrieved coordinates for puerto deseado: (-47.7503, -65.8938)
# Retrieved coordinates for bamboo flat: (11.7, 92.7167)
# Retrieved coordinates for ponta delgada: (37.7333, -25.6667)
# Retrieved coordinates for grand-bassam: (5.2118, -3.7388)
# Retrieved coordinates for sitka: (57.0531, -135.33)
# Retrieved coordinates for dong ha: (16.8163, 107.1003)
# Retrieved coordinates for utrik: (11.2278, 169.8474)
# Retrieved coordinates for ar rutbah: (33.0381, 40.2848)
# Retrieved coordinates for jinchang: (38.4953, 102.1739)
# Retrieved coordinates for sao felix do xingu: (-6.6447, -51.995)
# Retrieved coordinates for paso de carrasco: (-34.8603, -56.0522)
# Retrieved coordinates for dunedin: (-45.8742, 170.5036)
# Retrieved coordinates for east london: (-33.0153, 27.9116)
# Retrieved coordinates for bereznik: (62.8551, 42.7072)
# Retrieved coordinates for saudarkrokur: (65.7461, -19.6394)
# Retrieved coordinates for tindouf: (27.6711, -8.1474)
# Retrieved coordinates for tura: (25.5198, 90.2201)
# Retrieved coordinates for bilmak: (47.3624, 36.6511)
# Retrieved coordinates for zolochiv: (49.806, 24.8944)
# Retrieved coordinates for lompoc: (34.6391, -120.4579)
# Retrieved coordinates for port moresby: (-9.4431, 147.1797)
# Retrieved coordinates for humberto de campos: (-2.5983, -43.4611)
# City fannuj not found (Status Code: 404). Skipping...
# Retrieved coordinates for kangding: (30.0513, 101.9603)
# Retrieved coordinates for oakdale: (44.963, -92.9649)
# Retrieved coordinates for umluj: (25.0213, 37.2685)
# Retrieved coordinates for licheng: (23.2955, 113.8284)
# Retrieved coordinates for enshi: (30.3, 109.4833)
# Retrieved coordinates for fujin: (47.26, 132.0322)
# Retrieved coordinates for sakaiminato: (35.55, 133.2333)
# Retrieved coordinates for vilyuchinsk: (52.9306, 158.4028)
# Retrieved coordinates for barkot: (30.8167, 78.2)
# Retrieved coordinates for khorramabad: (33.4878, 48.3558)
# Retrieved coordinates for aitape: (-3.1374, 142.3475)
# Retrieved coordinates for cold lake: (54.4502, -110.2017)
# Retrieved coordinates for mozarlandia: (-14.7447, -50.5706)
# Retrieved coordinates for kyzylorda: (44.8528, 65.5092)
# Retrieved coordinates for rethymno: (35.3647, 24.4714)
# Retrieved coordinates for st ives: (50.2086, -5.4875)
# Retrieved coordinates for bondo: (3.8146, 23.6866)
# Retrieved coordinates for bathurst: (-33.4166, 149.5806)
# Retrieved coordinates for hammerfest: (70.6634, 23.6821)
# Retrieved coordinates for sault ste. marie: (46.5168, -84.3333)
# Retrieved coordinates for arica: (-18.475, -70.3042)
# Retrieved coordinates for powell: (40.1578, -83.0752)
# Retrieved coordinates for ambasamudram: (8.7, 77.4667)
# Retrieved coordinates for huicheng: (23.0385, 116.2899)
# Retrieved coordinates for rio grande: (-32.035, -52.0986)
# Retrieved coordinates for grand baie: (-20.0182, 57.5802)
# Retrieved coordinates for kota kinabalu: (5.9749, 116.0724)
# Retrieved coordinates for yoko: (5.5333, 12.3167)
# Retrieved coordinates for villamontes: (-21.25, -63.5)
# Retrieved coordinates for greenville: (35.6127, -77.3663)
# Retrieved coordinates for makokou: (0.5738, 12.8642)
# Retrieved coordinates for nikolayevsk-on-amure: (53.1406, 140.73)
# Retrieved coordinates for port saint john's: (-31.6229, 29.5448)
# Retrieved coordinates for remire-montjoly: (4.9167, -52.2667)
# Retrieved coordinates for ilhabela: (-23.7781, -45.3581)
# Retrieved coordinates for pokaran: (26.9167, 71.9167)
# Retrieved coordinates for ca mau: (9.1769, 105.15)
# Retrieved coordinates for goundi: (9.3627, 17.366)
# Retrieved coordinates for necochea: (-38.5473, -58.7368)
# Retrieved coordinates for palikir - national government center: (6.9248, 158.1611)
# Retrieved coordinates for orange cove: (36.6244, -119.3137)
# Retrieved coordinates for kayyerkan: (69.3786, 87.7439)
# Retrieved coordinates for maturin: (9.75, -63.1767)
# Retrieved coordinates for castillos: (-34.1667, -53.8333)
# Retrieved coordinates for enid: (36.3956, -97.8784)
# Retrieved coordinates for gwadar: (25.1216, 62.3254)
# Retrieved coordinates for san luis: (-33.295, -66.3356)
# Retrieved coordinates for limburg an der lahn: (50.3833, 8.05)
# Retrieved coordinates for fort wellington: (6.4, -57.6)
# Retrieved coordinates for labytnangi: (66.6572, 66.4183)
# Retrieved coordinates for chemax: (20.65, -87.9333)
# Retrieved coordinates for sinabang: (2.4803, 96.3801)
# Retrieved coordinates for antofagasta: (-23.65, -70.4)
# Retrieved coordinates for ahuacatlan: (21.05, -104.4833)
# Retrieved coordinates for pizarro: (4.9533, -77.366)
# City devinuwara not found (Status Code: 404). Skipping...
# Retrieved coordinates for buala: (-8.145, 159.5921)
# Retrieved coordinates for afaahiti: (-17.75, -149.2833)
# Retrieved coordinates for broken hill: (-31.95, 141.4333)
# Retrieved coordinates for paracale: (14.2804, 122.7881)
# Retrieved coordinates for ankang: (32.68, 109.0172)
# Retrieved coordinates for novopskov: (49.5464, 39.0899)
# Retrieved coordinates for atchison: (39.563, -95.1216)
# Retrieved coordinates for gamba: (-2.65, 10)
# Retrieved coordinates for jiuquan: (39.7432, 98.5174)
# Retrieved coordinates for 'ain benian: (36.8028, 2.9219)
# Retrieved coordinates for mar del plata: (-38.0023, -57.5575)
# Retrieved coordinates for balcarce: (-37.8462, -58.2552)
# Retrieved coordinates for nurota: (40.5614, 65.6886)
# Retrieved coordinates for san antonio de pale: (-1.4014, 5.6325)
# Retrieved coordinates for tumayr: (25.7039, 45.868)
# Retrieved coordinates for acarau: (-2.8856, -40.12)
# Retrieved coordinates for la passe: (45.5549, -0.8967)
# Retrieved coordinates for kikwit: (-5.041, 18.8162)
# Retrieved coordinates for vilyuysk: (63.7553, 121.6247)
# Retrieved coordinates for haiku-pauwela: (20.9219, -156.3051)
# Retrieved coordinates for egilsstadir: (65.2653, -14.3948)
# Retrieved coordinates for baardheere: (2.3446, 42.2764)
# Retrieved coordinates for tromso: (69.6496, 18.957)
# Retrieved coordinates for gbarnga: (6.9956, -9.4722)
# Retrieved coordinates for vyazemskiy: (47.5378, 134.7525)
# Retrieved coordinates for yongchuan: (29.3514, 105.8947)
# Retrieved coordinates for calvinia: (-31.4707, 19.776)
# City duncan town not found (Status Code: 404). Skipping...
# Retrieved coordinates for chernyshevsk: (52.5243, 117.0174)
# Retrieved coordinates for taveta: (-3.3963, 37.6736)
# Retrieved coordinates for bandon: (51.7469, -8.7425)
# Retrieved coordinates for hancheng: (32.5186, 112.3522)
# Retrieved coordinates for sao jose da coroa grande: (-8.8978, -35.1478)
# Retrieved coordinates for mili: (6.0815, 171.735)
# Retrieved coordinates for fortuna: (40.5982, -124.1573)
# Retrieved coordinates for okha: (53.5739, 142.9478)
# Retrieved coordinates for ziro: (27.6333, 93.8333)
# Retrieved coordinates for al hamul: (31.3115, 31.1477)
# Retrieved coordinates for mahina: (-17.5065, -149.489)
# Retrieved coordinates for sakakah: (29.9697, 40.2064)
# Retrieved coordinates for gorgan: (36.8387, 54.4348)
# Retrieved coordinates for bangassou: (4.7413, 22.8184)
# Total valid cities with coordinates: 427

# %%
print(valid_cities)
# Out:
# {'margaret river': {'city': 'margaret river', 'lat': -33.95, 'lon': 115.0667, 'country': 'AU'}, 'punta arenas': {'city': 'punta arenas', 'lat': -53.15, 'lon': -70.9167, 'country': 'CL'}, 'port-aux-francais': {'city': 'port-aux-francais', 'lat': -49.35, 'lon': 70.2167, 'country': 'TF'}, 'puerto natales': {'city': 'puerto natales', 'lat': -51.7236, 'lon': -72.4875, 'country': 'CL'}, 'adamstown': {'city': 'adamstown', 'lat': -25.066, 'lon': -130.1015, 'country': 'PN'}, 'arauco': {'city': 'arauco', 'lat': -37.2463, 'lon': -73.3175, 'country': 'CL'}, 'puerto ayora': {'city': 'puerto ayora', 'lat': -0.7393, 'lon': -90.3518, 'country': 'EC'}, 'dalandzadgad': {'city': 'dalandzadgad', 'lat': 43.5708, 'lon': 104.425, 'country': 'MN'}, 'isafjordur': {'city': 'isafjordur', 'lat': 66.0755, 'lon': -23.124, 'country': 'IS'}, 'hermanus': {'city': 'hermanus', 'lat': -34.4187, 'lon': 19.2345, 'country': 'ZA'}, 'qaqortoq': {'city': 'qaqortoq', 'lat': 60.7167, 'lon': -46.0333, 'country': 'GL'}, 'gierloz': {'city': 'gierloz', 'lat': 54.0813, 'lon': 21.4955, 'country': 'PL'}, 'ribeira grande': {'city': 'ribeira grande', 'lat': 38.5167, 'lon': -28.7, 'country': 'PT'}, 'lhasa': {'city': 'lhasa', 'lat': 29.65, 'lon': 91.1, 'country': 'CN'}, 'mont-dore': {'city': 'mont-dore', 'lat': -22.2833, 'lon': 166.5833, 'country': 'NC'}, 'kingman': {'city': 'kingman', 'lat': 35.1894, 'lon': -114.053, 'country': 'US'}, 'yuzhno-kurilsk': {'city': 'yuzhno-kurilsk', 'lat': 44.0306, 'lon': 145.8556, 'country': 'RU'}, 'new norfolk': {'city': 'new norfolk', 'lat': -42.7826, 'lon': 147.0587, 'country': 'AU'}, 'namtsy': {'city': 'namtsy', 'lat': 62.7161, 'lon': 129.6658, 'country': 'RU'}, 'invercargill': {'city': 'invercargill', 'lat': -46.4, 'lon': 168.35, 'country': 'NZ'}, 'edinburgh of the seven seas': {'city': 'edinburgh of the seven seas', 'lat': -37.0676, 'lon': -12.3116, 'country': 'SH'}, 'wenchang': {'city': 'wenchang', 'lat': 30.904, 'lon': 118.4887, 'country': 'CN'}, 'antsiranana': {'city': 'antsiranana', 'lat': -12.2787, 'lon': 49.2917, 'country': 'MG'}, 'talcahuano': {'city': 'talcahuano', 'lat': -36.7167, 'lon': -73.1167, 'country': 'CL'}, 'tazacorte': {'city': 'tazacorte', 'lat': 28.629, 'lon': -17.9293, 'country': 'ES'}, 'beberibe': {'city': 'beberibe', 'lat': -4.1797, 'lon': -38.1306, 'country': 'BR'}, 'albany': {'city': 'albany', 'lat': 42.6001, 'lon': -73.9662, 'country': 'US'}, 'kirakira': {'city': 'kirakira', 'lat': -10.4544, 'lon': 161.9205, 'country': 'SB'}, 'sola': {'city': 'sola', 'lat': -13.8833, 'lon': 167.55, 'country': 'VU'}, 'winkler': {'city': 'winkler', 'lat': 49.1817, 'lon': -97.941, 'country': 'CA'}, 'waitangi': {'city': 'waitangi', 'lat': -43.9535, 'lon': -176.5597, 'country': 'NZ'}, 'las khorey': {'city': 'las khorey', 'lat': 11.1595, 'lon': 48.1967, 'country': 'SO'}, 'sittwe': {'city': 'sittwe', 'lat': 20.15, 'lon': 92.9, 'country': 'MM'}, 'blackmans bay': {'city': 'blackmans bay', 'lat': -43.0167, 'lon': 147.3167, 'country': 'AU'}, 'estebania': {'city': 'estebania', 'lat': 18.4577, 'lon': -70.6435, 'country': 'DO'}, 'grytviken': {'city': 'grytviken', 'lat': -54.2811, 'lon': -36.5092, 'country': 'GS'}, "st. john's": {'city': "st. john's", 'lat': 47.5649, 'lon': -52.7093, 'country': 'CA'}, 'tarawa': {'city': 'tarawa', 'lat': 1.419, 'lon': 172.984, 'country': 'KI'}, 'yellowknife': {'city': 'yellowknife', 'lat': 62.456, 'lon': -114.3525, 'country': 'CA'}, 'kirensk': {'city': 'kirensk', 'lat': 57.7853, 'lon': 108.1119, 'country': 'RU'}, 'turkeli': {'city': 'turkeli', 'lat': 41.9476, 'lon': 34.3386, 'country': 'TR'}, 'punta del este': {'city': 'punta del este', 'lat': -34.9667, 'lon': -54.95, 'country': 'UY'}, 'georgetown': {'city': 'georgetown', 'lat': 5.4112, 'lon': 100.3354, 'country': 'MY'}, 'labrador city': {'city': 'labrador city', 'lat': 52.9463, 'lon': -66.9114, 'country': 'CA'}, 'silvis': {'city': 'silvis', 'lat': 41.5123, 'lon': -90.4151, 'country': 'US'}, 'plettenberg bay': {'city': 'plettenberg bay', 'lat': -34.0527, 'lon': 23.37 ...

# %%
city_names = list(valid_cities.keys())
print(city_names)
# Out:
# ['margaret river', 'punta arenas', 'port-aux-francais', 'puerto natales', 'adamstown', 'arauco', 'puerto ayora', 'dalandzadgad', 'isafjordur', 'hermanus', 'qaqortoq', 'gierloz', 'ribeira grande', 'lhasa', 'mont-dore', 'kingman', 'yuzhno-kurilsk', 'new norfolk', 'namtsy', 'invercargill', 'edinburgh of the seven seas', 'wenchang', 'antsiranana', 'talcahuano', 'tazacorte', 'beberibe', 'albany', 'kirakira', 'sola', 'winkler', 'waitangi', 'las khorey', 'sittwe', 'blackmans bay', 'estebania', 'grytviken', "st. john's", 'tarawa', 'yellowknife', 'kirensk', 'turkeli', 'punta del este', 'georgetown', 'labrador city', 'silvis', 'plettenberg bay', 'ancud', 'vadso', 'college', 'whitehorse', 'longyearbyen', 'kenai', 'kristiansund', 'igarka', 'badger', 'san julian', 'kodiak', 'iqaluit', 'avarua', 'port augusta', 'lazaro cardenas', 'guatrache', 'talnakh', 'tchintabaraden', 'altai', 'selfoss', 'saipan', 'okondja', 'nemuro', 'thompson', 'katsuura', 'ushuaia', 'casablanca', 'rumoi', 'tarakan', 'san patricio', 'axim', 'praia da vitoria', 'lebu', 'atafu village', 'klyuchi', 'weno', 'minas de matahambre', 'fort bragg', 'lata', 'majuro', 'port mathurin', 'nantucket', 'sant lluis', 'hilo', 'margate', 'richards bay', 'vorgashor', 'hirara', 'iskateley', 'conde-sur-noireau', 'boguchany', 'bilibino', 'swakopmund', 'karratha', 'olenino', 'kailua-kona', 'alofi', 'bethel', 'urdinarrain', 'luderitz', 'chonchi', 'bredasdorp', 'newman', 'saldanha', 'tocopilla', 'anadyr', 'kashgar', 'salalah', 'enewetak', 'torit', 'port douglas', 'hithadhoo', 'palmer', 'olonkinbyen', 'rumphi', 'inarajan village', 'mount isa', "l'govskiy", 'uturoa', 'betio village', 'mizdah', 'williams lake', 'ilulissat', 'alotau', 'west island', 'touros', 'madagali', 'george town', 'ayorou', 'ta`u', 'papatowai', 'stanley', 'tual', 'usinsk', 'hadibu', 'yokadouma', 'watsa', 'san-pedro', 'vila franca do campo', 'happy valley-goose bay', 'chulym', 'wailua homesteads', 'kilindoni', 'al kharj', 'griffith', 'gadzhiyevo', 'konosha', 'manta', 'gorelki', 'macas', 'aasiaat', 'portland', 'hasaki', 'garibaldi', 'teknaf', 'thinadhoo', 'minas de marcona', 'tazovsky', 'laredo', 'iwanai', 'nyurba', 'sancti spiritus', 'qamdo', 'lianran', 'reynosa', 'wynyard', 'kzyltu', 'petropavlovsk-kamchatsky', 'dudinka', 'isangel', 'merizo village', 'antsohihy', 'oyem', 'okhotsk', 'luganville', 'holualoa', 'port elizabeth', 'udachny', 'lucapa', 'intendente alvear', 'at taj', 'preobrazheniye', 'broome', 'saint-philippe', 'ambanja', 'bagua grande', 'tiksi', 'lahan', 'nizhneudinsk', 'malaryta', 'sao lourenco do sul', 'fort st. john', 'yatou', 'wright', 'aguadilla', 'chicoana', 'pointe-noire', 'port lincoln', 'pontivy', 'kone', 'korla', 'igurubi', 'alaghsas', 'hobyo', 'sisimiut', 'susuman', 'jincheng', 'cabo san lucas', 'kijang', 'dauphin', 'plastun', 'dondaicha', 'ferkessedougou', 'ebon', 'hamilton', 'arroyo', 'camana', 'villajoyosa', 'batroun', 'neiafu', 'aykhal', 'nova sintra', 'kaduy', 'xiaoweizhai', 'ormara', 'lalibela', 'moussoro', 'kiruna', 'jamestown', 'dapaong', 'filadelfia', 'keflavik', 'crane', 'fuglafjordur', 'qionghu', 'anapolis', 'tselinnoye', 'tamanrasset', "arkhangel'sk", 'kapuskasing', 'dongning', 'itoman', 'ola', 'brookings', 'ketchikan', 'mogocha', 'howrah', 'angaur state', 'conde', 'frederikshavn', 'posse', 'yanam', 'lugoba', 'hawaiian paradise park', 'codrington', 'abashiri', 'glace bay', 'alzamay', 'guerrero negro', 'capao da canoa', 'ust-nera', 'selkirk', 'carnarvon', 'aracati', 'floro', 'tiquipaya', 'chibougamau', 'tobruk', "sovetskaya gavan'", 'mata-utu', 'yangjiang', "la'ie", 'sonoita', 'gazojak', 'klaksvik', 'christchurch', 'island harbour', 'undurkhaan', 'bom jesus da lapa', 'mccook', 'isla mujeres', 'flying fish cove', 'byram', 'potam', 'bardai', 'timmins', 'calca', 'port alfred', 'quixeramobim', 'constantia', 'fiambala', 'fortaleza', 'whakatane', 'plant city', 'buta', 'kill devil hills', 'nagqu', 'sena madureira', 'coro', 'vila velha', 'malabar', 'tolanaro', 'alice springs', 'puerto deseado', 'bamboo ...

# %%
# List to store air quality data
air_quality_data = []

# Loop through each city to get pollution data
for city, info in valid_cities.items():
    lat = info['lat']
    lon = info['lon']

    try:
        # Query the Air Pollution API
        pollution_url = f"{air_quality_url}?lat={lat}&lon={lon}&appid={weather_api_key}"
        pollution_response = requests.get(pollution_url).json()

        # Extract pollution components
        components = pollution_response['list'][0]['components']
        pm25 = components.get('pm2_5', None)
        pm10 = components.get('pm10', None)
        no2 = components.get('no2', None)
        o3 = components.get('o3', None)
        so2 = components.get('so2', None)
        co = components.get('co', None)
        nh3 = components.get('nh3', None)

        # Store the pollution data
        air_quality_data.append({
            'City': city,
            'Country': info['country'],
            'PM2.5': pm25,
            'PM10': pm10,
            'NO2': no2,
            'O3': o3,
            'SO2': so2,
            'CO': co,
            'NH3': nh3
        })

        print(f"Retrieved pollution data for {city}, {info['country']}")

    except Exception as e:
        print(f"Error retrieving data for {city}: {e}")

    # Pause to avoid rate limiting
    time.sleep(1)

# Convert the collected data into a DataFrame
air_quality_df = pd.DataFrame(air_quality_data)
print(air_quality_df.head())
# Out:
# Retrieved pollution data for margaret river, AU
# Retrieved pollution data for punta arenas, CL
# Retrieved pollution data for port-aux-francais, TF
# Retrieved pollution data for puerto natales, CL
# Retrieved pollution data for adamstown, PN
# Retrieved pollution data for arauco, CL
# Retrieved pollution data for puerto ayora, EC
# Retrieved pollution data for dalandzadgad, MN
# Retrieved pollution data for isafjordur, IS
# Retrieved pollution data for hermanus, ZA
# Retrieved pollution data for qaqortoq, GL
# Retrieved pollution data for gierloz, PL
# Retrieved pollution data for ribeira grande, PT
# Retrieved pollution data for lhasa, CN
# Retrieved pollution data for mont-dore, NC
# Retrieved pollution data for kingman, US
# Retrieved pollution data for yuzhno-kurilsk, RU
# Retrieved pollution data for new norfolk, AU
# Retrieved pollution data for namtsy, RU
# Retrieved pollution data for invercargill, NZ
# Retrieved pollution data for edinburgh of the seven seas, SH
# Retrieved pollution data for wenchang, CN
# Retrieved pollution data for antsiranana, MG
# Retrieved pollution data for talcahuano, CL
# Retrieved pollution data for tazacorte, ES
# Retrieved pollution data for beberibe, BR
# Retrieved pollution data for albany, US
# Retrieved pollution data for kirakira, SB
# Retrieved pollution data for sola, VU
# Retrieved pollution data for winkler, CA
# Retrieved pollution data for waitangi, NZ
# Retrieved pollution data for las khorey, SO
# Retrieved pollution data for sittwe, MM
# Retrieved pollution data for blackmans bay, AU
# Retrieved pollution data for estebania, DO
# Retrieved pollution data for grytviken, GS
# Retrieved pollution data for st. john's, CA
# Retrieved pollution data for tarawa, KI
# Retrieved pollution data for yellowknife, CA
# Retrieved pollution data for kirensk, RU
# Retrieved pollution data for turkeli, TR
# Retrieved pollution data for punta del este, UY
# Retrieved pollution data for georgetown, MY
# Retrieved pollution data for labrador city, CA
# Retrieved pollution data for silvis, US
# Retrieved pollution data for plettenberg bay, ZA
# Retrieved pollution data for ancud, CL
# Retrieved pollution data for vadso, NO
# Retrieved pollution data for college, US
# Retrieved pollution data for whitehorse, CA
# Retrieved pollution data for longyearbyen, SJ
# Retrieved pollution data for kenai, US
# Retrieved pollution data for kristiansund, NO
# Retrieved pollution data for igarka, RU
# Retrieved pollution data for badger, US
# Retrieved pollution data for san julian, MX
# Retrieved pollution data for kodiak, US
# Retrieved pollution data for iqaluit, CA
# Retrieved pollution data for avarua, CK
# Retrieved pollution data for port augusta, AU
# Retrieved pollution data for lazaro cardenas, MX
# Retrieved pollution data for guatrache, AR
# Retrieved pollution data for talnakh, RU
# Retrieved pollution data for tchintabaraden, NE
# Retrieved pollution data for altai, MN
# Retrieved pollution data for selfoss, IS
# Retrieved pollution data for saipan, MP
# Retrieved pollution data for okondja, GA
# Retrieved pollution data for nemuro, JP
# Retrieved pollution data for thompson, CA
# Retrieved pollution data for katsuura, JP
# Retrieved pollution data for ushuaia, AR
# Retrieved pollution data for casablanca, MA
# Retrieved pollution data for rumoi, JP
# Retrieved pollution data for tarakan, ID
# Retrieved pollution data for san patricio, US
# Retrieved pollution data for axim, GH
# Retrieved pollution data for praia da vitoria, PT
# Retrieved pollution data for lebu, CL
# Retrieved pollution data for atafu village, TK
# Retrieved pollution data for klyuchi, RU
# Retrieved pollution data for weno, FM
# Retrieved pollution data for minas de matahambre, CU
# Retrieved pollution data for fort bragg, US
# Retrieved pollution data for lata, PT
# Retrieved pollution data for majuro, MH
# Retrieved pollution data for port mathurin, MU
# Retrieved pollution data for nantucket, US
# Retrieved pollution data for sant lluis, ES
# Retrieved pollution data for hilo, US
# Retrieved pollution data for margate, GB
# Retrieved pollution data for richards bay, ZA
# Retrieved pollution data for vorgashor, RU
# Retrieved pollution data for hirara, JP
# Retrieved pollution data for iskateley, RU
# Retrieved pollution data for conde-sur-noireau, FR
# Retrieved pollution data for boguchany, RU
# Retrieved pollution data for bilibino, RU
# Retrieved pollution data for swakopmund, NA
# Retrieved pollution data for karratha, AU
# Retrieved pollution data for olenino, RU
# Retrieved pollution data for kailua-kona, US
# Retrieved pollution data for alofi, NU
# Retrieved pollution data for bethel, US
# Retrieved pollution data for urdinarrain, AR
# Retrieved pollution data for luderitz, NA
# Retrieved pollution data for chonchi, CL
# Retrieved pollution data for bredasdorp, ZA
# Retrieved pollution data for newman, US
# Retrieved pollution data for saldanha, ZA
# Retrieved pollution data for tocopilla, CL
# Retrieved pollution data for anadyr, RU
# Retrieved pollution data for kashgar, CN
# Retrieved pollution data for salalah, OM
# Retrieved pollution data for enewetak, MH
# Retrieved pollution data for torit, SS
# Retrieved pollution data for port douglas, AU
# Retrieved pollution data for hithadhoo, MV
# Retrieved pollution data for palmer, US
# Retrieved pollution data for olonkinbyen, SJ
# Retrieved pollution data for rumphi, MW
# Retrieved pollution data for inarajan village, GU
# Retrieved pollution data for mount isa, AU
# Retrieved pollution data for l'govskiy, RU
# Retrieved pollution data for uturoa, PF
# Retrieved pollution data for betio village, KI
# Retrieved pollution data for mizdah, LY
# Retrieved pollution data for williams lake, CA
# Retrieved pollution data for ilulissat, GL
# Retrieved pollution data for alotau, PG
# Retrieved pollution data for west island, CC
# Retrieved pollution data for touros, BR
# Retrieved pollution data for madagali, NG
# Retrieved pollution data for george town, MY
# Retrieved pollution data for ayorou, NE
# Retrieved pollution data for ta`u, AS
# Retrieved pollution data for papatowai, NZ
# Retrieved pollution data for stanley, GB
# Retrieved pollution data for tual, ID
# Retrieved pollution data for usinsk, RU
# Retrieved pollution data for hadibu, YE
# Retrieved pollution data for yokadouma, CM
# Retrieved pollution data for watsa, CD
# Retrieved pollution data for san-pedro, CI
# Retrieved pollution data for vila franca do campo, PT
# Retrieved pollution data for happy valley-goose bay, CA
# Retrieved pollution data for chulym, RU
# Retrieved pollution data for wailua homesteads, US
# Retrieved pollution data for kilindoni, TZ
# Retrieved pollution data for al kharj, SA
# Retrieved pollution data for griffith, US
# Retrieved pollution data for gadzhiyevo, RU
# Retrieved pollution data for konosha, RU
# Retrieved pollution data for manta, EC
# Retrieved pollution data for gorelki, RU
# Retrieved pollution data for macas, EC
# Retrieved pollution data for aasiaat, GL
# Retrieved pollution data for portland, US
# Retrieved pollution data for hasaki, JP
# Retrieved pollution data for garibaldi, BR
# Retrieved pollution data for teknaf, BD
# Retrieved pollution data for thinadhoo, MV
# Retrieved pollution data for minas de marcona, PE
# Retrieved pollution data for tazovsky, RU
# Retrieved pollution data for laredo, US
# Retrieved pollution data for iwanai, JP
# Retrieved pollution data for nyurba, RU
# Retrieved pollution data for sancti spiritus, CU
# Retrieved pollution data for qamdo, CN
# Retrieved pollution data for lianran, CN
# Retrieved pollution data for reynosa, MX
# Retrieved pollution data for wynyard, AU
# Retrieved pollution data for kzyltu, KZ
# Retrieved pollution data for petropavlovsk-kamchatsky, RU
# Retrieved pollution data for dudinka, RU
# Retrieved pollution data for isangel, VU
# Retrieved pollution data for merizo village, GU
# Retrieved pollution data for antsohihy, MG
# Retrieved pollution data for oyem, GA
# Retrieved pollution data for okhotsk, RU
# Retrieved pollution data for luganville, VU
# Retrieved pollution data for holualoa, US
# Retrieved pollution data for port elizabeth, ZA
# Retrieved pollution data for udachny, RU
# Retrieved pollution data for lucapa, AO
# Retrieved pollution data for intendente alvear, AR
# Retrieved pollution data for at taj, LY
# Retrieved pollution data for preobrazheniye, RU
# Retrieved pollution data for broome, US
# Retrieved pollution data for saint-philippe, RE
# Retrieved pollution data for ambanja, MG
# Retrieved pollution data for bagua grande, PE
# Retrieved pollution data for tiksi, RU
# Retrieved pollution data for lahan, NP
# Retrieved pollution data for nizhneudinsk, RU
# Retrieved pollution data for malaryta, BY
# Retrieved pollution data for sao lourenco do sul, BR
# Retrieved pollution data for fort st. john, CA
# Retrieved pollution data for yatou, CN
# Retrieved pollution data for wright, US
# Retrieved pollution data for aguadilla, PR
# Retrieved pollution data for chicoana, AR
# Retrieved pollution data for pointe-noire, CG
# Retrieved pollution data for port lincoln, AU
# Retrieved pollution data for pontivy, FR
# Retrieved pollution data for kone, NC
# Retrieved pollution data for korla, CN
# Retrieved pollution data for igurubi, TZ
# Retrieved pollution data for alaghsas, NE
# Retrieved pollution data for hobyo, SO
# Retrieved pollution data for sisimiut, GL
# Retrieved pollution data for susuman, RU
# Retrieved pollution data for jincheng, CN
# Retrieved pollution data for cabo san lucas, MX
# Retrieved pollution data for kijang, KR
# Retrieved pollution data for dauphin, CA
# Retrieved pollution data for plastun, RU
# Retrieved pollution data for dondaicha, IN
# Retrieved pollution data for ferkessedougou, CI
# Retrieved pollution data for ebon, MH
# Retrieved pollution data for hamilton, US
# Retrieved pollution data for arroyo, ES
# Retrieved pollution data for camana, PE
# Retrieved pollution data for villajoyosa, ES
# Retrieved pollution data for batroun, LB
# Retrieved pollution data for neiafu, TO
# Retrieved pollution data for aykhal, RU
# Retrieved pollution data for nova sintra, CV
# Retrieved pollution data for kaduy, RU
# Retrieved pollution data for xiaoweizhai, CN
# Retrieved pollution data for ormara, PK
# Retrieved pollution data for lalibela, ET
# Retrieved pollution data for moussoro, TD
# Retrieved pollution data for kiruna, SE
# Retrieved pollution data for jamestown, US
# Retrieved pollution data for dapaong, TG
# Retrieved pollution data for filadelfia, US
# Retrieved pollution data for keflavik, IS
# Retrieved pollution data for crane, US
# Retrieved pollution data for fuglafjordur, FO
# Retrieved pollution data for qionghu, CN
# Retrieved pollution data for anapolis, BR
# Retrieved pollution data for tselinnoye, RU
# Retrieved pollution data for tamanrasset, DZ
# Retrieved pollution data for arkhangel'sk, RU
# Retrieved pollution data for kapuskasing, CA
# Retrieved pollution data for dongning, CN
# Retrieved pollution data for itoman, JP
# Retrieved pollution data for ola, RU
# Retrieved pollution data for brookings, US
# Retrieved pollution data for ketchikan, US
# Retrieved pollution data for mogocha, RU
# Retrieved pollution data for howrah, IN
# Retrieved pollution data for angaur state, PW
# Retrieved pollution data for conde, BR
# Retrieved pollution data for frederikshavn, DK
# Retrieved pollution data for posse, BR
# Retrieved pollution data for yanam, IN
# Retrieved pollution data for lugoba, TZ
# Retrieved pollution data for hawaiian paradise park, US
# Retrieved pollution data for codrington, AU
# Retrieved pollution data for abashiri, JP
# Retrieved pollution data for glace bay, CA
# Retrieved pollution data for alzamay, RU
# Retrieved pollution data for guerrero negro, MX
# Retrieved pollution data for capao da canoa, BR
# Retrieved pollution data for ust-nera, RU
# Retrieved pollution data for selkirk, CA
# Retrieved pollution data for carnarvon, AU
# Retrieved pollution data for aracati, BR
# Retrieved pollution data for floro, NO
# Retrieved pollution data for tiquipaya, BO
# Retrieved pollution data for chibougamau, CA
# Retrieved pollution data for tobruk, LY
# Retrieved pollution data for sovetskaya gavan', RU
# Retrieved pollution data for mata-utu, WF
# Retrieved pollution data for yangjiang, CN
# Retrieved pollution data for la'ie, US
# Retrieved pollution data for sonoita, MX
# Retrieved pollution data for gazojak, TM
# Retrieved pollution data for klaksvik, FO
# Retrieved pollution data for christchurch, NZ
# Retrieved pollution data for island harbour, GB
# Retrieved pollution data for undurkhaan, MN
# Retrieved pollution data for bom jesus da lapa, BR
# Retrieved pollution data for mccook, US
# Retrieved pollution data for isla mujeres, MX
# Retrieved pollution data for flying fish cove, CX
# Retrieved pollution data for byram, US
# Retrieved pollution data for potam, MX
# Retrieved pollution data for bardai, NG
# Retrieved pollution data for timmins, CA
# Retrieved pollution data for calca, PE
# Retrieved pollution data for port alfred, ZA
# Retrieved pollution data for quixeramobim, BR
# Retrieved pollution data for constantia, RO
# Retrieved pollution data for fiambala, AR
# Retrieved pollution data for fortaleza, BR
# Retrieved pollution data for whakatane, NZ
# Retrieved pollution data for plant city, US
# Retrieved pollution data for buta, CD
# Retrieved pollution data for kill devil hills, US
# Retrieved pollution data for nagqu, CN
# Retrieved pollution data for sena madureira, BR
# Retrieved pollution data for coro, VE
# Retrieved pollution data for vila velha, BR
# Retrieved pollution data for malabar, AU
# Retrieved pollution data for tolanaro, MG
# Retrieved pollution data for alice springs, AU
# Retrieved pollution data for puerto deseado, AR
# Retrieved pollution data for bamboo flat, IN
# Retrieved pollution data for ponta delgada, PT
# Retrieved pollution data for grand-bassam, CI
# Retrieved pollution data for sitka, US
# Retrieved pollution data for dong ha, VN
# Retrieved pollution data for utrik, MH
# Retrieved pollution data for ar rutbah, IQ
# Retrieved pollution data for jinchang, CN
# Retrieved pollution data for sao felix do xingu, BR
# Retrieved pollution data for paso de carrasco, UY
# Retrieved pollution data for dunedin, NZ
# Retrieved pollution data for east london, ZA
# Retrieved pollution data for bereznik, RU
# Retrieved pollution data for saudarkrokur, IS
# Retrieved pollution data for tindouf, DZ
# Retrieved pollution data for tura, IN
# Retrieved pollution data for bilmak, UA
# Retrieved pollution data for zolochiv, UA
# Retrieved pollution data for lompoc, US
# Retrieved pollution data for port moresby, PG
# Retrieved pollution data for humberto de campos, BR
# Retrieved pollution data for kangding, CN
# Retrieved pollution data for oakdale, US
# Retrieved pollution data for umluj, SA
# Retrieved pollution data for licheng, CN
# Retrieved pollution data for enshi, CN
# Retrieved pollution data for fujin, CN
# Retrieved pollution data for sakaiminato, JP
# Retrieved pollution data for vilyuchinsk, RU
# Retrieved pollution data for barkot, IN
# Retrieved pollution data for khorramabad, IR
# Retrieved pollution data for aitape, PG
# Retrieved pollution data for cold lake, CA
# Retrieved pollution data for mozarlandia, BR
# Retrieved pollution data for kyzylorda, KZ
# Retrieved pollution data for rethymno, GR
# Retrieved pollution data for st ives, GB
# Retrieved pollution data for bondo, CD
# Retrieved pollution data for bathurst, AU
# Retrieved pollution data for hammerfest, NO
# Retrieved pollution data for sault ste. marie, CA
# Retrieved pollution data for arica, CL
# Retrieved pollution data for powell, US
# Retrieved pollution data for ambasamudram, IN
# Retrieved pollution data for huicheng, CN
# Retrieved pollution data for rio grande, BR
# Retrieved pollution data for grand baie, MU
# Retrieved pollution data for kota kinabalu, MY
# Retrieved pollution data for yoko, CM
# Retrieved pollution data for villamontes, BO
# Retrieved pollution data for greenville, US
# Retrieved pollution data for makokou, GA
# Retrieved pollution data for nikolayevsk-on-amure, RU
# Retrieved pollution data for port saint john's, ZA
# Retrieved pollution data for remire-montjoly, GF
# Retrieved pollution data for ilhabela, BR
# Retrieved pollution data for pokaran, IN
# Retrieved pollution data for ca mau, VN
# Retrieved pollution data for goundi, TD
# Retrieved pollution data for necochea, AR
# Retrieved pollution data for palikir - national government center, FM
# Retrieved pollution data for orange cove, US
# Retrieved pollution data for kayyerkan, RU
# Retrieved pollution data for maturin, VE
# Retrieved pollution data for castillos, UY
# Retrieved pollution data for enid, US
# Retrieved pollution data for gwadar, PK
# Retrieved pollution data for san luis, AR
# Retrieved pollution data for limburg an der lahn, DE
# Retrieved pollution data for fort wellington, GY
# Retrieved pollution data for labytnangi, RU
# Retrieved pollution data for chemax, MX
# Retrieved pollution data for sinabang, ID
# Retrieved pollution data for antofagasta, CL
# Retrieved pollution data for ahuacatlan, MX
# Retrieved pollution data for pizarro, CO
# Retrieved pollution data for buala, SB
# Retrieved pollution data for afaahiti, PF
# Retrieved pollution data for broken hill, AU
# Retrieved pollution data for paracale, PH
# Retrieved pollution data for ankang, CN
# Retrieved pollution data for novopskov, UA
# Retrieved pollution data for atchison, US
# Retrieved pollution data for gamba, GA
# Retrieved pollution data for jiuquan, CN
# Retrieved pollution data for 'ain benian, DZ
# Retrieved pollution data for mar del plata, AR
# Retrieved pollution data for balcarce, AR
# Retrieved pollution data for nurota, UZ
# Retrieved pollution data for san antonio de pale, GQ
# Retrieved pollution data for tumayr, SA
# Retrieved pollution data for acarau, BR
# Retrieved pollution data for la passe, FR
# Retrieved pollution data for kikwit, CD
# Retrieved pollution data for vilyuysk, RU
# Retrieved pollution data for haiku-pauwela, US
# Retrieved pollution data for egilsstadir, IS
# Retrieved pollution data for baardheere, SO
# Retrieved pollution data for tromso, NO
# Retrieved pollution data for gbarnga, LR
# Retrieved pollution data for vyazemskiy, RU
# Retrieved pollution data for yongchuan, CN
# Retrieved pollution data for calvinia, ZA
# Retrieved pollution data for chernyshevsk, RU
# Retrieved pollution data for taveta, KE
# Retrieved pollution data for bandon, IE
# Retrieved pollution data for hancheng, CN
# Retrieved pollution data for sao jose da coroa grande, BR
# Retrieved pollution data for mili, MH
# Retrieved pollution data for fortuna, US
# Retrieved pollution data for okha, RU
# Retrieved pollution data for ziro, IN
# Retrieved pollution data for al hamul, EG
# Retrieved pollution data for mahina, PF
# Retrieved pollution data for sakakah, SA
# Retrieved pollution data for gorgan, IR
# Retrieved pollution data for bangassou, CF
#                 City Country  PM2.5   PM10   NO2     O3   SO2      CO   NH3
# 0     margaret river      AU   2.54  10.04  0.15  59.37  0.39  226.97  0.00
# 1       punta arenas      CL   0.50   0.52  0.23  38.62  0.02  220.30  0.42
# 2  port-aux-francais      TF   0.50   0.70  0.01  43.27  0.03  226.97  0.00
# 3     puerto natales      CL   0.50   0.50  0.31  43.99  0.01  243.66  0.58
# 4          adamstown      PN   2.86  15.08  0.04  62.23  0.24  243.66  0.00

# %%
air_quality_df.to_csv('Resources/air_quality_data.csv', index=False)

# %%
# Create a dictionary to store city-country pairs
city_country_map = {}

for city in city_names:
    try:
        query_url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}"
        response = requests.get(query_url).json()
        
        # Store the city and corresponding country code
        country = response['sys']['country']
        city_country_map[city] = country

        # Print city and country
        print(f"City: {city}, Country: {country}")

    except KeyError as key_err:
        print(f"KeyError: {key_err} for {city}. Skipping...")
    except requests.exceptions.RequestException as req_err:
        print(f"Request error: {req_err} for {city}. Skipping...")

    # Pause to avoid rate limiting
    time.sleep(1)

print(city_country_map)
# Out:
# City: margaret river, Country: AU
# City: punta arenas, Country: CL
# City: port-aux-francais, Country: TF
# City: puerto natales, Country: CL
# City: adamstown, Country: PN
# City: arauco, Country: CL
# City: puerto ayora, Country: EC
# City: dalandzadgad, Country: MN
# City: isafjordur, Country: IS
# City: hermanus, Country: ZA
# City: qaqortoq, Country: GL
# City: gierloz, Country: PL
# City: ribeira grande, Country: PT
# City: lhasa, Country: CN
# City: mont-dore, Country: NC
# City: kingman, Country: US
# City: yuzhno-kurilsk, Country: RU
# City: new norfolk, Country: AU
# City: namtsy, Country: RU
# City: invercargill, Country: NZ
# City: edinburgh of the seven seas, Country: SH
# City: wenchang, Country: CN
# City: antsiranana, Country: MG
# City: talcahuano, Country: CL
# City: tazacorte, Country: ES
# City: beberibe, Country: BR
# City: albany, Country: US
# City: kirakira, Country: SB
# City: sola, Country: VU
# City: winkler, Country: CA
# City: waitangi, Country: NZ
# City: las khorey, Country: SO
# City: sittwe, Country: MM
# City: blackmans bay, Country: AU
# City: estebania, Country: DO
# City: grytviken, Country: GS
# City: st. john's, Country: CA
# City: tarawa, Country: KI
# City: yellowknife, Country: CA
# City: kirensk, Country: RU
# City: turkeli, Country: TR
# City: punta del este, Country: UY
# City: georgetown, Country: MY
# City: labrador city, Country: CA
# City: silvis, Country: US
# City: plettenberg bay, Country: ZA
# City: ancud, Country: CL
# City: vadso, Country: NO
# City: college, Country: US
# City: whitehorse, Country: CA
# City: longyearbyen, Country: SJ
# City: kenai, Country: US
# City: kristiansund, Country: NO
# City: igarka, Country: RU
# City: badger, Country: US
# City: san julian, Country: MX
# City: kodiak, Country: US
# City: iqaluit, Country: CA
# City: avarua, Country: CK
# City: port augusta, Country: AU
# City: lazaro cardenas, Country: MX
# City: guatrache, Country: AR
# City: talnakh, Country: RU
# City: tchintabaraden, Country: NE
# City: altai, Country: MN
# City: selfoss, Country: IS
# City: saipan, Country: MP
# City: okondja, Country: GA
# City: nemuro, Country: JP
# City: thompson, Country: CA
# City: katsuura, Country: JP
# City: ushuaia, Country: AR
# City: casablanca, Country: MA
# City: rumoi, Country: JP
# City: tarakan, Country: ID
# City: san patricio, Country: US
# City: axim, Country: GH
# City: praia da vitoria, Country: PT
# City: lebu, Country: CL
# City: atafu village, Country: TK
# City: klyuchi, Country: RU
# City: weno, Country: FM
# City: minas de matahambre, Country: CU
# City: fort bragg, Country: US
# City: lata, Country: PT
# City: majuro, Country: MH
# City: port mathurin, Country: MU
# City: nantucket, Country: US
# City: sant lluis, Country: ES
# City: hilo, Country: US
# City: margate, Country: GB
# City: richards bay, Country: ZA
# City: vorgashor, Country: RU
# City: hirara, Country: JP
# City: iskateley, Country: RU
# City: conde-sur-noireau, Country: FR
# City: boguchany, Country: RU
# City: bilibino, Country: RU
# City: swakopmund, Country: NA
# City: karratha, Country: AU
# City: olenino, Country: RU
# City: kailua-kona, Country: US
# City: alofi, Country: NU
# City: bethel, Country: US
# City: urdinarrain, Country: AR
# City: luderitz, Country: NA
# City: chonchi, Country: CL
# City: bredasdorp, Country: ZA
# City: newman, Country: US
# City: saldanha, Country: ZA
# City: tocopilla, Country: CL
# City: anadyr, Country: RU
# City: kashgar, Country: CN
# City: salalah, Country: OM
# City: enewetak, Country: MH
# City: torit, Country: SS
# City: port douglas, Country: AU
# City: hithadhoo, Country: MV
# City: palmer, Country: US
# City: olonkinbyen, Country: SJ
# City: rumphi, Country: MW
# City: inarajan village, Country: GU
# City: mount isa, Country: AU
# City: l'govskiy, Country: RU
# City: uturoa, Country: PF
# City: betio village, Country: KI
# City: mizdah, Country: LY
# City: williams lake, Country: CA
# City: ilulissat, Country: GL
# City: alotau, Country: PG
# City: west island, Country: CC
# City: touros, Country: BR
# City: madagali, Country: NG
# City: george town, Country: MY
# City: ayorou, Country: NE
# City: ta`u, Country: AS
# City: papatowai, Country: NZ
# City: stanley, Country: GB
# City: tual, Country: ID
# City: usinsk, Country: RU
# City: hadibu, Country: YE
# City: yokadouma, Country: CM
# City: watsa, Country: CD
# City: san-pedro, Country: CI
# City: vila franca do campo, Country: PT
# City: happy valley-goose bay, Country: CA
# City: chulym, Country: RU
# City: wailua homesteads, Country: US
# City: kilindoni, Country: TZ
# City: al kharj, Country: SA
# City: griffith, Country: US
# City: gadzhiyevo, Country: RU
# City: konosha, Country: RU
# City: manta, Country: EC
# City: gorelki, Country: RU
# City: macas, Country: EC
# City: aasiaat, Country: GL
# City: portland, Country: US
# City: hasaki, Country: JP
# City: garibaldi, Country: BR
# City: teknaf, Country: BD
# City: thinadhoo, Country: MV
# City: minas de marcona, Country: PE
# City: tazovsky, Country: RU
# City: laredo, Country: US
# City: iwanai, Country: JP
# City: nyurba, Country: RU
# City: sancti spiritus, Country: CU
# City: qamdo, Country: CN
# City: lianran, Country: CN
# City: reynosa, Country: MX
# City: wynyard, Country: AU
# City: kzyltu, Country: KZ
# City: petropavlovsk-kamchatsky, Country: RU
# City: dudinka, Country: RU
# City: isangel, Country: VU
# City: merizo village, Country: GU
# City: antsohihy, Country: MG
# City: oyem, Country: GA
# City: okhotsk, Country: RU
# City: luganville, Country: VU
# City: holualoa, Country: US
# City: port elizabeth, Country: ZA
# City: udachny, Country: RU
# City: lucapa, Country: AO
# City: intendente alvear, Country: AR
# City: at taj, Country: LY
# City: preobrazheniye, Country: RU
# City: broome, Country: US
# City: saint-philippe, Country: RE
# City: ambanja, Country: MG
# City: bagua grande, Country: PE
# City: tiksi, Country: RU
# City: lahan, Country: NP
# City: nizhneudinsk, Country: RU
# City: malaryta, Country: BY
# City: sao lourenco do sul, Country: BR
# City: fort st. john, Country: CA
# City: yatou, Country: CN
# City: wright, Country: US
# City: aguadilla, Country: PR
# City: chicoana, Country: AR
# City: pointe-noire, Country: CG
# City: port lincoln, Country: AU
# City: pontivy, Country: FR
# City: kone, Country: NC
# City: korla, Country: CN
# City: igurubi, Country: TZ
# City: alaghsas, Country: NE
# City: hobyo, Country: SO
# City: sisimiut, Country: GL
# City: susuman, Country: RU
# City: jincheng, Country: CN
# City: cabo san lucas, Country: MX
# City: kijang, Country: KR
# City: dauphin, Country: CA
# City: plastun, Country: RU
# City: dondaicha, Country: IN
# City: ferkessedougou, Country: CI
# City: ebon, Country: MH
# City: hamilton, Country: US
# City: arroyo, Country: ES
# City: camana, Country: PE
# City: villajoyosa, Country: ES
# City: batroun, Country: LB
# City: neiafu, Country: TO
# City: aykhal, Country: RU
# City: nova sintra, Country: CV
# City: kaduy, Country: RU
# City: xiaoweizhai, Country: CN
# City: ormara, Country: PK
# City: lalibela, Country: ET
# City: moussoro, Country: TD
# City: kiruna, Country: SE
# City: jamestown, Country: US
# City: dapaong, Country: TG
# City: filadelfia, Country: US
# City: keflavik, Country: IS
# City: crane, Country: US
# City: fuglafjordur, Country: FO
# City: qionghu, Country: CN
# City: anapolis, Country: BR
# City: tselinnoye, Country: RU
# City: tamanrasset, Country: DZ
# City: arkhangel'sk, Country: RU
# City: kapuskasing, Country: CA
# City: dongning, Country: CN
# City: itoman, Country: JP
# City: ola, Country: RU
# City: brookings, Country: US
# City: ketchikan, Country: US
# City: mogocha, Country: RU
# City: howrah, Country: IN
# City: angaur state, Country: PW
# City: conde, Country: BR
# City: frederikshavn, Country: DK
# City: posse, Country: BR
# City: yanam, Country: IN
# City: lugoba, Country: TZ
# City: hawaiian paradise park, Country: US
# City: codrington, Country: AU
# City: abashiri, Country: JP
# City: glace bay, Country: CA
# City: alzamay, Country: RU
# City: guerrero negro, Country: MX
# City: capao da canoa, Country: BR
# City: ust-nera, Country: RU
# City: selkirk, Country: CA
# City: carnarvon, Country: AU
# City: aracati, Country: BR
# City: floro, Country: NO
# City: tiquipaya, Country: BO
# City: chibougamau, Country: CA
# City: tobruk, Country: LY
# City: sovetskaya gavan', Country: RU
# City: mata-utu, Country: WF
# City: yangjiang, Country: CN
# City: la'ie, Country: US
# City: sonoita, Country: MX
# City: gazojak, Country: TM
# City: klaksvik, Country: FO
# City: christchurch, Country: NZ
# City: island harbour, Country: GB
# City: undurkhaan, Country: MN
# City: bom jesus da lapa, Country: BR
# City: mccook, Country: US
# City: isla mujeres, Country: MX
# City: flying fish cove, Country: CX
# City: byram, Country: US
# City: potam, Country: MX
# City: bardai, Country: NG
# City: timmins, Country: CA
# City: calca, Country: PE
# City: port alfred, Country: ZA
# City: quixeramobim, Country: BR
# City: constantia, Country: RO
# City: fiambala, Country: AR
# City: fortaleza, Country: BR
# City: whakatane, Country: NZ
# City: plant city, Country: US
# City: buta, Country: CD
# City: kill devil hills, Country: US
# City: nagqu, Country: CN
# City: sena madureira, Country: BR
# City: coro, Country: VE
# City: vila velha, Country: BR
# City: malabar, Country: AU
# City: tolanaro, Country: MG
# City: alice springs, Country: AU
# City: puerto deseado, Country: AR
# City: bamboo flat, Country: IN
# City: ponta delgada, Country: PT
# City: grand-bassam, Country: CI
# City: sitka, Country: US
# City: dong ha, Country: VN
# City: utrik, Country: MH
# City: ar rutbah, Country: IQ
# City: jinchang, Country: CN
# City: sao felix do xingu, Country: BR
# City: paso de carrasco, Country: UY
# City: dunedin, Country: NZ
# City: east london, Country: ZA
# City: bereznik, Country: RU
# City: saudarkrokur, Country: IS
# City: tindouf, Country: DZ
# City: tura, Country: IN
# City: bilmak, Country: UA
# City: zolochiv, Country: UA
# City: lompoc, Country: US
# City: port moresby, Country: PG
# City: humberto de campos, Country: BR
# City: kangding, Country: CN
# City: oakdale, Country: US
# City: umluj, Country: SA
# City: licheng, Country: CN
# City: enshi, Country: CN
# City: fujin, Country: CN
# City: sakaiminato, Country: JP
# City: vilyuchinsk, Country: RU
# City: barkot, Country: IN
# City: khorramabad, Country: IR
# City: aitape, Country: PG
# City: cold lake, Country: CA
# City: mozarlandia, Country: BR
# City: kyzylorda, Country: KZ
# City: rethymno, Country: GR
# City: st ives, Country: GB
# City: bondo, Country: CD
# City: bathurst, Country: AU
# City: hammerfest, Country: NO
# City: sault ste. marie, Country: CA
# City: arica, Country: CL
# City: powell, Country: US
# City: ambasamudram, Country: IN
# City: huicheng, Country: CN
# City: rio grande, Country: BR
# City: grand baie, Country: MU
# City: kota kinabalu, Country: MY
# City: yoko, Country: CM
# City: villamontes, Country: BO
# City: greenville, Country: US
# City: makokou, Country: GA
# City: nikolayevsk-on-amure, Country: RU
# City: port saint john's, Country: ZA
# City: remire-montjoly, Country: GF
# City: ilhabela, Country: BR
# City: pokaran, Country: IN
# City: ca mau, Country: VN
# City: goundi, Country: TD
# City: necochea, Country: AR
# City: palikir - national government center, Country: FM
# City: orange cove, Country: US
# City: kayyerkan, Country: RU
# City: maturin, Country: VE
# City: castillos, Country: UY
# City: enid, Country: US
# City: gwadar, Country: PK
# City: san luis, Country: AR
# City: limburg an der lahn, Country: DE
# City: fort wellington, Country: GY
# City: labytnangi, Country: RU
# City: chemax, Country: MX
# City: sinabang, Country: ID
# City: antofagasta, Country: CL
# City: ahuacatlan, Country: MX
# City: pizarro, Country: CO
# City: buala, Country: SB
# City: afaahiti, Country: PF
# City: broken hill, Country: AU
# City: paracale, Country: PH
# City: ankang, Country: CN
# City: novopskov, Country: UA
# City: atchison, Country: US
# City: gamba, Country: GA
# City: jiuquan, Country: CN
# City: 'ain benian, Country: DZ
# City: mar del plata, Country: AR
# City: balcarce, Country: AR
# City: nurota, Country: UZ
# City: san antonio de pale, Country: GQ
# City: tumayr, Country: SA
# City: acarau, Country: BR
# City: la passe, Country: FR
# City: kikwit, Country: CD
# City: vilyuysk, Country: RU
# City: haiku-pauwela, Country: US
# City: egilsstadir, Country: IS
# City: baardheere, Country: SO
# City: tromso, Country: NO
# City: gbarnga, Country: LR
# City: vyazemskiy, Country: RU
# City: yongchuan, Country: CN
# City: calvinia, Country: ZA
# City: chernyshevsk, Country: RU
# City: taveta, Country: KE
# City: bandon, Country: IE
# City: hancheng, Country: CN
# City: sao jose da coroa grande, Country: BR
# City: mili, Country: MH
# City: fortuna, Country: US
# City: okha, Country: RU
# City: ziro, Country: IN
# City: al hamul, Country: EG
# City: mahina, Country: PF
# City: sakakah, Country: SA
# City: gorgan, Country: IR
# City: bangassou, Country: CF
# {'margaret river': 'AU', 'punta arenas': 'CL', 'port-aux-francais': 'TF', 'puerto natales': 'CL', 'adamstown': 'PN', 'arauco': 'CL', 'puerto ayora': 'EC', 'dalandzadgad': 'MN', 'isafjordur': 'IS', 'hermanus': 'ZA', 'qaqortoq': 'GL', 'gierloz': 'PL', 'ribeira grande': 'PT', 'lhasa': 'CN', 'mont-dore': 'NC', 'kingman': 'US', 'yuzhno-kurilsk': 'RU', 'new norfolk': 'AU', 'namtsy': 'RU', 'invercargill': 'NZ', 'edinburgh of the seven seas': 'SH', 'wenchang': 'CN', 'antsiranana': 'MG', 'talcahuano': 'CL', 'tazacorte': 'ES', 'beberibe': 'BR', 'albany': 'US', 'kirakira': 'SB', 'sola': 'VU', 'winkler': 'CA', 'waitangi': 'NZ', 'las khorey': 'SO', 'sittwe': 'MM', 'blackmans bay': 'AU', 'estebania': 'DO', 'grytviken': 'GS', "st. john's": 'CA', 'tarawa': 'KI', 'yellowknife': 'CA', 'kirensk': 'RU', 'turkeli': 'TR', 'punta del este': 'UY', 'georgetown': 'MY', 'labrador city': 'CA', 'silvis': 'US', 'plettenberg bay': 'ZA', 'ancud': 'CL', 'vadso': 'NO', 'college': 'US', 'whitehorse': 'CA', 'longyearbyen': 'SJ', 'kenai': 'US', 'kristiansund': 'NO', 'igarka': 'RU', 'badger': 'US', 'san julian': 'MX', 'kodiak': 'US', 'iqaluit': 'CA', 'avarua': 'CK', 'port augusta': 'AU', 'lazaro cardenas': 'MX', 'guatrache': 'AR', 'talnakh': 'RU', 'tchintabaraden': 'NE', 'altai': 'MN', 'selfoss': 'IS', 'saipan': 'MP', 'okondja': 'GA', 'nemuro': 'JP', 'thompson': 'CA', 'katsuura': 'JP', 'ushuaia': 'AR', 'casablanca': 'MA', 'rumoi': 'JP', 'tarakan': 'ID', 'san patricio': 'US', 'axim': 'GH', 'praia da vitoria': 'PT', 'lebu': 'CL', 'atafu village': 'TK', 'klyuchi': 'RU', 'weno': 'FM', 'minas de matahambre': 'CU', 'fort bragg': 'US', 'lata': 'PT', 'majuro': 'MH', 'port mathurin': 'MU', 'nantucket': 'US', 'sant lluis': 'ES', 'hilo': 'US', 'margate': 'GB', 'richards bay': 'ZA', 'vorgashor': 'RU', 'hirara': 'JP', 'iskateley': 'RU', 'conde-sur-noireau': 'FR', 'boguchany': 'RU', 'bilibino': 'RU', 'swakopmund': 'NA', 'karratha': 'AU', 'olenino': 'RU', 'kailua-kona': 'US', 'alofi': 'NU', 'bethel': 'US', 'urdinarrain': 'AR', 'luderitz': 'NA', 'chonchi': 'CL', 'bredasdorp': 'ZA', 'newman': 'US', 'saldanha': 'ZA', 'tocopilla': 'CL', 'anadyr': 'RU', 'kashgar': 'CN', 'salalah': 'OM', 'enewetak': 'MH', 'torit': 'SS', 'port douglas': 'AU', 'hithadhoo': 'MV', 'palmer': 'US', 'olonkinbyen': 'SJ', 'rumphi': 'MW', 'inarajan village': 'GU', 'mount isa': 'AU', "l'govskiy": 'RU', 'uturoa': 'PF', 'betio village': 'KI', 'mizdah': 'LY', 'williams lake': 'CA', 'ilulissat': 'GL', 'alotau': 'PG', 'west island': 'CC', 'touros': 'BR', 'madagali': 'NG', 'george town': 'MY', 'ayorou': 'NE', 'ta`u': 'AS', 'papatowai': 'NZ', 'stanley': 'GB', 'tual': 'ID', 'usinsk': 'RU', 'hadibu': 'YE', 'yokadouma': 'CM', 'watsa': 'CD', 'san-pedro': 'CI', 'vila franca do campo': 'PT', 'happy valley-goose bay': 'CA', 'chulym': 'RU', 'wailua homesteads': 'US', 'kilindoni': 'TZ', 'al kharj': 'SA', 'griffith': 'US', 'gadzhiyevo': 'RU', 'konosha': 'RU', 'manta': 'EC', 'gorelki': 'RU', 'macas': 'EC', 'aasiaat': 'GL', 'portland': 'US', 'hasaki': 'JP', 'garibaldi': 'BR', 'teknaf': 'BD', 'thinadhoo': 'MV', 'minas de marcona': 'PE', 'tazovsky': 'RU', 'laredo': 'US', 'iwanai': 'JP', 'nyurba': 'RU', 'sancti spiritus': 'CU', 'qamdo': 'CN', 'lianran': 'CN', 'reynosa': 'MX', 'wynyard': 'AU', 'kzyltu': 'KZ', 'petropavlovsk-kamchatsky': 'RU', 'dudinka': 'RU', 'isangel': 'VU', 'merizo village': 'GU', 'antsohihy': 'MG', 'oyem': 'GA', 'okhotsk': 'RU', 'luganville': 'VU', 'holualoa': 'US', 'port elizabeth': 'ZA', 'udachny': 'RU', 'lucapa': 'AO', 'intendente alvear': 'AR', 'at taj': 'LY', 'preobrazheniye': 'RU', 'broome': 'US', 'saint-philippe': 'RE', 'ambanja': 'MG', 'bagua grande': 'PE', 'tiksi': 'RU', 'lahan': 'NP', 'nizhneudinsk': 'RU', 'malaryta': 'BY', 'sao lourenco do sul': 'BR', 'fort st. john': 'CA', 'yatou': 'CN', 'wright': 'US', 'aguadilla': 'PR', 'chicoana': 'AR', 'pointe-noire': 'CG', 'port lincoln': 'AU', 'pontivy': 'FR', 'kone': 'NC', 'korla': 'CN', 'igurubi': 'TZ', 'alaghsas': 'NE', 'hobyo': 'SO', 'sisimiut': 'GL', 'susuman ...

# %%
print(f"Total cities: {len(city_country_map)}")
# Out:
# Total cities: 427

# %%
data = list(city_country_map.items())

# Create the DataFrame
df = pd.DataFrame(data, columns=['City', 'Country'])

# Save the DataFrame to a CSV file
df.to_csv('Resources/city_country_map.csv', index=False, encoding='utf-8')

# %%
# Get all the unique countries from the city-country map
unique_countries = set(city_country_map.values())

# Print the count and the list of unique countries
print(f"Total unique countries: {len(unique_countries)}")
print(unique_countries)
# Out:
# Total unique countries: 115
# {'GR', 'KI', 'MX', 'PN', 'OM', 'NZ', 'TK', 'RE', 'PG', 'RU', 'TD', 'ZA', 'KE', 'TM', 'EC', 'AO', 'RO', 'GY', 'CC', 'GS', 'PR', 'MU', 'CG', 'GH', 'MM', 'SA', 'MP', 'SB', 'US', 'CX', 'IN', 'CF', 'CU', 'GQ', 'ID', 'PL', 'GA', 'CD', 'MG', 'FM', 'DK', 'JP', 'WF', 'ES', 'UY', 'DZ', 'PE', 'CL', 'CA', 'NU', 'GL', 'LY', 'VU', 'MH', 'PF', 'CV', 'NG', 'IE', 'BY', 'MN', 'SJ', 'LB', 'NP', 'TF', 'GB', 'UZ', 'MY', 'MW', 'AU', 'GU', 'VE', 'CO', 'SO', 'CM', 'VN', 'SH', 'TO', 'BD', 'ET', 'AS', 'NE', 'PK', 'NA', 'GF', 'BO', 'KZ', 'IQ', 'PW', 'MV', 'PH', 'PT', 'BR', 'SS', 'CK', 'LR', 'TR', 'IR', 'CN', 'KR', 'TG', 'FR', 'UA', 'MA', 'NO', 'IS', 'EG', 'FO', 'AR', 'TZ', 'CI', 'NC', 'DO', 'SE', 'YE', 'DE'}

# %%
import pycountry

# WHO API: Get all available countries and their alpha-3 codes
who_url = "https://ghoapi.azureedge.net/api/DIMENSION/COUNTRY/DimensionValues"
who_response = requests.get(who_url).json()

# Convert WHO countries from alpha-3 to alpha-2 codes to be matched withOpenWeather Country Code
who_countries_alpha2 = {}

for entry in who_response['value']:
    alpha_3 = entry['Code']
    country_name = entry['Title']

    # Convert alpha-3 to alpha-2 code using pycountry
    try:
        alpha_2 = pycountry.countries.get(alpha_3=alpha_3).alpha_2
        who_countries_alpha2[alpha_2] = country_name
    except AttributeError:
        print(f"Skipping {alpha_3} - No matching alpha-2 code found.")

print(f"WHO Countries (alpha-2): {who_countries_alpha2}")

who_country_codes = who_countries_alpha2.keys()
print(f"WHO Country Codes: {list(who_country_codes)}")
# Out:
# Skipping CHI - No matching alpha-2 code found.
# Skipping ME1 - No matching alpha-2 code found.
# Skipping SDN736 - No matching alpha-2 code found.
# Skipping XKX - No matching alpha-2 code found.
# WHO Countries (alpha-2): {'AW': 'Aruba', 'AF': 'Afghanistan', 'AO': 'Angola', 'AI': 'Anguilla', 'AL': 'Albania', 'AD': 'Andorra', 'AE': 'United Arab Emirates', 'AR': 'Argentina', 'AM': 'Armenia', 'AS': 'American Samoa', 'AG': 'Antigua and Barbuda', 'AU': 'Australia', 'AT': 'Austria', 'AZ': 'Azerbaijan', 'BI': 'Burundi', 'BE': 'Belgium', 'BJ': 'Benin', 'BQ': 'Bonaire, Saint Eustatius and Saba', 'BF': 'Burkina Faso', 'BD': 'Bangladesh', 'BG': 'Bulgaria', 'BH': 'Bahrain', 'BS': 'Bahamas', 'BA': 'Bosnia and Herzegovina', 'BY': 'Belarus', 'BZ': 'Belize', 'BM': 'Bermuda', 'BO': 'Bolivia (Plurinational State of)', 'BR': 'Brazil', 'BB': 'Barbados', 'BN': 'Brunei Darussalam', 'BT': 'Bhutan', 'BW': 'Botswana', 'CF': 'Central African Republic', 'CA': 'Canada', 'CH': 'Switzerland', 'CL': 'Chile', 'CN': 'China', 'CI': "Cote d'Ivoire", 'CM': 'Cameroon', 'CD': 'Democratic Republic of the Congo', 'CG': 'Congo', 'CK': 'Cook Islands', 'CO': 'Colombia', 'KM': 'Comoros', 'CV': 'Cabo Verde', 'CR': 'Costa Rica', 'CU': 'Cuba', 'CW': 'Curaçao', 'KY': 'Cayman Islands', 'CY': 'Cyprus', 'CZ': 'Czechia', 'DE': 'Germany', 'DJ': 'Djibouti', 'DM': 'Dominica', 'DK': 'Denmark', 'DO': 'Dominican Republic', 'DZ': 'Algeria', 'EC': 'Ecuador', 'EG': 'Egypt', 'ER': 'Eritrea', 'ES': 'Spain', 'EE': 'Estonia', 'ET': 'Ethiopia', 'FI': 'Finland', 'FJ': 'Fiji', 'FK': 'Falkland Islands (Malvinas)', 'FR': 'France', 'FO': 'Faroe Islands', 'FM': 'Micronesia (Federated States of)', 'GA': 'Gabon', 'GB': 'United Kingdom of Great Britain and Northern Ireland', 'GE': 'Georgia', 'GH': 'Ghana', 'GI': 'Gibraltar', 'GN': 'Guinea', 'GP': 'Guadeloupe', 'GM': 'Gambia', 'GW': 'Guinea-Bissau', 'GQ': 'Equatorial Guinea', 'GR': 'Greece', 'GD': 'Grenada', 'GL': 'Greenland', 'GT': 'Guatemala', 'GF': 'French Guiana', 'GU': 'Guam', 'GY': 'Guyana', 'HK': 'China, Hong Kong Special Administrative Region', 'HN': 'Honduras', 'HR': 'Croatia', 'HT': 'Haiti', 'HU': 'Hungary', 'ID': 'Indonesia', 'IM': 'Isle of Man', 'IN': 'India', 'IE': 'Ireland', 'IR': 'Iran (Islamic Republic of)', 'IQ': 'Iraq', 'IS': 'Iceland', 'IL': 'Israel', 'IT': 'Italy', 'JM': 'Jamaica', 'JO': 'Jordan', 'JP': 'Japan', 'KZ': 'Kazakhstan', 'KE': 'Kenya', 'KG': 'Kyrgyzstan', 'KH': 'Cambodia', 'KI': 'Kiribati', 'KN': 'Saint Kitts and Nevis', 'KR': 'Republic of Korea', 'KW': 'Kuwait', 'LA': "Lao People's Democratic Republic", 'LB': 'Lebanon', 'LR': 'Liberia', 'LY': 'Libya', 'LC': 'Saint Lucia', 'LI': 'Liechtenstein', 'LK': 'Sri Lanka', 'LS': 'Lesotho', 'LT': 'Lithuania', 'LU': 'Luxembourg', 'LV': 'Latvia', 'MO': 'China, Macao Special Administrative Region', 'MA': 'Morocco', 'MC': 'Monaco', 'MD': 'Republic of Moldova', 'MG': 'Madagascar', 'MV': 'Maldives', 'MX': 'Mexico', 'MH': 'Marshall Islands', 'MK': 'North Macedonia', 'ML': 'Mali', 'MT': 'Malta', 'MM': 'Myanmar', 'ME': 'Montenegro', 'MN': 'Mongolia', 'MP': 'Northern Mariana Islands', 'MZ': 'Mozambique', 'MR': 'Mauritania', 'MS': 'Montserrat', 'MQ': 'Martinique', 'MU': 'Mauritius', 'MW': 'Malawi', 'MY': 'Malaysia', 'YT': 'Mayotte', 'NA': 'Namibia', 'NC': 'New Caledonia', 'NE': 'Niger', 'NG': 'Nigeria', 'NI': 'Nicaragua', 'NU': 'Niue', 'NL': 'Netherlands (Kingdom of the)', 'NO': 'Norway', 'NP': 'Nepal', 'NR': 'Nauru', 'NZ': 'New Zealand', 'OM': 'Oman', 'PK': 'Pakistan', 'PA': 'Panama', 'PE': 'Peru', 'PH': 'Philippines', 'PW': 'Palau', 'PG': 'Papua New Guinea', 'PL': 'Poland', 'PR': 'Puerto Rico', 'KP': "Democratic People's Republic of Korea", 'PT': 'Portugal', 'PY': 'Paraguay', 'PS': 'occupied Palestinian territory, including east Jerusalem', 'PF': 'French Polynesia', 'QA': 'Qatar', 'RE': 'Reunion', 'RO': 'Romania', 'RU': 'Russian Federation', 'RW': 'Rwanda', 'SA': 'Saudi Arabia', 'SD': 'Sudan', 'SN': 'Senegal', 'SG': 'Singapore', 'SH': 'Saint Helena', 'SB': 'Solomon Islands', 'SL': 'Sierra Leone', 'SV': 'El Salvador', 'SM': 'San Marino', 'SO': 'Somalia', 'PM': 'Saint Pierre and Miquelon', 'RS': 'Serbia', 'SS': 'South Sudan', 'ST': 'Sao Tome and Principe', 'SR': 'Suriname', 'SK': 'Slo ...
# WHO Country Codes: ['AW', 'AF', 'AO', 'AI', 'AL', 'AD', 'AE', 'AR', 'AM', 'AS', 'AG', 'AU', 'AT', 'AZ', 'BI', 'BE', 'BJ', 'BQ', 'BF', 'BD', 'BG', 'BH', 'BS', 'BA', 'BY', 'BZ', 'BM', 'BO', 'BR', 'BB', 'BN', 'BT', 'BW', 'CF', 'CA', 'CH', 'CL', 'CN', 'CI', 'CM', 'CD', 'CG', 'CK', 'CO', 'KM', 'CV', 'CR', 'CU', 'CW', 'KY', 'CY', 'CZ', 'DE', 'DJ', 'DM', 'DK', 'DO', 'DZ', 'EC', 'EG', 'ER', 'ES', 'EE', 'ET', 'FI', 'FJ', 'FK', 'FR', 'FO', 'FM', 'GA', 'GB', 'GE', 'GH', 'GI', 'GN', 'GP', 'GM', 'GW', 'GQ', 'GR', 'GD', 'GL', 'GT', 'GF', 'GU', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IM', 'IN', 'IE', 'IR', 'IQ', 'IS', 'IL', 'IT', 'JM', 'JO', 'JP', 'KZ', 'KE', 'KG', 'KH', 'KI', 'KN', 'KR', 'KW', 'LA', 'LB', 'LR', 'LY', 'LC', 'LI', 'LK', 'LS', 'LT', 'LU', 'LV', 'MO', 'MA', 'MC', 'MD', 'MG', 'MV', 'MX', 'MH', 'MK', 'ML', 'MT', 'MM', 'ME', 'MN', 'MP', 'MZ', 'MR', 'MS', 'MQ', 'MU', 'MW', 'MY', 'YT', 'NA', 'NC', 'NE', 'NG', 'NI', 'NU', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PK', 'PA', 'PE', 'PH', 'PW', 'PG', 'PL', 'PR', 'KP', 'PT', 'PY', 'PS', 'PF', 'QA', 'RE', 'RO', 'RU', 'RW', 'SA', 'SD', 'SN', 'SG', 'SH', 'SB', 'SL', 'SV', 'SM', 'SO', 'PM', 'RS', 'SS', 'ST', 'SR', 'SK', 'SI', 'SE', 'SZ', 'SX', 'SC', 'SY', 'TC', 'TD', 'TG', 'TH', 'TJ', 'TK', 'TM', 'TL', 'TO', 'TT', 'TN', 'TR', 'TV', 'TZ', 'UG', 'UA', 'UY', 'US', 'UZ', 'VC', 'VE', 'VG', 'VI', 'VN', 'VU', 'WF', 'WS', 'YE', 'ZA', 'ZM', 'ZW']

# %%
# Filter cities where the country code exists in the WHO data
filtered_cities = {
    city: code for city, code in city_country_map.items() if code in who_country_codes
}

print(f"Cities with matching WHO data: {len(filtered_cities)}")
print(filtered_cities)
# Out:
# Cities with matching WHO data: 420
# {'margaret river': 'AU', 'punta arenas': 'CL', 'puerto natales': 'CL', 'arauco': 'CL', 'puerto ayora': 'EC', 'dalandzadgad': 'MN', 'isafjordur': 'IS', 'hermanus': 'ZA', 'qaqortoq': 'GL', 'gierloz': 'PL', 'ribeira grande': 'PT', 'lhasa': 'CN', 'mont-dore': 'NC', 'kingman': 'US', 'yuzhno-kurilsk': 'RU', 'new norfolk': 'AU', 'namtsy': 'RU', 'invercargill': 'NZ', 'edinburgh of the seven seas': 'SH', 'wenchang': 'CN', 'antsiranana': 'MG', 'talcahuano': 'CL', 'tazacorte': 'ES', 'beberibe': 'BR', 'albany': 'US', 'kirakira': 'SB', 'sola': 'VU', 'winkler': 'CA', 'waitangi': 'NZ', 'las khorey': 'SO', 'sittwe': 'MM', 'blackmans bay': 'AU', 'estebania': 'DO', "st. john's": 'CA', 'tarawa': 'KI', 'yellowknife': 'CA', 'kirensk': 'RU', 'turkeli': 'TR', 'punta del este': 'UY', 'georgetown': 'MY', 'labrador city': 'CA', 'silvis': 'US', 'plettenberg bay': 'ZA', 'ancud': 'CL', 'vadso': 'NO', 'college': 'US', 'whitehorse': 'CA', 'kenai': 'US', 'kristiansund': 'NO', 'igarka': 'RU', 'badger': 'US', 'san julian': 'MX', 'kodiak': 'US', 'iqaluit': 'CA', 'avarua': 'CK', 'port augusta': 'AU', 'lazaro cardenas': 'MX', 'guatrache': 'AR', 'talnakh': 'RU', 'tchintabaraden': 'NE', 'altai': 'MN', 'selfoss': 'IS', 'saipan': 'MP', 'okondja': 'GA', 'nemuro': 'JP', 'thompson': 'CA', 'katsuura': 'JP', 'ushuaia': 'AR', 'casablanca': 'MA', 'rumoi': 'JP', 'tarakan': 'ID', 'san patricio': 'US', 'axim': 'GH', 'praia da vitoria': 'PT', 'lebu': 'CL', 'atafu village': 'TK', 'klyuchi': 'RU', 'weno': 'FM', 'minas de matahambre': 'CU', 'fort bragg': 'US', 'lata': 'PT', 'majuro': 'MH', 'port mathurin': 'MU', 'nantucket': 'US', 'sant lluis': 'ES', 'hilo': 'US', 'margate': 'GB', 'richards bay': 'ZA', 'vorgashor': 'RU', 'hirara': 'JP', 'iskateley': 'RU', 'conde-sur-noireau': 'FR', 'boguchany': 'RU', 'bilibino': 'RU', 'swakopmund': 'NA', 'karratha': 'AU', 'olenino': 'RU', 'kailua-kona': 'US', 'alofi': 'NU', 'bethel': 'US', 'urdinarrain': 'AR', 'luderitz': 'NA', 'chonchi': 'CL', 'bredasdorp': 'ZA', 'newman': 'US', 'saldanha': 'ZA', 'tocopilla': 'CL', 'anadyr': 'RU', 'kashgar': 'CN', 'salalah': 'OM', 'enewetak': 'MH', 'torit': 'SS', 'port douglas': 'AU', 'hithadhoo': 'MV', 'palmer': 'US', 'rumphi': 'MW', 'inarajan village': 'GU', 'mount isa': 'AU', "l'govskiy": 'RU', 'uturoa': 'PF', 'betio village': 'KI', 'mizdah': 'LY', 'williams lake': 'CA', 'ilulissat': 'GL', 'alotau': 'PG', 'touros': 'BR', 'madagali': 'NG', 'george town': 'MY', 'ayorou': 'NE', 'ta`u': 'AS', 'papatowai': 'NZ', 'stanley': 'GB', 'tual': 'ID', 'usinsk': 'RU', 'hadibu': 'YE', 'yokadouma': 'CM', 'watsa': 'CD', 'san-pedro': 'CI', 'vila franca do campo': 'PT', 'happy valley-goose bay': 'CA', 'chulym': 'RU', 'wailua homesteads': 'US', 'kilindoni': 'TZ', 'al kharj': 'SA', 'griffith': 'US', 'gadzhiyevo': 'RU', 'konosha': 'RU', 'manta': 'EC', 'gorelki': 'RU', 'macas': 'EC', 'aasiaat': 'GL', 'portland': 'US', 'hasaki': 'JP', 'garibaldi': 'BR', 'teknaf': 'BD', 'thinadhoo': 'MV', 'minas de marcona': 'PE', 'tazovsky': 'RU', 'laredo': 'US', 'iwanai': 'JP', 'nyurba': 'RU', 'sancti spiritus': 'CU', 'qamdo': 'CN', 'lianran': 'CN', 'reynosa': 'MX', 'wynyard': 'AU', 'kzyltu': 'KZ', 'petropavlovsk-kamchatsky': 'RU', 'dudinka': 'RU', 'isangel': 'VU', 'merizo village': 'GU', 'antsohihy': 'MG', 'oyem': 'GA', 'okhotsk': 'RU', 'luganville': 'VU', 'holualoa': 'US', 'port elizabeth': 'ZA', 'udachny': 'RU', 'lucapa': 'AO', 'intendente alvear': 'AR', 'at taj': 'LY', 'preobrazheniye': 'RU', 'broome': 'US', 'saint-philippe': 'RE', 'ambanja': 'MG', 'bagua grande': 'PE', 'tiksi': 'RU', 'lahan': 'NP', 'nizhneudinsk': 'RU', 'malaryta': 'BY', 'sao lourenco do sul': 'BR', 'fort st. john': 'CA', 'yatou': 'CN', 'wright': 'US', 'aguadilla': 'PR', 'chicoana': 'AR', 'pointe-noire': 'CG', 'port lincoln': 'AU', 'pontivy': 'FR', 'kone': 'NC', 'korla': 'CN', 'igurubi': 'TZ', 'alaghsas': 'NE', 'hobyo': 'SO', 'sisimiut': 'GL', 'susuman': 'RU', 'jincheng': 'CN', 'cabo san lucas': 'MX', 'kijang': 'KR', 'dauphin': 'CA', 'plastun': 'RU', 'dondaicha': 'IN', 'ferkesse ...

# %%
# WHO API: Air pollution attributable DALYs
who_url = "https://ghoapi.azureedge.net/api/AIR_42"
response = requests.get(who_url)

# Check for valid response
if response.status_code == 200:
    data = response.json()['value']
    # Parse the data into a DataFrame
    who_data = [
        {
            'Country': entry['SpatialDim'],
            'Year': entry['TimeDim'],
            'MortalityRate_per_100k': entry['NumericValue']
        }
        for entry in data
    ]
    
    df_who = pd.DataFrame(who_data)
    print(df_who.head())
    
    df_who.to_csv('Resources/who_air_pollution_dalys.csv', index=False)
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
#   Country  Year  MortalityRate_per_100k
# 0     CIV  2015                  40.103
# 1     SOM  2011                  53.318
# 2     GRD  2012                   0.567
# 3     BRN  2015                   1.440
# 4     HND  2016                  32.081

# %%
# Function to convert ISO-3 to ISO-2
def iso3_to_iso2(iso3_code):
    try:
        return pycountry.countries.get(alpha_3=iso3_code).alpha_2
    except AttributeError:
        return None  

df_who = pd.read_csv('Resources/who_air_pollution_dalys.csv')

# Convert WHO's ISO-3 codes to ISO-2
df_who['Country_ISO2'] = df_who['Country'].apply(iso3_to_iso2)

df_who_clean = df_who.dropna(subset=['Country_ISO2'])

df_weather = pd.read_csv('Resources/city_country_map.csv')

merged_df = pd.merge(air_quality_df, df_who_clean, left_on='Country', right_on='Country_ISO2', how='inner')

print(merged_df.head())

merged_df.to_csv('Resources/merged_air_quality_health.csv', index=False)
# Out:
#              City Country_x  PM2.5   PM10   NO2     O3   SO2      CO  NH3  \
# 0  margaret river        AU   2.54  10.04  0.15  59.37  0.39  226.97  0.0
# 1  margaret river        AU   2.54  10.04  0.15  59.37  0.39  226.97  0.0
# 2  margaret river        AU   2.54  10.04  0.15  59.37  0.39  226.97  0.0
# 3  margaret river        AU   2.54  10.04  0.15  59.37  0.39  226.97  0.0
# 4  margaret river        AU   2.54  10.04  0.15  59.37  0.39  226.97  0.0
#
#   Country_y  Year  MortalityRate_per_100k Country_ISO2
# 0       AUS  2011                  10.110           AU
# 1       AUS  2012                   6.769           AU
# 2       AUS  2010                   1.823           AU
# 3       AUS  2019                   1.405           AU
# 4       AUS  2012                   0.430           AU

# %%
count = len(merged_df)
count
# Out:
# 70380

# %%
# Drop redundant columns (dropping 'Country_ISO2' and 'Country_y')
merged_df = merged_df.drop(['Country_ISO2', 'Country_y'], axis=1)

# Rename columns for clarity
merged_df = merged_df.rename(columns={'Country_x': 'Country'})

# %%
merged_df.to_csv('Resources/merged_air_quality_health.csv', index=False)

# %%
# Load the merged dataset
df = pd.read_csv('Resources/merged_air_quality_health.csv')

# Group by City and Country to calculate average values across all years
grouped_df = df.groupby(['City', 'Country'], as_index=False).agg({
    'PM2.5': 'mean',
    'PM10': 'mean',
    'NO2': 'mean',
    'O3': 'mean',
    'SO2': 'mean',
    'CO': 'mean',
    'NH3': 'mean',
    'MortalityRate_per_100k': 'mean'
})

grouped_df = grouped_df.round(1)

grouped_df.to_csv('Resources/average_air_quality_health.csv', index=False)

print(grouped_df.head(10))
# Out:
#             City Country  PM2.5   PM10   NO2    O3  SO2     CO  NH3  \
# 0    'ain benian      DZ    1.4    4.5   1.2  79.4  0.5  201.9  0.1
# 1       abashiri      JP    1.8    3.5   1.0  90.1  0.4  217.0  0.8
# 2         acarau      BR    2.3   10.4   0.2  52.2  0.1  347.1  0.1
# 3     ahuacatlan      MX    9.1   11.0  15.8  46.5  0.7  313.8  3.0
# 4         aitape      PG    1.0    1.2   0.1   7.2  0.0  168.6  0.0
# 5       al hamul      EG   18.4   35.7   1.8  83.0  1.6  208.6  5.8
# 6       al kharj      SA   33.2   80.8   5.8  39.7  3.8  233.6  1.1
# 7       alaghsas      NE   62.9  251.9   0.0  50.8  0.0  191.9  0.0
# 8         albany      US    2.6    3.4  16.1  26.1  0.1  270.4  0.3
# 9  alice springs      AU   16.4   70.6   0.1  45.4  0.0  283.7  0.2
#
#    MortalityRate_per_100k
# 0                    16.6
# 1                     5.1
# 2                     9.6
# 3                    10.7
# 4                    12.4
# 5                    36.2
# 6                    33.5
# 7                    34.1
# 8                     5.7
# 9                     3.2
