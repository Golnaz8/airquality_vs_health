# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Generate random latitude and longitude
lats = np.random.uniform(-90, 90, size=1000)
lngs = np.random.uniform(-180, 180, size=1000)


cities = []

# Use citipy to determine the nearest city for each lat-lng combination
for lat, lng in zip(lats, lngs):
    city = citipy.nearest_city(lat, lng).city_name
    if city not in cities:
        cities.append(city)

print(f"Generated {len(cities)} unique cities.")
# Out:
# Generated 435 unique cities.

# %%
# Base URLs
weather_url = "http://api.openweathermap.org/data/2.5/weather"
air_quality_url = "http://api.openweathermap.org/data/2.5/air_pollution"

# Dictionary to store valid city data with coordinates
valid_cities = {}

for city in cities:
    try:
        # Fetch city coordinates using the weather endpoint
        query_url = f"{weather_url}?q={city}&appid={weather_api_key}"
        response = requests.get(query_url)

        if response.status_code != 200:
            print(f"City {city} not found (Status Code: {response.status_code}). Skipping...")
            continue

        # Parse JSON response for coordinates
        data = response.json()
        lat = data['coord']['lat']
        lon = data['coord']['lon']
        country = data['sys']['country']

        # Store in filtered_cities dictionary
        valid_cities[city] = {'city': city, 'lat': lat, 'lon': lon, 'country': country}

        print(f"Retrieved coordinates for {city}: ({lat}, {lon})")

    except KeyError as key_err:
        print(f"KeyError: {key_err} for {city}. Skipping...")
    except requests.exceptions.RequestException as req_err:
        print(f"Request error: {req_err} for {city}. Skipping...")

    # Pause to avoid rate limiting
    time.sleep(1)

print(f"Total valid cities with coordinates: {len(valid_cities)}")
# Out:
# Retrieved coordinates for port-aux-francais: (-49.35, 70.2167)
# Retrieved coordinates for ribeira grande: (38.5167, -28.7)
# Retrieved coordinates for korenovsk: (45.4686, 39.4519)
# Retrieved coordinates for srandakan: (-7.9386, 110.2506)
# City 'ohonua not found (Status Code: 404). Skipping...
# Retrieved coordinates for rio grande: (-32.035, -52.0986)
# Retrieved coordinates for al muwayh: (22.4333, 41.7583)
# City taiohae not found (Status Code: 404). Skipping...
# Retrieved coordinates for thompson: (55.7435, -97.8558)
# Retrieved coordinates for midvagur: (62.0511, -7.1939)
# Retrieved coordinates for grytviken: (-54.2811, -36.5092)
# Retrieved coordinates for aleksandrovskoye: (44.7142, 43.0008)
# Retrieved coordinates for petropavlivka: (48.4564, 36.4367)
# Retrieved coordinates for adamstown: (-25.066, -130.1015)
# Retrieved coordinates for haiku-pauwela: (20.9219, -156.3051)
# Retrieved coordinates for port elizabeth: (-33.918, 25.5701)
# Retrieved coordinates for christchurch: (-43.5333, 172.6333)
# Retrieved coordinates for ushuaia: (-54.8, -68.3)
# Retrieved coordinates for talnakh: (69.4865, 88.3972)
# Retrieved coordinates for dudinka: (69.4058, 86.1778)
# Retrieved coordinates for bel ombre: (-4.6167, 55.4167)
# Retrieved coordinates for tongchuanshi: (35.0806, 109.0897)
# Retrieved coordinates for blackmans bay: (-43.0167, 147.3167)
# Retrieved coordinates for alofi: (-19.0595, -169.9187)
# Retrieved coordinates for kruisfontein: (-34.0033, 24.7314)
# Retrieved coordinates for aksu: (41.1231, 80.2644)
# Retrieved coordinates for bredasdorp: (-34.5322, 20.0403)
# Retrieved coordinates for longyearbyen: (78.2186, 15.6401)
# Retrieved coordinates for mbekenyera: (-10, 38.9833)
# Retrieved coordinates for ghadamis: (30.1337, 9.5007)
# Retrieved coordinates for ise: (34.4833, 136.7)
# Retrieved coordinates for iqaluit: (63.7506, -68.5145)
# Retrieved coordinates for okha: (53.5739, 142.9478)
# Retrieved coordinates for edinburgh of the seven seas: (-37.0676, -12.3116)
# Retrieved coordinates for afaahiti: (-17.75, -149.2833)
# Retrieved coordinates for aasiaat: (68.7098, -52.8699)
# Retrieved coordinates for chibougamau: (49.9168, -74.3659)
# Retrieved coordinates for mandalgovi: (45.7625, 106.2708)
# Retrieved coordinates for kailua-kona: (19.6406, -155.9956)
# Retrieved coordinates for bethel: (41.3712, -73.414)
# Retrieved coordinates for qaqortoq: (60.7167, -46.0333)
# Retrieved coordinates for badger: (64.8, -147.5333)
# Retrieved coordinates for edd: (13.9297, 41.6925)
# Retrieved coordinates for iskateley: (67.6803, 53.1512)
# Retrieved coordinates for sao vicente: (-23.9631, -46.3919)
# Retrieved coordinates for olyokminsk: (60.3736, 120.4264)
# Retrieved coordinates for geraldton: (-28.7667, 114.6)
# Retrieved coordinates for petropavlovsk-kamchatsky: (53.0452, 158.6483)
# Retrieved coordinates for tiksi: (71.6872, 128.8694)
# Retrieved coordinates for puerto natales: (-51.7236, -72.4875)
# Retrieved coordinates for la passe: (45.5549, -0.8967)
# Retrieved coordinates for west island: (-12.1568, 96.8225)
# Retrieved coordinates for ad dilam: (23.9915, 47.1627)
# Retrieved coordinates for fort st. john: (56.2499, -120.8529)
# Retrieved coordinates for waitangi: (-43.9535, -176.5597)
# Retrieved coordinates for coquimbo: (-29.9533, -71.3436)
# City devinuwara not found (Status Code: 404). Skipping...
# Retrieved coordinates for cidreira: (-30.1811, -50.2056)
# Retrieved coordinates for bilibino: (68.0546, 166.4372)
# Retrieved coordinates for egilsstadir: (65.2653, -14.3948)
# Retrieved coordinates for pamanukan: (-6.2842, 107.8106)
# Retrieved coordinates for san patricio: (28.017, -97.5169)
# Retrieved coordinates for saipan: (15.1355, 145.701)
# Retrieved coordinates for buchanan: (5.8808, -10.0467)
# Retrieved coordinates for kargopol': (61.5071, 38.9456)
# Retrieved coordinates for ciudad tula: (23, -99.7167)
# Retrieved coordinates for levanger: (63.7464, 11.2996)
# Retrieved coordinates for port lincoln: (-34.7333, 135.8667)
# Retrieved coordinates for papatowai: (-46.5619, 169.4708)
# Retrieved coordinates for la plata: (-34.9215, -57.9545)
# Retrieved coordinates for ak'ordat: (15.5486, 37.8867)
# Retrieved coordinates for nadi: (-17.8, 177.4167)
# Retrieved coordinates for east london: (-33.0153, 27.9116)
# Retrieved coordinates for siverek: (37.755, 39.3167)
# Retrieved coordinates for copala: (16.65, -98.9833)
# Retrieved coordinates for college: (64.8569, -147.8028)
# Retrieved coordinates for alzamay: (55.5562, 98.6644)
# Retrieved coordinates for fortuna: (40.5982, -124.1573)
# Retrieved coordinates for keflavik: (64.0049, -22.5624)
# Retrieved coordinates for shache: (38.4167, 77.2406)
# Retrieved coordinates for raduzhny: (62.0961, 77.475)
# Retrieved coordinates for utrik: (11.2278, 169.8474)
# Retrieved coordinates for harstad: (68.799, 16.5293)
# Retrieved coordinates for wailua homesteads: (22.0669, -159.378)
# Retrieved coordinates for albany: (42.6001, -73.9662)
# Retrieved coordinates for turan: (16.0678, 108.2208)
# Retrieved coordinates for naze: (28.3667, 129.4833)
# Retrieved coordinates for punta arenas: (-53.15, -70.9167)
# Retrieved coordinates for uturoa: (-16.7333, -151.4333)
# City yagry not found (Status Code: 404). Skipping...
# Retrieved coordinates for jiayuguan: (39.8167, 98.3)
# Retrieved coordinates for port isabel: (26.0734, -97.2086)
# Retrieved coordinates for viedma: (-40.8135, -62.9967)
# Retrieved coordinates for margaret river: (-33.95, 115.0667)
# Retrieved coordinates for jamestown: (42.097, -79.2353)
# Retrieved coordinates for olonkinbyen: (70.9221, -8.7187)
# Retrieved coordinates for nakamura: (32.9833, 132.9333)
# Retrieved coordinates for atafu village: (-8.5421, -172.5159)
# Retrieved coordinates for mount isa: (-20.7333, 139.5)
# City fuvahmulah not found (Status Code: 404). Skipping...
# Retrieved coordinates for lorengau: (-2.0226, 147.2712)
# Retrieved coordinates for guerrero negro: (27.9769, -114.0611)
# Retrieved coordinates for flying fish cove: (-10.4217, 105.6791)
# Retrieved coordinates for ancud: (-41.8697, -73.8203)
# Retrieved coordinates for franklin: (39.9667, -83.0166)
# Retrieved coordinates for ulsteinvik: (62.3432, 5.8487)
# Retrieved coordinates for queenstown: (-31.8976, 26.8753)
# Retrieved coordinates for ochobo: (7.183, 7.9769)
# Retrieved coordinates for sannicandro garganico: (41.8384, 15.5654)
# Retrieved coordinates for hamilton: (39.1834, -84.5333)
# Retrieved coordinates for chadron: (42.8294, -102.9999)
# Retrieved coordinates for santa ana de yacuma: (-13.75, -65.4333)
# Retrieved coordinates for kone: (-21.0595, 164.8658)
# Retrieved coordinates for qarazhal: (48.0078, 70.7903)
# Retrieved coordinates for kayangel: (8.0823, 134.7173)
# Retrieved coordinates for acarau: (-2.8856, -40.12)
# Retrieved coordinates for lamu: (-2.2717, 40.902)
# Retrieved coordinates for gamay: (12.3854, 125.2979)
# Retrieved coordinates for i-n-salah: (27.1935, 2.4607)
# Retrieved coordinates for mahina: (-17.5065, -149.489)
# Retrieved coordinates for turar ryskulov: (42.5333, 70.3333)
# Retrieved coordinates for ondara: (38.8289, 0.0222)
# Retrieved coordinates for san antonio de pale: (-1.4014, 5.6325)
# Retrieved coordinates for stanley: (54.868, -1.6985)
# Retrieved coordinates for nagqu: (31.5, 92)
# Retrieved coordinates for celikhan: (38.0342, 38.2433)
# Retrieved coordinates for pyhajarvi: (67.0701, 27.2176)
# Retrieved coordinates for vadso: (70.0744, 29.7487)
# Retrieved coordinates for hawaiian paradise park: (19.5933, -154.9731)
# Retrieved coordinates for greymouth: (-42.4667, 171.2)
# Retrieved coordinates for bamboo flat: (11.7, 92.7167)
# Retrieved coordinates for katsuren-haebaru: (26.3369, 127.8719)
# Retrieved coordinates for akureyri: (65.6835, -18.0878)
# Retrieved coordinates for udachny: (66.4167, 112.4)
# Retrieved coordinates for daru: (-9.0763, 143.2092)
# Retrieved coordinates for kolondieba: (11.0882, -6.8926)
# Retrieved coordinates for yatou: (37.15, 122.3833)
# Retrieved coordinates for tofol: (5.3248, 163.0078)
# Retrieved coordinates for weno: (7.4515, 151.8468)
# Retrieved coordinates for constitucion: (-35.3333, -72.4167)
# Retrieved coordinates for hithadhoo: (-0.6, 73.0833)
# City savave village not found (Status Code: 404). Skipping...
# City zangguy not found (Status Code: 404). Skipping...
# Retrieved coordinates for itoman: (26.1247, 127.6694)
# Retrieved coordinates for hancheng: (32.5186, 112.3522)
# Retrieved coordinates for lebu: (-37.6167, -73.65)
# Retrieved coordinates for darwin: (-12.4611, 130.8418)
# Retrieved coordinates for beau vallon: (-20.4189, 57.6953)
# Retrieved coordinates for port hedland: (-20.3167, 118.5667)
# Retrieved coordinates for cabo san lucas: (22.8909, -109.9124)
# Retrieved coordinates for kavieng: (-2.5744, 150.7967)
# Retrieved coordinates for nova sintra: (14.8667, -24.7167)
# Retrieved coordinates for northam: (51.0333, -4.2167)
# Retrieved coordinates for smithers: (54.7804, -127.1743)
# Retrieved coordinates for pahrump: (36.2083, -115.9839)
# Retrieved coordinates for hermanus: (-34.4187, 19.2345)
# Retrieved coordinates for akjoujt: (19.6969, -14.4164)
# Retrieved coordinates for senillosa: (-39, -68.4167)
# Retrieved coordinates for iquique: (-20.2208, -70.1431)
# Retrieved coordinates for punta del este: (-34.9667, -54.95)
# Retrieved coordinates for schlusser: (40.2417, -77.1769)
# Retrieved coordinates for kudahuvadhoo: (2.6708, 72.8944)
# Retrieved coordinates for sim: (54.993, 57.6982)
# Retrieved coordinates for lihue: (21.9789, -159.3672)
# Retrieved coordinates for richfield: (44.8833, -93.283)
# Retrieved coordinates for tralee: (52.2704, -9.7026)
# Retrieved coordinates for wagga wagga: (-35.1167, 147.3667)
# Retrieved coordinates for st. john's: (47.5649, -52.7093)
# Retrieved coordinates for anadyr: (64.75, 177.4833)
# Retrieved coordinates for ararat: (39.8317, 44.7049)
# Retrieved coordinates for klyuchi: (52.2667, 79.1667)
# Retrieved coordinates for armidale: (-30.5167, 151.65)
# Retrieved coordinates for huilong: (31.8111, 121.655)
# Retrieved coordinates for broome: (42.2506, -75.833)
# Retrieved coordinates for adani: (6.7397, 7.0112)
# Retrieved coordinates for arraial do cabo: (-22.9661, -42.0278)
# Retrieved coordinates for labytnangi: (66.6572, 66.4183)
# Retrieved coordinates for moroni: (-11.7022, 43.2551)
# Retrieved coordinates for itacare: (-14.2775, -38.9967)
# Retrieved coordinates for chajari: (-30.7505, -57.9796)
# Retrieved coordinates for puerto ayora: (-0.7393, -90.3518)
# Retrieved coordinates for pisco: (-13.7, -76.2167)
# Retrieved coordinates for gereshk: (31.8209, 64.5701)
# Retrieved coordinates for bathsheba: (13.2167, -59.5167)
# Retrieved coordinates for nemuro: (43.3236, 145.575)
# Retrieved coordinates for lerwick: (60.1545, -1.1494)
# Retrieved coordinates for yashkul': (46.1711, 45.3435)
# Retrieved coordinates for loango: (-4.6719, 11.8312)
# Retrieved coordinates for gadzhiyevo: (69.2551, 33.3362)
# Retrieved coordinates for pestovo: (58.5938, 35.8024)
# Retrieved coordinates for santana: (-0.0583, -51.1817)
# Retrieved coordinates for tolanaro: (-25.0319, 46.9987)
# Retrieved coordinates for whangarei: (-35.7317, 174.3239)
# Retrieved coordinates for alotau: (-10.3069, 150.4462)
# Retrieved coordinates for mount gambier: (-37.8333, 140.7667)
# Retrieved coordinates for coahuayana de hidalgo: (18.7, -103.6583)
# City toga village not found (Status Code: 404). Skipping...
# Retrieved coordinates for xilin hot: (43.9667, 116.0333)
# Retrieved coordinates for puerto baquerizo moreno: (-0.9, -89.6)
# Retrieved coordinates for shingu: (33.7333, 135.9833)
# Retrieved coordinates for kodiak: (57.79, -152.4072)
# City gueoul not found (Status Code: 404). Skipping...
# Retrieved coordinates for nar'yan-mar: (67.6713, 53.087)
# Retrieved coordinates for as sulayyil: (20.4607, 45.5779)
# Retrieved coordinates for cabedelo: (-6.9811, -34.8339)
# Retrieved coordinates for khandyga: (62.6667, 135.6)
# Retrieved coordinates for reggane: (26.7158, 0.1714)
# Retrieved coordinates for sao jose da coroa grande: (-8.8978, -35.1478)
# Retrieved coordinates for tonghae: (37.5439, 129.1069)
# Retrieved coordinates for trinidad: (-14.8333, -64.9)
# Retrieved coordinates for newnham: (-41.3833, 147.1333)
# Retrieved coordinates for guli: (28.8833, 120.0333)
# Retrieved coordinates for karratha: (-20.7377, 116.8463)
# Retrieved coordinates for gueret: (46.1667, 1.8667)
# Retrieved coordinates for tupiza: (-21.45, -65.7167)
# Retrieved coordinates for dabakala: (8.3667, -4.4333)
# Retrieved coordinates for newman: (37.3138, -121.0208)
# Retrieved coordinates for hobyo: (5.3505, 48.5268)
# Retrieved coordinates for yoichi: (43.2039, 140.7703)
# Retrieved coordinates for malabar: (-33.9667, 151.25)
# Retrieved coordinates for breves: (-1.6822, -50.4803)
# Retrieved coordinates for qorovulbozor: (39.5006, 64.7936)
# Retrieved coordinates for port douglas: (-16.4833, 145.4667)
# Retrieved coordinates for isafjordur: (66.0755, -23.124)
# Retrieved coordinates for gaziantep: (37.0594, 37.3825)
# Retrieved coordinates for saudarkrokur: (65.7461, -19.6394)
# Retrieved coordinates for tazacorte: (28.629, -17.9293)
# Retrieved coordinates for arkhangel'sk: (64.5401, 40.5433)
# Retrieved coordinates for tera: (14.0078, 0.7531)
# Retrieved coordinates for kattivakkam: (13.2167, 80.3167)
# Retrieved coordinates for ilulissat: (69.2167, -51.1)
# Retrieved coordinates for saint-denis: (48.9167, 2.3333)
# Retrieved coordinates for semporna: (4.4818, 118.6112)
# Retrieved coordinates for invercargill: (-46.4, 168.35)
# Retrieved coordinates for whitehorse: (60.7161, -135.0538)
# Retrieved coordinates for quellon: (-43.1167, -73.6167)
# Retrieved coordinates for avarua: (-21.2078, -159.775)
# Retrieved coordinates for sinop: (41.7711, 34.8709)
# Retrieved coordinates for hasaki: (35.7333, 140.8333)
# Retrieved coordinates for puyang chengguanzhen: (35.7028, 115.0053)
# Retrieved coordinates for isla mujeres: (21.2311, -86.731)
# Retrieved coordinates for chapadinha: (-3.7417, -43.3603)
# Retrieved coordinates for kashgar: (39.4547, 75.9797)
# Retrieved coordinates for ta`u: (-14.2336, -169.5144)
# Retrieved coordinates for revda: (56.801, 59.9303)
# Retrieved coordinates for mulki: (13.1, 74.8)
# Retrieved coordinates for bam: (29.106, 58.357)
# Retrieved coordinates for conduaga: (8.862, 117.4893)
# Retrieved coordinates for fisterra: (42.9049, -9.2629)
# Retrieved coordinates for nantucket: (41.2835, -70.0995)
# City vingt cinq not found (Status Code: 404). Skipping...
# Retrieved coordinates for yellowknife: (62.456, -114.3525)
# Retrieved coordinates for lompoc: (34.6391, -120.4579)
# Retrieved coordinates for jiazi: (22.8779, 116.067)
# Retrieved coordinates for hinton: (53.4001, -117.5857)
# Retrieved coordinates for alice springs: (-23.7, 133.8833)
# Retrieved coordinates for newcastle west: (52.4492, -9.0611)
# Retrieved coordinates for constantia: (44.1833, 28.65)
# Retrieved coordinates for cockburn town: (21.4612, -71.1419)
# Retrieved coordinates for tamanrasset: (22.785, 5.5228)
# Retrieved coordinates for quesnel: (52.9999, -122.5029)
# Retrieved coordinates for brookings: (44.3114, -96.7984)
# Retrieved coordinates for champerico: (14.3, -91.9167)
# Retrieved coordinates for ola: (59.5833, 151.2833)
# Retrieved coordinates for amahai: (-3.3333, 128.9167)
# Retrieved coordinates for great bend: (38.3645, -98.7648)
# Retrieved coordinates for znomenka: (48.7128, 32.6647)
# Retrieved coordinates for luderitz: (-26.6481, 15.1594)
# Retrieved coordinates for la ligua: (-32.4524, -71.2311)
# Retrieved coordinates for valera: (9.3178, -70.6036)
# Retrieved coordinates for mejit: (10.2753, 170.8646)
# Retrieved coordinates for penhalonga: (-18.8911, 32.6978)
# Retrieved coordinates for kaseda-shirakame: (31.4167, 130.3167)
# Retrieved coordinates for ballina: (-28.8667, 153.5667)
# Retrieved coordinates for susuman: (62.7833, 148.1667)
# Retrieved coordinates for ariquemes: (-9.9133, -63.0408)
# Retrieved coordinates for kununurra: (-15.7667, 128.7333)
# Retrieved coordinates for magadi: (12.9667, 77.2333)
# Retrieved coordinates for el bolson: (-41.9667, -71.5167)
# Retrieved coordinates for nowa deba: (50.4297, 21.7508)
# Retrieved coordinates for kimbe: (-5.5502, 150.1429)
# Retrieved coordinates for caleta de carquin: (-11.0925, -77.6267)
# Retrieved coordinates for miracema do tocantins: (-9.5618, -48.3967)
# Retrieved coordinates for alo: (6.5486, 4.2686)
# Retrieved coordinates for novouzensk: (50.4592, 48.1431)
# Retrieved coordinates for big bend: (-26.8167, 31.9333)
# Retrieved coordinates for kerikeri: (-35.2268, 173.9474)
# Retrieved coordinates for tynda: (55.1667, 124.7167)
# Retrieved coordinates for happy valley-goose bay: (53.3168, -60.3315)
# Retrieved coordinates for padang: (-0.9492, 100.3543)
# Retrieved coordinates for sungai raya: (0.7, 108.9)
# City tranovaho not found (Status Code: 404). Skipping...
# Retrieved coordinates for bodaybo: (57.8506, 114.1933)
# Retrieved coordinates for aden: (12.7794, 45.0367)
# Retrieved coordinates for new norfolk: (-42.7826, 147.0587)
# City we not found (Status Code: 404). Skipping...
# Retrieved coordinates for new baltimore: (42.6811, -82.7369)
# Retrieved coordinates for amga: (60.8953, 131.9608)
# Retrieved coordinates for holualoa: (19.6228, -155.9522)
# Retrieved coordinates for chifeng: (42.2683, 118.9636)
# Retrieved coordinates for hammerfest: (70.6634, 23.6821)
# Retrieved coordinates for sylvan lake: (52.3168, -114.0853)
# Retrieved coordinates for howrah: (22.5892, 88.3103)
# Retrieved coordinates for kitimat: (54.0524, -128.6534)
# Retrieved coordinates for bechar: (31.6167, -2.2167)
# Retrieved coordinates for massawa: (15.6097, 39.45)
# Retrieved coordinates for almeirim: (-1.5233, -52.5817)
# Retrieved coordinates for codrington: (-38.2667, 141.9667)
# Retrieved coordinates for mizdah: (31.4451, 12.9801)
# Retrieved coordinates for bordighera: (43.7806, 7.6645)
# Retrieved coordinates for bandon: (51.7469, -8.7425)
# Retrieved coordinates for bodo: (67.28, 14.405)
# Retrieved coordinates for saint-francois: (46.4154, 3.9054)
# Retrieved coordinates for kapa'a: (22.0752, -159.319)
# Retrieved coordinates for awjilah: (29.1081, 21.2869)
# City abraham's bay not found (Status Code: 404). Skipping...
# Retrieved coordinates for barrouallie: (13.2333, -61.2667)
# Retrieved coordinates for moree: (-29.4667, 149.85)
# Retrieved coordinates for kalmunai: (7.4167, 81.8167)
# Retrieved coordinates for chui: (-33.6971, -53.4616)
# Retrieved coordinates for fale old settlement: (-9.3852, -171.2468)
# Retrieved coordinates for zheleznogorsk: (52.331, 35.3711)
# Retrieved coordinates for port alfred: (-33.5906, 26.891)
# Retrieved coordinates for yuzhno-kurilsk: (44.0306, 145.8556)
# Retrieved coordinates for bayside: (40.8424, -124.0637)
# Retrieved coordinates for port mathurin: (-19.6833, 63.4167)
# Retrieved coordinates for mhamid: (29.82, -5.72)
# Retrieved coordinates for xiuyan: (40.2928, 123.2744)
# Retrieved coordinates for bikenibeu village: (1.3673, 173.1241)
# Retrieved coordinates for galliano: (29.4422, -90.2992)
# Retrieved coordinates for rongelap: (11.1635, 166.8941)
# Retrieved coordinates for andalgala: (-27.5819, -66.3165)
# Retrieved coordinates for tucuma: (-0.1833, -50.05)
# Retrieved coordinates for sao joao da barra: (-21.6403, -41.0511)
# Retrieved coordinates for colonia: (50.9333, 6.95)
# Retrieved coordinates for malanje: (-9.5402, 16.341)
# Retrieved coordinates for hadibu: (12.65, 54.0333)
# Retrieved coordinates for ust-nera: (64.5667, 143.2)
# Retrieved coordinates for quepos: (9.4236, -84.1652)
# Retrieved coordinates for carnarvon: (-24.8667, 113.6333)
# Retrieved coordinates for villa gesell: (-37.2639, -56.973)
# Retrieved coordinates for napili-honokowai: (20.9708, -156.6705)
# City antsirabe afovoany not found (Status Code: 404). Skipping...
# Retrieved coordinates for oranjemund: (-28.55, 16.4333)
# Retrieved coordinates for port macquarie: (-31.4333, 152.9167)
# Retrieved coordinates for jagtial: (18.8, 78.9333)
# Retrieved coordinates for kimberley: (-28.7323, 24.7623)
# Retrieved coordinates for yarmouth: (41.7057, -70.2286)
# Retrieved coordinates for santa elena de uairen: (4.6167, -61.1333)
# Retrieved coordinates for enewetak: (11.3474, 162.3373)
# Retrieved coordinates for paracuru: (-3.41, -39.0306)
# Retrieved coordinates for lindome: (57.5667, 12.0833)
# Retrieved coordinates for kurchatov: (51.6601, 35.6521)
# Retrieved coordinates for georgetown: (5.4112, 100.3354)
# Retrieved coordinates for skudai: (1.5333, 103.6667)
# Retrieved coordinates for yebaishou: (41.3975, 119.6408)
# Retrieved coordinates for laojunmiao: (39.8333, 97.7333)
# Retrieved coordinates for sokoni: (-6.4333, 39.55)
# Retrieved coordinates for iranshahr: (27.2025, 60.6848)
# Retrieved coordinates for nogliki: (51.8333, 143.1667)
# Retrieved coordinates for mogocha: (53.7333, 119.7667)
# Retrieved coordinates for ocean shores: (46.9737, -124.1563)
# Retrieved coordinates for rio gallegos: (-51.6226, -69.2181)
# Retrieved coordinates for lovington: (32.944, -103.3485)
# Retrieved coordinates for mahdia: (35.5047, 11.0622)
# Retrieved coordinates for plettenberg bay: (-34.0527, 23.3716)
# Retrieved coordinates for kingston: (17.997, -76.7936)
# Retrieved coordinates for axim: (4.8699, -2.2405)
# Retrieved coordinates for castillos: (-34.1667, -53.8333)
# Retrieved coordinates for stephenville: (32.2207, -98.2023)
# Retrieved coordinates for monterey: (36.2505, -121.2516)
# Retrieved coordinates for sainte-rose: (16.3324, -61.6979)
# Retrieved coordinates for la foa: (-21.7108, 165.8276)
# Retrieved coordinates for vicosa: (-20.7539, -42.8819)
# Retrieved coordinates for magadan: (59.5667, 150.8)
# Retrieved coordinates for manturovo: (58.3353, 44.7619)
# Retrieved coordinates for guerande: (47.3291, -2.4283)
# Retrieved coordinates for torrington: (41.8007, -73.1212)
# Retrieved coordinates for lewistown: (40.5992, -77.5714)
# Retrieved coordinates for burnie: (-41.0667, 145.9167)
# Retrieved coordinates for saint-philippe: (-21.3585, 55.7679)
# Retrieved coordinates for mossel bay: (-34.1831, 22.146)
# Retrieved coordinates for singaraja: (-8.112, 115.0882)
# Retrieved coordinates for yorkton: (51.2167, -102.4677)
# Retrieved coordinates for shahrud: (36.4182, 54.9763)
# Retrieved coordinates for kuragino: (53.8975, 92.6725)
# Retrieved coordinates for murun-kuren: (49.6342, 100.1625)
# Retrieved coordinates for wankyi: (7.7392, -2.1046)
# Retrieved coordinates for nuku'alofa: (-21.1333, -175.2)
# Retrieved coordinates for jebrail: (39.3992, 47.0283)
# Retrieved coordinates for taiynsha: (53.8478, 69.7639)
# Retrieved coordinates for sona: (45.4388, 10.8255)
# Retrieved coordinates for livingston: (55.9029, -3.5226)
# Retrieved coordinates for dunedin: (-45.8742, 170.5036)
# City hihifo not found (Status Code: 404). Skipping...
# Retrieved coordinates for chonchi: (-42.6128, -73.8092)
# Retrieved coordinates for inhuma: (-6.6683, -41.7078)
# Retrieved coordinates for marechal deodoro: (-9.7103, -35.895)
# Retrieved coordinates for sofifi: (0.7349, 127.576)
# Retrieved coordinates for san andres: (12.5847, -81.7006)
# Retrieved coordinates for sibolga: (1.7427, 98.7792)
# Retrieved coordinates for jiuquan: (39.7432, 98.5174)
# Retrieved coordinates for valparaiso: (-33.0393, -71.6273)
# Retrieved coordinates for malmberget: (67.1753, 20.6549)
# Retrieved coordinates for la reforma: (25.0833, -108.05)
# Retrieved coordinates for yelbarga: (15.6333, 76.0167)
# Retrieved coordinates for springbok: (-29.6643, 17.8865)
# Retrieved coordinates for chernyshevsk: (52.5243, 117.0174)
# Retrieved coordinates for rexburg: (43.826, -111.7897)
# Retrieved coordinates for kristiansund: (63.1115, 7.732)
# Retrieved coordinates for bereeda: (11.8704, 51.0579)
# Retrieved coordinates for oppdal: (62.5943, 9.6912)
# Retrieved coordinates for bakanas: (44.8081, 76.2772)
# City bejubang dua not found (Status Code: 404). Skipping...
# Retrieved coordinates for polyarnyy: (69.1989, 33.4478)
# City hayma' not found (Status Code: 404). Skipping...
# Retrieved coordinates for socorro: (31.6546, -106.3033)
# Retrieved coordinates for illizi: (26.4833, 8.4667)
# Retrieved coordinates for ciudad victoria: (23.7333, -99.1333)
# City qapqal not found (Status Code: 404). Skipping...
# Retrieved coordinates for klodawa: (52.2545, 18.9135)
# Retrieved coordinates for murray bridge: (-35.1167, 139.2667)
# Retrieved coordinates for puerto carreno: (6.189, -67.4859)
# Retrieved coordinates for mount pearl: (47.5166, -52.7813)
# Retrieved coordinates for el kala: (36.8956, 8.4433)
# Retrieved coordinates for nizhnyaya salda: (58.0776, 60.7202)
# Retrieved coordinates for puttalam: (8.0362, 79.8283)
# Retrieved coordinates for paradip garh: (20.3167, 86.6167)
# Retrieved coordinates for abancay: (-13.6339, -72.8814)
# Retrieved coordinates for scarborough: (54.2797, -0.4044)
# Retrieved coordinates for ujae: (8.9322, 165.7642)
# Retrieved coordinates for codajas: (-3.8367, -62.0569)
# Retrieved coordinates for thinadhoo: (0.5333, 72.9333)
# Retrieved coordinates for zonguldak: (41.25, 31.8333)
# Retrieved coordinates for vila velha: (-20.3297, -40.2925)
# Total valid cities with coordinates: 417

# %%
print(valid_cities)
# Out:
# {'tiksi': {'city': 'tiksi', 'lat': 71.6872, 'lon': 128.8694, 'country': 'RU'}, 'waitangi': {'city': 'waitangi', 'lat': -43.9535, 'lon': -176.5597, 'country': 'NZ'}, 'thompson': {'city': 'thompson', 'lat': 55.7435, 'lon': -97.8558, 'country': 'CA'}, 'punta arenas': {'city': 'punta arenas', 'lat': -53.15, 'lon': -70.9167, 'country': 'CL'}, 'carnarvon': {'city': 'carnarvon', 'lat': -24.8667, 'lon': 113.6333, 'country': 'AU'}, 'bilibino': {'city': 'bilibino', 'lat': 68.0546, 'lon': 166.4372, 'country': 'RU'}, 'puerto natales': {'city': 'puerto natales', 'lat': -51.7236, 'lon': -72.4875, 'country': 'CL'}, 'kulhudhuffushi': {'city': 'kulhudhuffushi', 'lat': 6.6221, 'lon': 73.07, 'country': 'MV'}, 'albany': {'city': 'albany', 'lat': 42.6001, 'lon': -73.9662, 'country': 'US'}, 'ribeira grande': {'city': 'ribeira grande', 'lat': 38.5167, 'lon': -28.7, 'country': 'PT'}, 'touros': {'city': 'touros', 'lat': -5.1989, 'lon': -35.4608, 'country': 'BR'}, 'chonchi': {'city': 'chonchi', 'lat': -42.6128, 'lon': -73.8092, 'country': 'CL'}, 'port-aux-francais': {'city': 'port-aux-francais', 'lat': -49.35, 'lon': 70.2167, 'country': 'TF'}, 'avarua': {'city': 'avarua', 'lat': -21.2078, 'lon': -159.775, 'country': 'CK'}, 'hadibu': {'city': 'hadibu', 'lat': 12.65, 'lon': 54.0333, 'country': 'YE'}, 'arraial do cabo': {'city': 'arraial do cabo', 'lat': -22.9661, 'lon': -42.0278, 'country': 'BR'}, 'nguigmi': {'city': 'nguigmi', 'lat': 14.2495, 'lon': 13.1092, 'country': 'NE'}, 'ushuaia': {'city': 'ushuaia', 'lat': -54.8, 'lon': -68.3, 'country': 'AR'}, 'invercargill': {'city': 'invercargill', 'lat': -46.4, 'lon': 168.35, 'country': 'NZ'}, 'tura': {'city': 'tura', 'lat': 25.5198, 'lon': 90.2201, 'country': 'IN'}, 'vernon': {'city': 'vernon', 'lat': 50.2581, 'lon': -119.2691, 'country': 'CA'}, 'blackmans bay': {'city': 'blackmans bay', 'lat': -43.0167, 'lon': 147.3167, 'country': 'AU'}, 'malanje': {'city': 'malanje', 'lat': -9.5402, 'lon': 16.341, 'country': 'AO'}, 'bandarbeyla': {'city': 'bandarbeyla', 'lat': 9.4942, 'lon': 50.8122, 'country': 'SO'}, 'iqaluit': {'city': 'iqaluit', 'lat': 63.7506, 'lon': -68.5145, 'country': 'CA'}, 'mbaiki': {'city': 'mbaiki', 'lat': 3.8678, 'lon': 17.9892, 'country': 'CF'}, 'narasannapeta': {'city': 'narasannapeta', 'lat': 18.4167, 'lon': 84.05, 'country': 'IN'}, 'adamstown': {'city': 'adamstown', 'lat': -25.066, 'lon': -130.1015, 'country': 'PN'}, 'baley': {'city': 'baley', 'lat': 51.6, 'lon': 116.6333, 'country': 'RU'}, 'vilyuysk': {'city': 'vilyuysk', 'lat': 63.7553, 'lon': 121.6247, 'country': 'RU'}, 'taulaga': {'city': 'taulaga', 'lat': -11.0553, 'lon': -171.0883, 'country': 'AS'}, "vrangel'": {'city': "vrangel'", 'lat': 42.7297, 'lon': 133.0839, 'country': 'RU'}, 'san fernando del valle de catamarca': {'city': 'san fernando del valle de catamarca', 'lat': -28.4696, 'lon': -65.7852, 'country': 'AR'}, 'holualoa': {'city': 'holualoa', 'lat': 19.6228, 'lon': -155.9522, 'country': 'US'}, 'grytviken': {'city': 'grytviken', 'lat': -54.2811, 'lon': -36.5092, 'country': 'GS'}, 'beau vallon': {'city': 'beau vallon', 'lat': -20.4189, 'lon': 57.6953, 'country': 'MU'}, 'papatowai': {'city': 'papatowai', 'lat': -46.5619, 'lon': 169.4708, 'country': 'NZ'}, 'polyarnyy': {'city': 'polyarnyy', 'lat': 69.1989, 'lon': 33.4478, 'country': 'RU'}, 'rio grande': {'city': 'rio grande', 'lat': -32.035, 'lon': -52.0986, 'country': 'BR'}, 'west island': {'city': 'west island', 'lat': -12.1568, 'lon': 96.8225, 'country': 'CC'}, 'menongue': {'city': 'menongue', 'lat': -14.6585, 'lon': 17.691, 'country': 'AO'}, 'margaret river': {'city': 'margaret river', 'lat': -33.95, 'lon': 115.0667, 'country': 'AU'}, 'utrik': {'city': 'utrik', 'lat': 11.2278, 'lon': 169.8474, 'country': 'MH'}, 'harper': {'city': 'harper', 'lat': 4.375, 'lon': -7.7169, 'country': 'LR'}, 'mar del plata': {'city': 'mar del plata', 'lat': -38.0023, 'lon': -57.5575, 'country': 'AR'}, 'yatou': {'city': 'yatou', 'lat': 37.15, 'lon': 122.3833, 'country': 'CN'}, 'sitka': {'city': 'sit ...

# %%
city_names = list(valid_cities.keys())
print(city_names)
# Out:
# ['tiksi', 'waitangi', 'thompson', 'punta arenas', 'carnarvon', 'bilibino', 'puerto natales', 'kulhudhuffushi', 'albany', 'ribeira grande', 'touros', 'chonchi', 'port-aux-francais', 'avarua', 'hadibu', 'arraial do cabo', 'nguigmi', 'ushuaia', 'invercargill', 'tura', 'vernon', 'blackmans bay', 'malanje', 'bandarbeyla', 'iqaluit', 'mbaiki', 'narasannapeta', 'adamstown', 'baley', 'vilyuysk', 'taulaga', "vrangel'", 'san fernando del valle de catamarca', 'holualoa', 'grytviken', 'beau vallon', 'papatowai', 'polyarnyy', 'rio grande', 'west island', 'menongue', 'margaret river', 'utrik', 'harper', 'mar del plata', 'yatou', 'sitka', 'hermanus', 'kodiak', 'petropavlovsk-kamchatsky', 'happy valley-goose bay', 'thunder bay', 'bredasdorp', 'aasiaat', 'basco', 'sao joao da barra', 'aktau', 'xinyuan', 'talnakh', 'chipata', 'hasaki', 'ilulissat', 'puerto ayora', 'geraldton', 'humaita', 'isla aguada', 'safford', 'skeldon', 'ust-nera', 'abong mbang', 'yellowknife', 'olonkinbyen', 'uturoa', 'quimili', 'gubkinskiy', 'edinburgh of the seven seas', 'puerto colombia', 'villa gesell', 'grand falls-windsor', 'kavaratti', 'saint-francois', 'klaksvik', 'lahaina', 'faya-largeau', 'amble', 'lorengau', 'katsuren-haebaru', 'nurota', 'weno', 'bethel', 'aketi', 'brandon', 'maintirano', 'taveta', "st. john's", 'longyearbyen', 'sagua la grande', 'amga', 'huanuni', 'saipan', 'sao tome', 'pisco', 'vuktyl', 'port elizabeth', 'susanville', 'carloforte', 'gizo', 'punta del este', 'rabo de peixe', 'sydney mines', 'vorgashor', "l'isle-jourdain", 'praia da vitoria', 'newman', 'ulysses', 'daoukro', 'prince albert', 'wailua homesteads', 'cabo san lucas', 'challapata', 'qamdo', 'ancud', 'ornskoldsvik', 'jilib', 'al bawiti', 'taltal', 'kailua-kona', 'jorpeland', 'iskateley', 'atafu village', 'nogliki', 'keflavik', 'puerto baquerizo moreno', 'malango', 'klyuchi', 'tougan', 'tual', 'arteche', 'acarau', 'port-vila', 'kavieng', 'santarem', 'severo-yeniseyskiy', 'colonia', 'posto fiscal rolim de moura', 'fuerte olimpo', 'palikir - national government center', "bich'vinta", "qarah zia' od din", 'parfino', 'arawa', 'enewetak', 'balaka', 'kijang', 'isafjordur', 'aluksne', 'coracora', 'tezu', 'khasab', 'kolosovka', 'lebu', 'kapuskasing', 'puerto ayacucho', 'sidney', 'east london', 'korop', 'brookings', 'thinadhoo', 'axim', 'alice springs', 'belmonte', 'nelsonville', 'port alfred', 'qaqortoq', 'poronaysk', 'lompoc', 'nchelenge', 'akureyri', 'margate', 'anadyr', 'el porvenir', 'fale old settlement', 'georgetown', 'puerto carreno', 'zykovo', 'nakhon thai', 'luganville', 'piti village', 'francistown', 'kirensk', 'xining', 'shibirghan', 'port lincoln', 'yuzhno-kurilsk', 'poiana teiului', 'hamilton', 'karratha', 'vorkuta', 'san patricio', 'pacific grove', 'viitasaari', 'great falls', 'hampton bays', 'zeya', 'saint-philippe', 'zakynthos', 'camocim', 'darwin', 'port said', 'port mathurin', 'ixtapa', 'santiago papasquiaro', 'remire-montjoly', 'balkanabat', 'mata-utu', 'kenora', 'santa cruz', 'jacksonville beach', 'sinop', 'lihue', 'christchurch', 'tonghae', 'mirnyy', 'kostomuksha', 'siwa oasis', 'rouissat', 'muslyumovo', 'vadso', 'queenstown', 'dazhou', 'beledweyne', 'badger', 'cadale', 'udachny', 'rutana', 'astorga', 'eraan', 'dudinka', 'jwaneng', 'kachug', 'amursk', 'dunedin', 'haiku-pauwela', 'paracuru', 'lucon', 'thabazimbi', 'alaghsas', 'oranjemund', 'stanley', 'whitehorse', 'mandera', 'flying fish cove', 'staryy dobrotvir', 'caleta de carquin', "nar'yan-mar", 'yeniseysk', 'pospelikha', 'fiche', 'domanivka', 'tannum sands', 'alotau', 'egilsstadir', 'hawaiian paradise park', 'port blair', 'azhikkal', 'bikenibeu village', 'at-bashi', 'atar', 'bamboo flat', 'korba', 'grajau', 'necochea', 'jamestown', 'lerwick', 'galliano', 'bayanaul', 'kone', 'bankim', 'belomorsk', 'rurrenabaque', 'mawu', 'nova olimpia', 'mazatlan', 'huron', 'kikwit', 'dwarka', 'sidi qacem', 'puerto armuelles', 'chernyshevskiy', 'aioun', 'griffith', 'raduzhnyy', 'mogocha', "port saint john's", 'vilyuchinsk', 'revda', 'lan ...

# %%
# List to store air quality data
air_quality_data = []

# Loop through each city to get pollution data
for city, info in valid_cities.items():
    lat = info['lat']
    lon = info['lon']

    try:
        # Query the Air Pollution API
        pollution_url = f"{air_quality_url}?lat={lat}&lon={lon}&appid={weather_api_key}"
        pollution_response = requests.get(pollution_url).json()

        # Extract pollution components
        components = pollution_response['list'][0]['components']
        pm25 = components.get('pm2_5', None)
        pm10 = components.get('pm10', None)
        no2 = components.get('no2', None)
        o3 = components.get('o3', None)
        so2 = components.get('so2', None)
        co = components.get('co', None)
        nh3 = components.get('nh3', None)

        # Store the pollution data
        air_quality_data.append({
            'City': city,
            'Country': info['country'],
            'PM2.5': pm25,
            'PM10': pm10,
            'NO2': no2,
            'O3': o3,
            'SO2': so2,
            'CO': co,
            'NH3': nh3
        })

        print(f"Retrieved pollution data for {city}, {info['country']}")

    except Exception as e:
        print(f"Error retrieving data for {city}: {e}")

    # Pause to avoid rate limiting
    time.sleep(1)

# Convert the collected data into a DataFrame
air_quality_df = pd.DataFrame(air_quality_data)
print(air_quality_df.head())
# Out:
# Retrieved pollution data for tiksi, RU, PM2.5: 0.5
# Retrieved pollution data for waitangi, NZ, PM2.5: 0.83
# Retrieved pollution data for thompson, CA, PM2.5: 0.5
# Retrieved pollution data for punta arenas, CL, PM2.5: 0.5
# Retrieved pollution data for carnarvon, AU, PM2.5: 0.72
# Retrieved pollution data for bilibino, RU, PM2.5: 0.5
# Retrieved pollution data for puerto natales, CL, PM2.5: 0.5
# Retrieved pollution data for kulhudhuffushi, MV, PM2.5: 0.89
# Retrieved pollution data for albany, US, PM2.5: 0.5
# Retrieved pollution data for ribeira grande, PT, PM2.5: 3.32
# Retrieved pollution data for touros, BR, PM2.5: 1.58
# Retrieved pollution data for chonchi, CL, PM2.5: 0.92
# Retrieved pollution data for port-aux-francais, TF, PM2.5: 0.5
# Retrieved pollution data for avarua, CK, PM2.5: 1.56
# Retrieved pollution data for hadibu, YE, PM2.5: 7.94
# Retrieved pollution data for arraial do cabo, BR, PM2.5: 2.51
# Retrieved pollution data for nguigmi, NE, PM2.5: 56.58
# Retrieved pollution data for ushuaia, AR, PM2.5: 0.5
# Retrieved pollution data for invercargill, NZ, PM2.5: 0.97
# Retrieved pollution data for tura, IN, PM2.5: 69.51
# Retrieved pollution data for vernon, CA, PM2.5: 3.63
# Retrieved pollution data for blackmans bay, AU, PM2.5: 1.07
# Retrieved pollution data for malanje, AO, PM2.5: 4.88
# Retrieved pollution data for bandarbeyla, SO, PM2.5: 4.15
# Retrieved pollution data for iqaluit, CA, PM2.5: 0.94
# Retrieved pollution data for mbaiki, CF, PM2.5: 0.5
# Retrieved pollution data for narasannapeta, IN, PM2.5: 12
# Retrieved pollution data for adamstown, PN, PM2.5: 0.92
# Retrieved pollution data for baley, RU, PM2.5: 0.5
# Retrieved pollution data for vilyuysk, RU, PM2.5: 0.5
# Retrieved pollution data for taulaga, AS, PM2.5: 1.44
# Retrieved pollution data for vrangel', RU, PM2.5: 1.9
# Retrieved pollution data for san fernando del valle de catamarca, AR, PM2.5: 1.94
# Retrieved pollution data for holualoa, US, PM2.5: 24.85
# Retrieved pollution data for grytviken, GS, PM2.5: 2.47
# Retrieved pollution data for beau vallon, MU, PM2.5: 3.56
# Retrieved pollution data for papatowai, NZ, PM2.5: 0.86
# Retrieved pollution data for polyarnyy, RU, PM2.5: 0.5
# Retrieved pollution data for rio grande, BR, PM2.5: 4.26
# Retrieved pollution data for west island, CC, PM2.5: 6.61
# Retrieved pollution data for menongue, AO, PM2.5: 11.45
# Retrieved pollution data for margaret river, AU, PM2.5: 0.5
# Retrieved pollution data for utrik, MH, PM2.5: 1.28
# Retrieved pollution data for harper, LR, PM2.5: 1.95
# Retrieved pollution data for mar del plata, AR, PM2.5: 2.06
# Retrieved pollution data for yatou, CN, PM2.5: 9.43
# Retrieved pollution data for sitka, US, PM2.5: 0.5
# Retrieved pollution data for hermanus, ZA, PM2.5: 1.36
# Retrieved pollution data for kodiak, US, PM2.5: 0.5
# Retrieved pollution data for petropavlovsk-kamchatsky, RU, PM2.5: 1.91
# Retrieved pollution data for happy valley-goose bay, CA, PM2.5: 0.5
# Retrieved pollution data for thunder bay, CA, PM2.5: 0.5
# Retrieved pollution data for bredasdorp, ZA, PM2.5: 1.58
# Retrieved pollution data for aasiaat, GL, PM2.5: 0.5
# Retrieved pollution data for basco, PH, PM2.5: 2.79
# Retrieved pollution data for sao joao da barra, BR, PM2.5: 2.38
# Retrieved pollution data for aktau, KZ, PM2.5: 17.46
# Retrieved pollution data for xinyuan, CN, PM2.5: 2.85
# Retrieved pollution data for talnakh, RU, PM2.5: 0.5
# Retrieved pollution data for chipata, ZM, PM2.5: 2.46
# Retrieved pollution data for hasaki, JP, PM2.5: 6.89
# Retrieved pollution data for ilulissat, GL, PM2.5: 0.5
# Retrieved pollution data for puerto ayora, EC, PM2.5: 2.93
# Retrieved pollution data for geraldton, AU, PM2.5: 1.01
# Retrieved pollution data for humaita, BR, PM2.5: 1.73
# Retrieved pollution data for isla aguada, MX, PM2.5: 1.18
# Retrieved pollution data for safford, US, PM2.5: 1.66
# Retrieved pollution data for skeldon, GY, PM2.5: 0.73
# Retrieved pollution data for ust-nera, RU, PM2.5: 0.5
# Retrieved pollution data for abong mbang, CM, PM2.5: 0.55
# Retrieved pollution data for yellowknife, CA, PM2.5: 0.5
# Retrieved pollution data for olonkinbyen, SJ, PM2.5: 0.5
# Retrieved pollution data for uturoa, PF, PM2.5: 1.3
# Retrieved pollution data for quimili, AR, PM2.5: 0.74
# Retrieved pollution data for gubkinskiy, RU, PM2.5: 0.51
# Retrieved pollution data for edinburgh of the seven seas, SH, PM2.5: 0.94
# Retrieved pollution data for puerto colombia, CO, PM2.5: 1.24
# Retrieved pollution data for villa gesell, AR, PM2.5: 4.68
# Retrieved pollution data for grand falls-windsor, CA, PM2.5: 1.42
# Retrieved pollution data for kavaratti, IN, PM2.5: 0.73
# Retrieved pollution data for saint-francois, FR, PM2.5: 4.62
# Retrieved pollution data for klaksvik, FO, PM2.5: 2.16
# Retrieved pollution data for lahaina, US, PM2.5: 2.35
# Retrieved pollution data for faya-largeau, TD, PM2.5: 32.98
# Retrieved pollution data for amble, GB, PM2.5: 5.64
# Retrieved pollution data for lorengau, PG, PM2.5: 0.5
# Retrieved pollution data for katsuren-haebaru, JP, PM2.5: 1.47
# Retrieved pollution data for nurota, UZ, PM2.5: 11.72
# Retrieved pollution data for weno, FM, PM2.5: 0.5
# Retrieved pollution data for bethel, US, PM2.5: 0.5
# Retrieved pollution data for aketi, CD, PM2.5: 0.5
# Retrieved pollution data for brandon, US, PM2.5: 24.24
# Retrieved pollution data for maintirano, MG, PM2.5: 5.97
# Retrieved pollution data for taveta, KE, PM2.5: 5.98
# Retrieved pollution data for st. john's, CA, PM2.5: 0.82
# Retrieved pollution data for longyearbyen, SJ, PM2.5: 0.5
# Retrieved pollution data for sagua la grande, CU, PM2.5: 0.96
# Retrieved pollution data for amga, RU, PM2.5: 0.5
# Retrieved pollution data for huanuni, BO, PM2.5: 1.83
# Retrieved pollution data for saipan, MP, PM2.5: 0.56
# Retrieved pollution data for sao tome, ST, PM2.5: 1.21
# Retrieved pollution data for pisco, PE, PM2.5: 4.37
# Retrieved pollution data for vuktyl, RU, PM2.5: 1.59
# Retrieved pollution data for port elizabeth, ZA, PM2.5: 1.33
# Retrieved pollution data for susanville, US, PM2.5: 2.32
# Retrieved pollution data for carloforte, IT, PM2.5: 11.75
# Retrieved pollution data for gizo, SB, PM2.5: 0.69
# Retrieved pollution data for punta del este, UY, PM2.5: 3.45
# Retrieved pollution data for rabo de peixe, PT, PM2.5: 2.29
# Retrieved pollution data for sydney mines, CA, PM2.5: 0.5
# Retrieved pollution data for vorgashor, RU, PM2.5: 1.2
# Retrieved pollution data for l'isle-jourdain, FR, PM2.5: 2.38
# Retrieved pollution data for praia da vitoria, PT, PM2.5: 2.62
# Retrieved pollution data for newman, US, PM2.5: 17.19
# Retrieved pollution data for ulysses, US, PM2.5: 7.07
# Retrieved pollution data for daoukro, CI, PM2.5: 4.48
# Retrieved pollution data for prince albert, CA, PM2.5: 2.91
# Retrieved pollution data for wailua homesteads, US, PM2.5: 2.71
# Retrieved pollution data for cabo san lucas, MX, PM2.5: 3.22
# Retrieved pollution data for challapata, BO, PM2.5: 2.15
# Retrieved pollution data for qamdo, CN, PM2.5: 1.55
# Retrieved pollution data for ancud, CL, PM2.5: 0.5
# Retrieved pollution data for ornskoldsvik, SE, PM2.5: 0.5
# Retrieved pollution data for jilib, SO, PM2.5: 2.56
# Retrieved pollution data for al bawiti, EG, PM2.5: 18.46
# Retrieved pollution data for taltal, CL, PM2.5: 7.12
# Retrieved pollution data for kailua-kona, US, PM2.5: 24.85
# Retrieved pollution data for jorpeland, NO, PM2.5: 0.5
# Retrieved pollution data for iskateley, RU, PM2.5: 1.24
# Retrieved pollution data for atafu village, TK, PM2.5: 0.67
# Retrieved pollution data for nogliki, RU, PM2.5: 0.5
# Retrieved pollution data for keflavik, IS, PM2.5: 0.5
# Retrieved pollution data for puerto baquerizo moreno, EC, PM2.5: 2.55
# Retrieved pollution data for malango, ID, PM2.5: 2.45
# Retrieved pollution data for klyuchi, RU, PM2.5: 1.54
# Retrieved pollution data for tougan, BF, PM2.5: 9
# Retrieved pollution data for tual, ID, PM2.5: 2.06
# Retrieved pollution data for arteche, PH, PM2.5: 0.64
# Retrieved pollution data for acarau, BR, PM2.5: 3.22
# Retrieved pollution data for port-vila, VU, PM2.5: 2.82
# Retrieved pollution data for kavieng, PG, PM2.5: 0.5
# Retrieved pollution data for santarem, BR, PM2.5: 4.21
# Retrieved pollution data for severo-yeniseyskiy, RU, PM2.5: 0.5
# Retrieved pollution data for colonia, DE, PM2.5: 3.49
# Retrieved pollution data for posto fiscal rolim de moura, BR, PM2.5: 10.79
# Retrieved pollution data for fuerte olimpo, PY, PM2.5: 7.01
# Retrieved pollution data for palikir - national government center, FM, PM2.5: 0.53
# Retrieved pollution data for bich'vinta, GE, PM2.5: 0.5
# Retrieved pollution data for qarah zia' od din, IR, PM2.5: 1.08
# Retrieved pollution data for parfino, RU, PM2.5: 0.63
# Retrieved pollution data for arawa, PG, PM2.5: 30.8
# Retrieved pollution data for enewetak, MH, PM2.5: 1.07
# Retrieved pollution data for balaka, MW, PM2.5: 4.61
# Retrieved pollution data for kijang, KR, PM2.5: 23.83
# Retrieved pollution data for isafjordur, IS, PM2.5: 0.54
# Retrieved pollution data for aluksne, LV, PM2.5: 0.5
# Retrieved pollution data for coracora, PE, PM2.5: 6.29
# Retrieved pollution data for tezu, IN, PM2.5: 5.15
# Retrieved pollution data for khasab, OM, PM2.5: 22.93
# Retrieved pollution data for kolosovka, RU, PM2.5: 4.33
# Retrieved pollution data for lebu, CL, PM2.5: 2.58
# Retrieved pollution data for kapuskasing, CA, PM2.5: 0.5
# Retrieved pollution data for puerto ayacucho, VE, PM2.5: 0.5
# Retrieved pollution data for sidney, AU, PM2.5: 11.2
# Retrieved pollution data for east london, ZA, PM2.5: 1.28
# Retrieved pollution data for korop, UA, PM2.5: 1.66
# Retrieved pollution data for brookings, US, PM2.5: 1.47
# Retrieved pollution data for thinadhoo, MV, PM2.5: 0.56
# Retrieved pollution data for axim, GH, PM2.5: 2.18
# Retrieved pollution data for alice springs, AU, PM2.5: 17.58
# Retrieved pollution data for belmonte, BR, PM2.5: 2.56
# Retrieved pollution data for nelsonville, US, PM2.5: 0.5
# Retrieved pollution data for port alfred, ZA, PM2.5: 1.07
# Retrieved pollution data for qaqortoq, GL, PM2.5: 0.84
# Retrieved pollution data for poronaysk, RU, PM2.5: 0.5
# Retrieved pollution data for lompoc, US, PM2.5: 1.26
# Retrieved pollution data for nchelenge, ZM, PM2.5: 1.47
# Retrieved pollution data for akureyri, IS, PM2.5: 0.61
# Retrieved pollution data for margate, GB, PM2.5: 9.32
# Retrieved pollution data for anadyr, RU, PM2.5: 0.5
# Retrieved pollution data for el porvenir, HN, PM2.5: 1
# Retrieved pollution data for fale old settlement, TK, PM2.5: 0.68
# Retrieved pollution data for georgetown, MY, PM2.5: 11.11
# Retrieved pollution data for puerto carreno, CO, PM2.5: 0.5
# Retrieved pollution data for zykovo, RU, PM2.5: 2.38
# Retrieved pollution data for nakhon thai, TH, PM2.5: 8.92
# Retrieved pollution data for luganville, VU, PM2.5: 0.62
# Retrieved pollution data for piti village, GU, PM2.5: 0.5
# Retrieved pollution data for francistown, BW, PM2.5: 3.45
# Retrieved pollution data for kirensk, RU, PM2.5: 0.5
# Retrieved pollution data for xining, CN, PM2.5: 17.6
# Retrieved pollution data for shibirghan, AF, PM2.5: 6.47
# Retrieved pollution data for port lincoln, AU, PM2.5: 5.14
# Retrieved pollution data for yuzhno-kurilsk, RU, PM2.5: 2.16
# Retrieved pollution data for poiana teiului, RO, PM2.5: 2.68
# Retrieved pollution data for hamilton, US, PM2.5: 0.5
# Retrieved pollution data for karratha, AU, PM2.5: 5.79
# Retrieved pollution data for vorkuta, RU, PM2.5: 1.19
# Retrieved pollution data for san patricio, US, PM2.5: 11.82
# Retrieved pollution data for pacific grove, US, PM2.5: 1.88
# Retrieved pollution data for viitasaari, FI, PM2.5: 0.5
# Retrieved pollution data for great falls, US, PM2.5: 10.62
# Retrieved pollution data for hampton bays, US, PM2.5: 0.5
# Retrieved pollution data for zeya, RU, PM2.5: 0.57
# Retrieved pollution data for saint-philippe, RE, PM2.5: 7.86
# Retrieved pollution data for zakynthos, GR, PM2.5: 6.45
# Retrieved pollution data for camocim, BR, PM2.5: 3.11
# Retrieved pollution data for darwin, AU, PM2.5: 3.14
# Retrieved pollution data for port said, EG, PM2.5: 4.95
# Retrieved pollution data for port mathurin, MU, PM2.5: 1.52
# Retrieved pollution data for ixtapa, MX, PM2.5: 11.44
# Retrieved pollution data for santiago papasquiaro, MX, PM2.5: 6.33
# Retrieved pollution data for remire-montjoly, GF, PM2.5: 1.08
# Retrieved pollution data for balkanabat, TM, PM2.5: 17.9
# Retrieved pollution data for mata-utu, WF, PM2.5: 2.99
# Retrieved pollution data for kenora, CA, PM2.5: 0.5
# Retrieved pollution data for santa cruz, BO, PM2.5: 33.37
# Retrieved pollution data for jacksonville beach, US, PM2.5: 12.46
# Retrieved pollution data for sinop, TR, PM2.5: 1.87
# Retrieved pollution data for lihue, US, PM2.5: 2.41
# Retrieved pollution data for christchurch, NZ, PM2.5: 1.41
# Retrieved pollution data for tonghae, KR, PM2.5: 16.93
# Retrieved pollution data for mirnyy, RU, PM2.5: 0.5
# Retrieved pollution data for kostomuksha, RU, PM2.5: 0.5
# Retrieved pollution data for siwa oasis, EG, PM2.5: 12.32
# Retrieved pollution data for rouissat, DZ, PM2.5: 56.79
# Retrieved pollution data for muslyumovo, RU, PM2.5: 6.74
# Retrieved pollution data for vadso, NO, PM2.5: 0.5
# Retrieved pollution data for queenstown, ZA, PM2.5: 1.26
# Retrieved pollution data for dazhou, CN, PM2.5: 66.43
# Retrieved pollution data for beledweyne, SO, PM2.5: 3.45
# Retrieved pollution data for badger, US, PM2.5: 0.5
# Retrieved pollution data for cadale, SO, PM2.5: 2.64
# Retrieved pollution data for udachny, RU, PM2.5: 0.5
# Retrieved pollution data for rutana, BI, PM2.5: 12.91
# Retrieved pollution data for astorga, BR, PM2.5: 12.53
# Retrieved pollution data for eraan, PH, PM2.5: 3.71
# Retrieved pollution data for dudinka, RU, PM2.5: 1.27
# Retrieved pollution data for jwaneng, BW, PM2.5: 0.73
# Retrieved pollution data for kachug, RU, PM2.5: 0.5
# Retrieved pollution data for amursk, RU, PM2.5: 2.86
# Retrieved pollution data for dunedin, NZ, PM2.5: 0.88
# Retrieved pollution data for haiku-pauwela, US, PM2.5: 2.52
# Retrieved pollution data for paracuru, BR, PM2.5: 2.58
# Retrieved pollution data for lucon, FR, PM2.5: 4.24
# Retrieved pollution data for thabazimbi, ZA, PM2.5: 0.5
# Retrieved pollution data for alaghsas, NE, PM2.5: 64.22
# Retrieved pollution data for oranjemund, NA, PM2.5: 41.5
# Retrieved pollution data for stanley, GB, PM2.5: 10.18
# Retrieved pollution data for whitehorse, CA, PM2.5: 0.5
# Retrieved pollution data for mandera, KE, PM2.5: 1.26
# Retrieved pollution data for flying fish cove, CX, PM2.5: 6.51
# Retrieved pollution data for staryy dobrotvir, UA, PM2.5: 3.84
# Retrieved pollution data for caleta de carquin, PE, PM2.5: 4.23
# Retrieved pollution data for nar'yan-mar, RU, PM2.5: 1.24
# Retrieved pollution data for yeniseysk, RU, PM2.5: 1.12
# Retrieved pollution data for pospelikha, RU, PM2.5: 9.21
# Retrieved pollution data for fiche, ET, PM2.5: 19
# Retrieved pollution data for domanivka, UA, PM2.5: 1.57
# Retrieved pollution data for tannum sands, AU, PM2.5: 1.67
# Retrieved pollution data for alotau, PG, PM2.5: 0.54
# Retrieved pollution data for egilsstadir, IS, PM2.5: 0.55
# Retrieved pollution data for hawaiian paradise park, US, PM2.5: 2.28
# Retrieved pollution data for port blair, IN, PM2.5: 1.81
# Retrieved pollution data for azhikkal, IN, PM2.5: 23.96
# Retrieved pollution data for bikenibeu village, KI, PM2.5: 4.01
# Retrieved pollution data for at-bashi, KG, PM2.5: 3.11
# Retrieved pollution data for atar, MR, PM2.5: 53.65
# Retrieved pollution data for bamboo flat, IN, PM2.5: 1.81
# Retrieved pollution data for korba, IN, PM2.5: 65.13
# Retrieved pollution data for grajau, BR, PM2.5: 10.54
# Retrieved pollution data for necochea, AR, PM2.5: 2.11
# Retrieved pollution data for jamestown, US, PM2.5: 0.5
# Retrieved pollution data for lerwick, GB, PM2.5: 2.63
# Retrieved pollution data for galliano, US, PM2.5: 10.54
# Retrieved pollution data for bayanaul, KZ, PM2.5: 4.18
# Retrieved pollution data for kone, NC, PM2.5: 1.47
# Retrieved pollution data for bankim, CM, PM2.5: 1.16
# Retrieved pollution data for belomorsk, RU, PM2.5: 0.5
# Retrieved pollution data for rurrenabaque, BO, PM2.5: 8.32
# Retrieved pollution data for mawu, CN, PM2.5: 8.4
# Retrieved pollution data for nova olimpia, BR, PM2.5: 2.33
# Retrieved pollution data for mazatlan, MX, PM2.5: 11.79
# Retrieved pollution data for huron, US, PM2.5: 0.5
# Retrieved pollution data for kikwit, CD, PM2.5: 16.41
# Retrieved pollution data for dwarka, IN, PM2.5: 25.52
# Retrieved pollution data for sidi qacem, MA, PM2.5: 2.04
# Retrieved pollution data for puerto armuelles, PA, PM2.5: 0.64
# Retrieved pollution data for chernyshevskiy, RU, PM2.5: 0.5
# Retrieved pollution data for aioun, MR, PM2.5: 48.99
# Retrieved pollution data for griffith, US, PM2.5: 1.46
# Retrieved pollution data for raduzhnyy, RU, PM2.5: 1.24
# Retrieved pollution data for mogocha, RU, PM2.5: 0.5
# Retrieved pollution data for port saint john's, ZA, PM2.5: 1.5
# Retrieved pollution data for vilyuchinsk, RU, PM2.5: 2.01
# Retrieved pollution data for revda, RU, PM2.5: 2.66
# Retrieved pollution data for lanark, GB, PM2.5: 5.8
# Retrieved pollution data for tadine, NC, PM2.5: 2.34
# Retrieved pollution data for qingdao, CN, PM2.5: 67.05
# Retrieved pollution data for rzhev, RU, PM2.5: 0.7
# Retrieved pollution data for hithadhoo, MV, PM2.5: 0.5
# Retrieved pollution data for constantia, RO, PM2.5: 20.3
# Retrieved pollution data for ta`u, AS, PM2.5: 2.71
# Retrieved pollution data for bodo, NO, PM2.5: 0.5
# Retrieved pollution data for vila franca do campo, PT, PM2.5: 2.29
# Retrieved pollution data for villamontes, BO, PM2.5: 8.06
# Retrieved pollution data for ust-tsilma, RU, PM2.5: 1.08
# Retrieved pollution data for tolanaro, MG, PM2.5: 2.47
# Retrieved pollution data for wabag, PG, PM2.5: 1.73
# Retrieved pollution data for gering, US, PM2.5: 4.01
# Retrieved pollution data for thames, NZ, PM2.5: 0.5
# Retrieved pollution data for launceston, AU, PM2.5: 1.61
# Retrieved pollution data for salvador, SV, PM2.5: 1.15
# Retrieved pollution data for iguaba grande, BR, PM2.5: 2.56
# Retrieved pollution data for sept-iles, CA, PM2.5: 0.5
# Retrieved pollution data for gornyak, RU, PM2.5: 5.1
# Retrieved pollution data for nikolayevka, RU, PM2.5: 1.32
# Retrieved pollution data for buenos aires, AR, PM2.5: 9.49
# Retrieved pollution data for wotho, MH, PM2.5: 1.21
# Retrieved pollution data for christiana, ZA, PM2.5: 5.53
# Retrieved pollution data for ust'-kut, RU, PM2.5: 0.5
# Retrieved pollution data for castillos, UY, PM2.5: 1.64
# Retrieved pollution data for teknaf, BD, PM2.5: 20.45
# Retrieved pollution data for yantzaza, EC, PM2.5: 0.83
# Retrieved pollution data for penzance, GB, PM2.5: 4.07
# Retrieved pollution data for chibougamau, CA, PM2.5: 0.5
# Retrieved pollution data for bechar, DZ, PM2.5: 7.2
# Retrieved pollution data for songea, TZ, PM2.5: 3.82
# Retrieved pollution data for la'ie, US, PM2.5: 3.02
# Retrieved pollution data for caconda, AO, PM2.5: 4.65
# Retrieved pollution data for pokrovsk, UA, PM2.5: 3.26
# Retrieved pollution data for camana, PE, PM2.5: 6.97
# Retrieved pollution data for middle island, US, PM2.5: 0.5
# Retrieved pollution data for burgersdorp, ZA, PM2.5: 2.23
# Retrieved pollution data for portland, US, PM2.5: 1.35
# Retrieved pollution data for new whiteland, US, PM2.5: 0.5
# Retrieved pollution data for an muileann gcearr, IE, PM2.5: 2.68
# Retrieved pollution data for east ballina, AU, PM2.5: 2.24
# Retrieved pollution data for aykhal, RU, PM2.5: 0.5
# Retrieved pollution data for calvi, FR, PM2.5: 8.68
# Retrieved pollution data for suva, FJ, PM2.5: 1.89
# Retrieved pollution data for ad dindar, SD, PM2.5: 16.7
# Retrieved pollution data for armacao de buzios, BR, PM2.5: 2.16
# Retrieved pollution data for visakhapatnam, IN, PM2.5: 12.7
# Retrieved pollution data for veraval, IN, PM2.5: 38.4
# Retrieved pollution data for hanceville, US, PM2.5: 2
# Retrieved pollution data for selfoss, IS, PM2.5: 0.77
# Retrieved pollution data for moree, AU, PM2.5: 2.22
# Retrieved pollution data for woolgoolga, AU, PM2.5: 1.41
# Retrieved pollution data for tukrah, LY, PM2.5: 5.41
# Retrieved pollution data for minas de marcona, PE, PM2.5: 4.44
# Retrieved pollution data for fort bragg, US, PM2.5: 2.08
# Retrieved pollution data for tambacounda, SN, PM2.5: 5.85
# Retrieved pollution data for swift current, CA, PM2.5: 4.18
# Retrieved pollution data for igarka, RU, PM2.5: 0.54
# Retrieved pollution data for novo aripuana, BR, PM2.5: 0.76
# Retrieved pollution data for toliara, MG, PM2.5: 2.6
# Retrieved pollution data for mercedes, AR, PM2.5: 2.65
# Retrieved pollution data for santo antonio, BR, PM2.5: 1.74
# Retrieved pollution data for sinabang, ID, PM2.5: 0.68
# Retrieved pollution data for gambela, ET, PM2.5: 6.28
# Retrieved pollution data for sutherlin, US, PM2.5: 0.5
# Retrieved pollution data for arno, SE, PM2.5: 0.5
# Retrieved pollution data for meizhou, CN, PM2.5: 48.89
# Retrieved pollution data for mejit, MH, PM2.5: 1.01
# Retrieved pollution data for utete, TZ, PM2.5: 3.84
# Retrieved pollution data for hovd, MN, PM2.5: 2.24
# Retrieved pollution data for panama city beach, US, PM2.5: 9.63
# Retrieved pollution data for kelso, US, PM2.5: 0.82
# Retrieved pollution data for garissa, KE, PM2.5: 3.22
# Retrieved pollution data for new norfolk, AU, PM2.5: 0.92
# Retrieved pollution data for tempio pausania, IT, PM2.5: 12.16
# Retrieved pollution data for nemuro, JP, PM2.5: 2.91
# Retrieved pollution data for mascote, BR, PM2.5: 2.19
# Retrieved pollution data for tynda, RU, PM2.5: 0.5
# Retrieved pollution data for inarajan village, GU, PM2.5: 0.5
# Retrieved pollution data for marivan, IR, PM2.5: 28.47
# Retrieved pollution data for morehead city, US, PM2.5: 3.07
# Retrieved pollution data for cockburn town, TC, PM2.5: 1.37
# Retrieved pollution data for thai nguyen, VN, PM2.5: 22.45
# Retrieved pollution data for chulym, RU, PM2.5: 2.04
# Retrieved pollution data for susuman, RU, PM2.5: 0.5
# Retrieved pollution data for hobyo, SO, PM2.5: 3.15
# Retrieved pollution data for siracusa, IT, PM2.5: 51.42
# Retrieved pollution data for cannonvale, AU, PM2.5: 1.6
# Retrieved pollution data for afaahiti, PF, PM2.5: 2
# Retrieved pollution data for pskov, RU, PM2.5: 0.5
# Retrieved pollution data for greymouth, NZ, PM2.5: 0.84
# Retrieved pollution data for port macquarie, AU, PM2.5: 1.29
# Retrieved pollution data for westport, US, PM2.5: 0.5
# Retrieved pollution data for svetlyy, RU, PM2.5: 0.5
# Retrieved pollution data for oujda-angad, MA, PM2.5: 6.12
# Retrieved pollution data for codrington, AU, PM2.5: 0.5
# Retrieved pollution data for howrah, IN, PM2.5: 378.96
# Retrieved pollution data for kingston, JM, PM2.5: 6.31
# Retrieved pollution data for aral, CN, PM2.5: 102.13
# Retrieved pollution data for mount gambier, AU, PM2.5: 1.41
# Retrieved pollution data for okhotsk, RU, PM2.5: 0.5
# Retrieved pollution data for rosamond, US, PM2.5: 7.58
# Retrieved pollution data for puerto vilelas, AR, PM2.5: 5.96
# Retrieved pollution data for nema, RU, PM2.5: 2.17
# Retrieved pollution data for nadi, FJ, PM2.5: 0.73
# Retrieved pollution data for kapa'a, US, PM2.5: 2.71
# Retrieved pollution data for edson, CA, PM2.5: 0.5
# Retrieved pollution data for venustiano carranza, MX, PM2.5: 23.21
# Retrieved pollution data for hachinohe, JP, PM2.5: 4.19
# Retrieved pollution data for mawlamyinegyunn, MM, PM2.5: 46.64
# Retrieved pollution data for pudasjarvi, FI, PM2.5: 0.5
# Retrieved pollution data for vodnyy, RU, PM2.5: 1.08
# Retrieved pollution data for richfield, US, PM2.5: 3.06
# Retrieved pollution data for thouars, FR, PM2.5: 3.25
# Retrieved pollution data for la passe, FR, PM2.5: 4.64
# Retrieved pollution data for ilheus, BR, PM2.5: 2.57
# Retrieved pollution data for safotu, WS, PM2.5: 2.68
# Retrieved pollution data for callao, PE, PM2.5: 6.56
# Retrieved pollution data for cananea, MX, PM2.5: 2.07
# Retrieved pollution data for kerikeri, NZ, PM2.5: 0.7
# Retrieved pollution data for balabac, PH, PM2.5: 1.43
# Retrieved pollution data for albertina, BR, PM2.5: 11.88
# Retrieved pollution data for belyy yar, RU, PM2.5: 5.29
# Retrieved pollution data for hirara, JP, PM2.5: 2.42
#            City Country  PM2.5  PM10   NO2     O3   SO2      CO   NH3
# 0         tiksi      RU   0.50  1.78  0.18  58.65  0.06  243.66  0.00
# 1      waitangi      NZ   0.83  2.33  0.02  61.51  0.08  223.64  0.00
# 2      thompson      CA   0.50  0.54  0.72  58.65  0.37  211.95  0.20
# 3  punta arenas      CL   0.50  0.67  0.04  47.92  0.03  223.64  0.14
# 4     carnarvon      AU   0.72  2.39  0.17  58.65  0.18  220.30  0.02

# %%
# Create a dictionary to store city-country pairs
city_country_map = {}

for city in city_names:
    try:
        query_url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}"
        response = requests.get(query_url).json()
        
        # Store the city and corresponding country code
        country = response['sys']['country']
        city_country_map[city] = country

        # Print city and country
        print(f"City: {city}, Country: {country}")

    except KeyError as key_err:
        print(f"KeyError: {key_err} for {city}. Skipping...")
    except requests.exceptions.RequestException as req_err:
        print(f"Request error: {req_err} for {city}. Skipping...")

    # Pause to avoid rate limiting
    time.sleep(1)

print(city_country_map)
# Out:
# City: tiksi, Country: RU
# City: waitangi, Country: NZ
# City: thompson, Country: CA
# City: punta arenas, Country: CL
# City: carnarvon, Country: AU
# City: bilibino, Country: RU
# City: puerto natales, Country: CL
# City: kulhudhuffushi, Country: MV
# City: albany, Country: US
# City: ribeira grande, Country: PT
# City: touros, Country: BR
# City: chonchi, Country: CL
# City: port-aux-francais, Country: TF
# City: avarua, Country: CK
# City: hadibu, Country: YE
# City: arraial do cabo, Country: BR
# City: nguigmi, Country: NE
# City: ushuaia, Country: AR
# City: invercargill, Country: NZ
# City: tura, Country: IN
# City: vernon, Country: CA
# City: blackmans bay, Country: AU
# City: malanje, Country: AO
# City: bandarbeyla, Country: SO
# City: iqaluit, Country: CA
# City: mbaiki, Country: CF
# City: narasannapeta, Country: IN
# City: adamstown, Country: PN
# City: baley, Country: RU
# City: vilyuysk, Country: RU
# City: taulaga, Country: AS
# City: vrangel', Country: RU
# City: san fernando del valle de catamarca, Country: AR
# City: holualoa, Country: US
# City: grytviken, Country: GS
# City: beau vallon, Country: MU
# City: papatowai, Country: NZ
# City: polyarnyy, Country: RU
# City: rio grande, Country: BR
# City: west island, Country: CC
# City: menongue, Country: AO
# City: margaret river, Country: AU
# City: utrik, Country: MH
# City: harper, Country: LR
# City: mar del plata, Country: AR
# City: yatou, Country: CN
# City: sitka, Country: US
# City: hermanus, Country: ZA
# City: kodiak, Country: US
# City: petropavlovsk-kamchatsky, Country: RU
# City: happy valley-goose bay, Country: CA
# City: thunder bay, Country: CA
# City: bredasdorp, Country: ZA
# City: aasiaat, Country: GL
# City: basco, Country: PH
# City: sao joao da barra, Country: BR
# City: aktau, Country: KZ
# City: xinyuan, Country: CN
# City: talnakh, Country: RU
# City: chipata, Country: ZM
# City: hasaki, Country: JP
# City: ilulissat, Country: GL
# City: puerto ayora, Country: EC
# City: geraldton, Country: AU
# City: humaita, Country: BR
# City: isla aguada, Country: MX
# City: safford, Country: US
# City: skeldon, Country: GY
# City: ust-nera, Country: RU
# City: abong mbang, Country: CM
# City: yellowknife, Country: CA
# City: olonkinbyen, Country: SJ
# City: uturoa, Country: PF
# City: quimili, Country: AR
# City: gubkinskiy, Country: RU
# City: edinburgh of the seven seas, Country: SH
# City: puerto colombia, Country: CO
# City: villa gesell, Country: AR
# City: grand falls-windsor, Country: CA
# City: kavaratti, Country: IN
# City: saint-francois, Country: FR
# City: klaksvik, Country: FO
# City: lahaina, Country: US
# City: faya-largeau, Country: TD
# City: amble, Country: GB
# City: lorengau, Country: PG
# City: katsuren-haebaru, Country: JP
# City: nurota, Country: UZ
# City: weno, Country: FM
# City: bethel, Country: US
# City: aketi, Country: CD
# City: brandon, Country: US
# City: maintirano, Country: MG
# City: taveta, Country: KE
# City: st. john's, Country: CA
# City: longyearbyen, Country: SJ
# City: sagua la grande, Country: CU
# City: amga, Country: RU
# City: huanuni, Country: BO
# City: saipan, Country: MP
# City: sao tome, Country: ST
# City: pisco, Country: PE
# City: vuktyl, Country: RU
# City: port elizabeth, Country: ZA
# City: susanville, Country: US
# City: carloforte, Country: IT
# City: gizo, Country: SB
# City: punta del este, Country: UY
# City: rabo de peixe, Country: PT
# City: sydney mines, Country: CA
# City: vorgashor, Country: RU
# City: l'isle-jourdain, Country: FR
# City: praia da vitoria, Country: PT
# City: newman, Country: US
# City: ulysses, Country: US
# City: daoukro, Country: CI
# City: prince albert, Country: CA
# City: wailua homesteads, Country: US
# City: cabo san lucas, Country: MX
# City: challapata, Country: BO
# City: qamdo, Country: CN
# City: ancud, Country: CL
# City: ornskoldsvik, Country: SE
# City: jilib, Country: SO
# City: al bawiti, Country: EG
# City: taltal, Country: CL
# City: kailua-kona, Country: US
# City: jorpeland, Country: NO
# City: iskateley, Country: RU
# City: atafu village, Country: TK
# City: nogliki, Country: RU
# City: keflavik, Country: IS
# City: puerto baquerizo moreno, Country: EC
# City: malango, Country: ID
# City: klyuchi, Country: RU
# City: tougan, Country: BF
# City: tual, Country: ID
# City: arteche, Country: PH
# City: acarau, Country: BR
# City: port-vila, Country: VU
# City: kavieng, Country: PG
# City: santarem, Country: BR
# City: severo-yeniseyskiy, Country: RU
# City: colonia, Country: DE
# City: posto fiscal rolim de moura, Country: BR
# City: fuerte olimpo, Country: PY
# City: palikir - national government center, Country: FM
# City: bich'vinta, Country: GE
# City: qarah zia' od din, Country: IR
# City: parfino, Country: RU
# City: arawa, Country: PG
# City: enewetak, Country: MH
# City: balaka, Country: MW
# City: kijang, Country: KR
# City: isafjordur, Country: IS
# City: aluksne, Country: LV
# City: coracora, Country: PE
# City: tezu, Country: IN
# City: khasab, Country: OM
# City: kolosovka, Country: RU
# City: lebu, Country: CL
# City: kapuskasing, Country: CA
# City: puerto ayacucho, Country: VE
# City: sidney, Country: AU
# City: east london, Country: ZA
# City: korop, Country: UA
# City: brookings, Country: US
# City: thinadhoo, Country: MV
# City: axim, Country: GH
# City: alice springs, Country: AU
# City: belmonte, Country: BR
# City: nelsonville, Country: US
# City: port alfred, Country: ZA
# City: qaqortoq, Country: GL
# City: poronaysk, Country: RU
# City: lompoc, Country: US
# City: nchelenge, Country: ZM
# City: akureyri, Country: IS
# City: margate, Country: GB
# City: anadyr, Country: RU
# City: el porvenir, Country: HN
# City: fale old settlement, Country: TK
# City: georgetown, Country: MY
# City: puerto carreno, Country: CO
# City: zykovo, Country: RU
# City: nakhon thai, Country: TH
# City: luganville, Country: VU
# City: piti village, Country: GU
# City: francistown, Country: BW
# City: kirensk, Country: RU
# City: xining, Country: CN
# City: shibirghan, Country: AF
# City: port lincoln, Country: AU
# City: yuzhno-kurilsk, Country: RU
# City: poiana teiului, Country: RO
# City: hamilton, Country: US
# City: karratha, Country: AU
# City: vorkuta, Country: RU
# City: san patricio, Country: US
# City: pacific grove, Country: US
# City: viitasaari, Country: FI
# City: great falls, Country: US
# City: hampton bays, Country: US
# City: zeya, Country: RU
# City: saint-philippe, Country: RE
# City: zakynthos, Country: GR
# City: camocim, Country: BR
# City: darwin, Country: AU
# City: port said, Country: EG
# City: port mathurin, Country: MU
# City: ixtapa, Country: MX
# City: santiago papasquiaro, Country: MX
# City: remire-montjoly, Country: GF
# City: balkanabat, Country: TM
# City: mata-utu, Country: WF
# City: kenora, Country: CA
# City: santa cruz, Country: BO
# City: jacksonville beach, Country: US
# City: sinop, Country: TR
# City: lihue, Country: US
# City: christchurch, Country: NZ
# City: tonghae, Country: KR
# City: mirnyy, Country: RU
# City: kostomuksha, Country: RU
# City: siwa oasis, Country: EG
# City: rouissat, Country: DZ
# City: muslyumovo, Country: RU
# City: vadso, Country: NO
# City: queenstown, Country: ZA
# City: dazhou, Country: CN
# City: beledweyne, Country: SO
# City: badger, Country: US
# City: cadale, Country: SO
# City: udachny, Country: RU
# City: rutana, Country: BI
# City: astorga, Country: BR
# City: eraan, Country: PH
# City: dudinka, Country: RU
# City: jwaneng, Country: BW
# City: kachug, Country: RU
# City: amursk, Country: RU
# City: dunedin, Country: NZ
# City: haiku-pauwela, Country: US
# City: paracuru, Country: BR
# City: lucon, Country: FR
# City: thabazimbi, Country: ZA
# City: alaghsas, Country: NE
# City: oranjemund, Country: NA
# City: stanley, Country: GB
# City: whitehorse, Country: CA
# City: mandera, Country: KE
# City: flying fish cove, Country: CX
# City: staryy dobrotvir, Country: UA
# City: caleta de carquin, Country: PE
# City: nar'yan-mar, Country: RU
# City: yeniseysk, Country: RU
# City: pospelikha, Country: RU
# City: fiche, Country: ET
# City: domanivka, Country: UA
# City: tannum sands, Country: AU
# City: alotau, Country: PG
# City: egilsstadir, Country: IS
# City: hawaiian paradise park, Country: US
# City: port blair, Country: IN
# City: azhikkal, Country: IN
# City: bikenibeu village, Country: KI
# City: at-bashi, Country: KG
# City: atar, Country: MR
# City: bamboo flat, Country: IN
# City: korba, Country: IN
# City: grajau, Country: BR
# City: necochea, Country: AR
# City: jamestown, Country: US
# City: lerwick, Country: GB
# City: galliano, Country: US
# City: bayanaul, Country: KZ
# City: kone, Country: NC
# City: bankim, Country: CM
# City: belomorsk, Country: RU
# City: rurrenabaque, Country: BO
# City: mawu, Country: CN
# City: nova olimpia, Country: BR
# City: mazatlan, Country: MX
# City: huron, Country: US
# City: kikwit, Country: CD
# City: dwarka, Country: IN
# City: sidi qacem, Country: MA
# City: puerto armuelles, Country: PA
# City: chernyshevskiy, Country: RU
# City: aioun, Country: MR
# City: griffith, Country: US
# City: raduzhnyy, Country: RU
# City: mogocha, Country: RU
# City: port saint john's, Country: ZA
# City: vilyuchinsk, Country: RU
# City: revda, Country: RU
# City: lanark, Country: GB
# City: tadine, Country: NC
# City: qingdao, Country: CN
# City: rzhev, Country: RU
# City: hithadhoo, Country: MV
# City: constantia, Country: RO
# City: ta`u, Country: AS
# City: bodo, Country: NO
# City: vila franca do campo, Country: PT
# City: villamontes, Country: BO
# City: ust-tsilma, Country: RU
# City: tolanaro, Country: MG
# City: wabag, Country: PG
# City: gering, Country: US
# City: thames, Country: NZ
# City: launceston, Country: AU
# City: salvador, Country: SV
# City: iguaba grande, Country: BR
# City: sept-iles, Country: CA
# City: gornyak, Country: RU
# City: nikolayevka, Country: RU
# City: buenos aires, Country: AR
# City: wotho, Country: MH
# City: christiana, Country: ZA
# City: ust'-kut, Country: RU
# City: castillos, Country: UY
# City: teknaf, Country: BD
# City: yantzaza, Country: EC
# City: penzance, Country: GB
# City: chibougamau, Country: CA
# City: bechar, Country: DZ
# City: songea, Country: TZ
# City: la'ie, Country: US
# City: caconda, Country: AO
# City: pokrovsk, Country: UA
# City: camana, Country: PE
# City: middle island, Country: US
# City: burgersdorp, Country: ZA
# City: portland, Country: US
# City: new whiteland, Country: US
# City: an muileann gcearr, Country: IE
# City: east ballina, Country: AU
# City: aykhal, Country: RU
# City: calvi, Country: FR
# City: suva, Country: FJ
# City: ad dindar, Country: SD
# City: armacao de buzios, Country: BR
# City: visakhapatnam, Country: IN
# City: veraval, Country: IN
# City: hanceville, Country: US
# City: selfoss, Country: IS
# City: moree, Country: AU
# City: woolgoolga, Country: AU
# City: tukrah, Country: LY
# City: minas de marcona, Country: PE
# City: fort bragg, Country: US
# City: tambacounda, Country: SN
# City: swift current, Country: CA
# City: igarka, Country: RU
# City: novo aripuana, Country: BR
# City: toliara, Country: MG
# City: mercedes, Country: AR
# City: santo antonio, Country: BR
# City: sinabang, Country: ID
# City: gambela, Country: ET
# City: sutherlin, Country: US
# City: arno, Country: SE
# City: meizhou, Country: CN
# City: mejit, Country: MH
# City: utete, Country: TZ
# City: hovd, Country: MN
# City: panama city beach, Country: US
# City: kelso, Country: US
# City: garissa, Country: KE
# City: new norfolk, Country: AU
# City: tempio pausania, Country: IT
# City: nemuro, Country: JP
# City: mascote, Country: BR
# City: tynda, Country: RU
# City: inarajan village, Country: GU
# City: marivan, Country: IR
# City: morehead city, Country: US
# City: cockburn town, Country: TC
# City: thai nguyen, Country: VN
# City: chulym, Country: RU
# City: susuman, Country: RU
# City: hobyo, Country: SO
# City: siracusa, Country: IT
# City: cannonvale, Country: AU
# City: afaahiti, Country: PF
# City: pskov, Country: RU
# City: greymouth, Country: NZ
# City: port macquarie, Country: AU
# City: westport, Country: US
# City: svetlyy, Country: RU
# City: oujda-angad, Country: MA
# City: codrington, Country: AU
# City: howrah, Country: IN
# City: kingston, Country: JM
# City: aral, Country: CN
# City: mount gambier, Country: AU
# City: okhotsk, Country: RU
# City: rosamond, Country: US
# City: puerto vilelas, Country: AR
# City: nema, Country: RU
# City: nadi, Country: FJ
# City: kapa'a, Country: US
# City: edson, Country: CA
# City: venustiano carranza, Country: MX
# City: hachinohe, Country: JP
# City: mawlamyinegyunn, Country: MM
# City: pudasjarvi, Country: FI
# City: vodnyy, Country: RU
# City: richfield, Country: US
# City: thouars, Country: FR
# City: la passe, Country: FR
# City: ilheus, Country: BR
# City: safotu, Country: WS
# City: callao, Country: PE
# City: cananea, Country: MX
# City: kerikeri, Country: NZ
# City: balabac, Country: PH
# City: albertina, Country: BR
# City: belyy yar, Country: RU
# City: hirara, Country: JP
# {'tiksi': 'RU', 'waitangi': 'NZ', 'thompson': 'CA', 'punta arenas': 'CL', 'carnarvon': 'AU', 'bilibino': 'RU', 'puerto natales': 'CL', 'kulhudhuffushi': 'MV', 'albany': 'US', 'ribeira grande': 'PT', 'touros': 'BR', 'chonchi': 'CL', 'port-aux-francais': 'TF', 'avarua': 'CK', 'hadibu': 'YE', 'arraial do cabo': 'BR', 'nguigmi': 'NE', 'ushuaia': 'AR', 'invercargill': 'NZ', 'tura': 'IN', 'vernon': 'CA', 'blackmans bay': 'AU', 'malanje': 'AO', 'bandarbeyla': 'SO', 'iqaluit': 'CA', 'mbaiki': 'CF', 'narasannapeta': 'IN', 'adamstown': 'PN', 'baley': 'RU', 'vilyuysk': 'RU', 'taulaga': 'AS', "vrangel'": 'RU', 'san fernando del valle de catamarca': 'AR', 'holualoa': 'US', 'grytviken': 'GS', 'beau vallon': 'MU', 'papatowai': 'NZ', 'polyarnyy': 'RU', 'rio grande': 'BR', 'west island': 'CC', 'menongue': 'AO', 'margaret river': 'AU', 'utrik': 'MH', 'harper': 'LR', 'mar del plata': 'AR', 'yatou': 'CN', 'sitka': 'US', 'hermanus': 'ZA', 'kodiak': 'US', 'petropavlovsk-kamchatsky': 'RU', 'happy valley-goose bay': 'CA', 'thunder bay': 'CA', 'bredasdorp': 'ZA', 'aasiaat': 'GL', 'basco': 'PH', 'sao joao da barra': 'BR', 'aktau': 'KZ', 'xinyuan': 'CN', 'talnakh': 'RU', 'chipata': 'ZM', 'hasaki': 'JP', 'ilulissat': 'GL', 'puerto ayora': 'EC', 'geraldton': 'AU', 'humaita': 'BR', 'isla aguada': 'MX', 'safford': 'US', 'skeldon': 'GY', 'ust-nera': 'RU', 'abong mbang': 'CM', 'yellowknife': 'CA', 'olonkinbyen': 'SJ', 'uturoa': 'PF', 'quimili': 'AR', 'gubkinskiy': 'RU', 'edinburgh of the seven seas': 'SH', 'puerto colombia': 'CO', 'villa gesell': 'AR', 'grand falls-windsor': 'CA', 'kavaratti': 'IN', 'saint-francois': 'FR', 'klaksvik': 'FO', 'lahaina': 'US', 'faya-largeau': 'TD', 'amble': 'GB', 'lorengau': 'PG', 'katsuren-haebaru': 'JP', 'nurota': 'UZ', 'weno': 'FM', 'bethel': 'US', 'aketi': 'CD', 'brandon': 'US', 'maintirano': 'MG', 'taveta': 'KE', "st. john's": 'CA', 'longyearbyen': 'SJ', 'sagua la grande': 'CU', 'amga': 'RU', 'huanuni': 'BO', 'saipan': 'MP', 'sao tome': 'ST', 'pisco': 'PE', 'vuktyl': 'RU', 'port elizabeth': 'ZA', 'susanville': 'US', 'carloforte': 'IT', 'gizo': 'SB', 'punta del este': 'UY', 'rabo de peixe': 'PT', 'sydney mines': 'CA', 'vorgashor': 'RU', "l'isle-jourdain": 'FR', 'praia da vitoria': 'PT', 'newman': 'US', 'ulysses': 'US', 'daoukro': 'CI', 'prince albert': 'CA', 'wailua homesteads': 'US', 'cabo san lucas': 'MX', 'challapata': 'BO', 'qamdo': 'CN', 'ancud': 'CL', 'ornskoldsvik': 'SE', 'jilib': 'SO', 'al bawiti': 'EG', 'taltal': 'CL', 'kailua-kona': 'US', 'jorpeland': 'NO', 'iskateley': 'RU', 'atafu village': 'TK', 'nogliki': 'RU', 'keflavik': 'IS', 'puerto baquerizo moreno': 'EC', 'malango': 'ID', 'klyuchi': 'RU', 'tougan': 'BF', 'tual': 'ID', 'arteche': 'PH', 'acarau': 'BR', 'port-vila': 'VU', 'kavieng': 'PG', 'santarem': 'BR', 'severo-yeniseyskiy': 'RU', 'colonia': 'DE', 'posto fiscal rolim de moura': 'BR', 'fuerte olimpo': 'PY', 'palikir - national government center': 'FM', "bich'vinta": 'GE', "qarah zia' od din": 'IR', 'parfino': 'RU', 'arawa': 'PG', 'enewetak': 'MH', 'balaka': 'MW', 'kijang': 'KR', 'isafjordur': 'IS', 'aluksne': 'LV', 'coracora': 'PE', 'tezu': 'IN', 'khasab': 'OM', 'kolosovka': 'RU', 'lebu': 'CL', 'kapuskasing': 'CA', 'puerto ayacucho': 'VE', 'sidney': 'AU', 'east london': 'ZA', 'korop': 'UA', 'brookings': 'US', 'thinadhoo': 'MV', 'axim': 'GH', 'alice springs': 'AU', 'belmonte': 'BR', 'nelsonville': 'US', 'port alfred': 'ZA', 'qaqortoq': 'GL', 'poronaysk': 'RU', 'lompoc': 'US', 'nchelenge': 'ZM', 'akureyri': 'IS', 'margate': 'GB', 'anadyr': 'RU', 'el porvenir': 'HN', 'fale old settlement': 'TK', 'georgetown': 'MY', 'puerto carreno': 'CO', 'zykovo': 'RU', 'nakhon thai': 'TH', 'luganville': 'VU', 'piti village': 'GU', 'francistown': 'BW', 'kirensk': 'RU', 'xining': 'CN', 'shibirghan': 'AF', 'port lincoln': 'AU', 'yuzhno-kurilsk': 'RU', 'poiana teiului': 'RO', 'hamilton': 'US', 'karratha': 'AU', 'vorkuta': 'RU', 'san patricio': 'US', 'pacific grove': 'US', 'viitasaari': 'FI', 'great falls': 'US', 'hampton bays': ...

# %%
air_quality_df.to_csv('Resources/air_quality_data.csv', index=False)

# %%
print(f"Total cities: {len(city_country_map)}")
# Out:
# Total cities: 421

# %%
data = list(city_country_map.items())

# Create the DataFrame
df = pd.DataFrame(data, columns=['City', 'Country'])

# Save the DataFrame to a CSV file
df.to_csv('Resources/city_country_map.csv', index=False, encoding='utf-8')

# %%
# Get all the unique countries from the city-country map
unique_countries = set(city_country_map.values())

# Print the count and the list of unique countries
print(f"Total unique countries: {len(unique_countries)}")
print(unique_countries)
# Out:
# Total unique countries: 117
# {'RE', 'DE', 'IR', 'SJ', 'OM', 'MX', 'CN', 'PT', 'LR', 'ID', 'ZA', 'SN', 'EG', 'UZ', 'AS', 'PY', 'GE', 'BW', 'MM', 'CF', 'PE', 'CU', 'ET', 'PA', 'IS', 'IE', 'NA', 'PG', 'WS', 'TH', 'KG', 'EC', 'KZ', 'ST', 'NO', 'BR', 'BO', 'AF', 'JM', 'FR', 'MU', 'GS', 'SB', 'TM', 'GY', 'US', 'AO', 'CD', 'KR', 'KI', 'CI', 'GB', 'AR', 'RO', 'TD', 'PF', 'SD', 'CA', 'TC', 'VN', 'SO', 'BF', 'CM', 'MR', 'ZM', 'MA', 'CL', 'HN', 'SE', 'JP', 'MH', 'VE', 'IN', 'LY', 'RU', 'SH', 'TR', 'TK', 'FI', 'BI', 'AU', 'GU', 'SV', 'MY', 'KE', 'UA', 'DZ', 'LV', 'CK', 'FJ', 'MV', 'GR', 'CO', 'MN', 'IT', 'TF', 'GL', 'VU', 'FO', 'UY', 'WF', 'TZ', 'CC', 'MW', 'GH', 'CX', 'NE', 'YE', 'BD', 'MP', 'GF', 'PN', 'MG', 'NC', 'PH', 'FM', 'NZ'}

# %%
import pycountry

# WHO API: Get all available countries and their alpha-3 codes
who_url = "https://ghoapi.azureedge.net/api/DIMENSION/COUNTRY/DimensionValues"
who_response = requests.get(who_url).json()

# Convert WHO countries from alpha-3 to alpha-2 codes to be matched withOpenWeather Country Code
who_countries_alpha2 = {}

for entry in who_response['value']:
    alpha_3 = entry['Code']
    country_name = entry['Title']

    # Convert alpha-3 to alpha-2 code using pycountry
    try:
        alpha_2 = pycountry.countries.get(alpha_3=alpha_3).alpha_2
        who_countries_alpha2[alpha_2] = country_name
    except AttributeError:
        print(f"Skipping {alpha_3} - No matching alpha-2 code found.")

print(f"WHO Countries (alpha-2): {who_countries_alpha2}")

who_country_codes = who_countries_alpha2.keys()
print(f"WHO Country Codes: {list(who_country_codes)}")
# Out:
# Skipping CHI - No matching alpha-2 code found.
# Skipping ME1 - No matching alpha-2 code found.
# Skipping SDN736 - No matching alpha-2 code found.
# Skipping XKX - No matching alpha-2 code found.
# WHO Countries (alpha-2): {'AW': 'Aruba', 'AF': 'Afghanistan', 'AO': 'Angola', 'AI': 'Anguilla', 'AL': 'Albania', 'AD': 'Andorra', 'AE': 'United Arab Emirates', 'AR': 'Argentina', 'AM': 'Armenia', 'AS': 'American Samoa', 'AG': 'Antigua and Barbuda', 'AU': 'Australia', 'AT': 'Austria', 'AZ': 'Azerbaijan', 'BI': 'Burundi', 'BE': 'Belgium', 'BJ': 'Benin', 'BQ': 'Bonaire, Saint Eustatius and Saba', 'BF': 'Burkina Faso', 'BD': 'Bangladesh', 'BG': 'Bulgaria', 'BH': 'Bahrain', 'BS': 'Bahamas', 'BA': 'Bosnia and Herzegovina', 'BY': 'Belarus', 'BZ': 'Belize', 'BM': 'Bermuda', 'BO': 'Bolivia (Plurinational State of)', 'BR': 'Brazil', 'BB': 'Barbados', 'BN': 'Brunei Darussalam', 'BT': 'Bhutan', 'BW': 'Botswana', 'CF': 'Central African Republic', 'CA': 'Canada', 'CH': 'Switzerland', 'CL': 'Chile', 'CN': 'China', 'CI': "Cote d'Ivoire", 'CM': 'Cameroon', 'CD': 'Democratic Republic of the Congo', 'CG': 'Congo', 'CK': 'Cook Islands', 'CO': 'Colombia', 'KM': 'Comoros', 'CV': 'Cabo Verde', 'CR': 'Costa Rica', 'CU': 'Cuba', 'CW': 'Curaçao', 'KY': 'Cayman Islands', 'CY': 'Cyprus', 'CZ': 'Czechia', 'DE': 'Germany', 'DJ': 'Djibouti', 'DM': 'Dominica', 'DK': 'Denmark', 'DO': 'Dominican Republic', 'DZ': 'Algeria', 'EC': 'Ecuador', 'EG': 'Egypt', 'ER': 'Eritrea', 'ES': 'Spain', 'EE': 'Estonia', 'ET': 'Ethiopia', 'FI': 'Finland', 'FJ': 'Fiji', 'FK': 'Falkland Islands (Malvinas)', 'FR': 'France', 'FO': 'Faroe Islands', 'FM': 'Micronesia (Federated States of)', 'GA': 'Gabon', 'GB': 'United Kingdom of Great Britain and Northern Ireland', 'GE': 'Georgia', 'GH': 'Ghana', 'GI': 'Gibraltar', 'GN': 'Guinea', 'GP': 'Guadeloupe', 'GM': 'Gambia', 'GW': 'Guinea-Bissau', 'GQ': 'Equatorial Guinea', 'GR': 'Greece', 'GD': 'Grenada', 'GL': 'Greenland', 'GT': 'Guatemala', 'GF': 'French Guiana', 'GU': 'Guam', 'GY': 'Guyana', 'HK': 'China, Hong Kong Special Administrative Region', 'HN': 'Honduras', 'HR': 'Croatia', 'HT': 'Haiti', 'HU': 'Hungary', 'ID': 'Indonesia', 'IM': 'Isle of Man', 'IN': 'India', 'IE': 'Ireland', 'IR': 'Iran (Islamic Republic of)', 'IQ': 'Iraq', 'IS': 'Iceland', 'IL': 'Israel', 'IT': 'Italy', 'JM': 'Jamaica', 'JO': 'Jordan', 'JP': 'Japan', 'KZ': 'Kazakhstan', 'KE': 'Kenya', 'KG': 'Kyrgyzstan', 'KH': 'Cambodia', 'KI': 'Kiribati', 'KN': 'Saint Kitts and Nevis', 'KR': 'Republic of Korea', 'KW': 'Kuwait', 'LA': "Lao People's Democratic Republic", 'LB': 'Lebanon', 'LR': 'Liberia', 'LY': 'Libya', 'LC': 'Saint Lucia', 'LI': 'Liechtenstein', 'LK': 'Sri Lanka', 'LS': 'Lesotho', 'LT': 'Lithuania', 'LU': 'Luxembourg', 'LV': 'Latvia', 'MO': 'China, Macao Special Administrative Region', 'MA': 'Morocco', 'MC': 'Monaco', 'MD': 'Republic of Moldova', 'MG': 'Madagascar', 'MV': 'Maldives', 'MX': 'Mexico', 'MH': 'Marshall Islands', 'MK': 'North Macedonia', 'ML': 'Mali', 'MT': 'Malta', 'MM': 'Myanmar', 'ME': 'Montenegro', 'MN': 'Mongolia', 'MP': 'Northern Mariana Islands', 'MZ': 'Mozambique', 'MR': 'Mauritania', 'MS': 'Montserrat', 'MQ': 'Martinique', 'MU': 'Mauritius', 'MW': 'Malawi', 'MY': 'Malaysia', 'YT': 'Mayotte', 'NA': 'Namibia', 'NC': 'New Caledonia', 'NE': 'Niger', 'NG': 'Nigeria', 'NI': 'Nicaragua', 'NU': 'Niue', 'NL': 'Netherlands (Kingdom of the)', 'NO': 'Norway', 'NP': 'Nepal', 'NR': 'Nauru', 'NZ': 'New Zealand', 'OM': 'Oman', 'PK': 'Pakistan', 'PA': 'Panama', 'PE': 'Peru', 'PH': 'Philippines', 'PW': 'Palau', 'PG': 'Papua New Guinea', 'PL': 'Poland', 'PR': 'Puerto Rico', 'KP': "Democratic People's Republic of Korea", 'PT': 'Portugal', 'PY': 'Paraguay', 'PS': 'occupied Palestinian territory, including east Jerusalem', 'PF': 'French Polynesia', 'QA': 'Qatar', 'RE': 'Reunion', 'RO': 'Romania', 'RU': 'Russian Federation', 'RW': 'Rwanda', 'SA': 'Saudi Arabia', 'SD': 'Sudan', 'SN': 'Senegal', 'SG': 'Singapore', 'SH': 'Saint Helena', 'SB': 'Solomon Islands', 'SL': 'Sierra Leone', 'SV': 'El Salvador', 'SM': 'San Marino', 'SO': 'Somalia', 'PM': 'Saint Pierre and Miquelon', 'RS': 'Serbia', 'SS': 'South Sudan', 'ST': 'Sao Tome and Principe', 'SR': 'Suriname', 'SK': 'Slo ...
# WHO Country Codes: ['AW', 'AF', 'AO', 'AI', 'AL', 'AD', 'AE', 'AR', 'AM', 'AS', 'AG', 'AU', 'AT', 'AZ', 'BI', 'BE', 'BJ', 'BQ', 'BF', 'BD', 'BG', 'BH', 'BS', 'BA', 'BY', 'BZ', 'BM', 'BO', 'BR', 'BB', 'BN', 'BT', 'BW', 'CF', 'CA', 'CH', 'CL', 'CN', 'CI', 'CM', 'CD', 'CG', 'CK', 'CO', 'KM', 'CV', 'CR', 'CU', 'CW', 'KY', 'CY', 'CZ', 'DE', 'DJ', 'DM', 'DK', 'DO', 'DZ', 'EC', 'EG', 'ER', 'ES', 'EE', 'ET', 'FI', 'FJ', 'FK', 'FR', 'FO', 'FM', 'GA', 'GB', 'GE', 'GH', 'GI', 'GN', 'GP', 'GM', 'GW', 'GQ', 'GR', 'GD', 'GL', 'GT', 'GF', 'GU', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IM', 'IN', 'IE', 'IR', 'IQ', 'IS', 'IL', 'IT', 'JM', 'JO', 'JP', 'KZ', 'KE', 'KG', 'KH', 'KI', 'KN', 'KR', 'KW', 'LA', 'LB', 'LR', 'LY', 'LC', 'LI', 'LK', 'LS', 'LT', 'LU', 'LV', 'MO', 'MA', 'MC', 'MD', 'MG', 'MV', 'MX', 'MH', 'MK', 'ML', 'MT', 'MM', 'ME', 'MN', 'MP', 'MZ', 'MR', 'MS', 'MQ', 'MU', 'MW', 'MY', 'YT', 'NA', 'NC', 'NE', 'NG', 'NI', 'NU', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PK', 'PA', 'PE', 'PH', 'PW', 'PG', 'PL', 'PR', 'KP', 'PT', 'PY', 'PS', 'PF', 'QA', 'RE', 'RO', 'RU', 'RW', 'SA', 'SD', 'SN', 'SG', 'SH', 'SB', 'SL', 'SV', 'SM', 'SO', 'PM', 'RS', 'SS', 'ST', 'SR', 'SK', 'SI', 'SE', 'SZ', 'SX', 'SC', 'SY', 'TC', 'TD', 'TG', 'TH', 'TJ', 'TK', 'TM', 'TL', 'TO', 'TT', 'TN', 'TR', 'TV', 'TZ', 'UG', 'UA', 'UY', 'US', 'UZ', 'VC', 'VE', 'VG', 'VI', 'VN', 'VU', 'WF', 'WS', 'YE', 'ZA', 'ZM', 'ZW']

# %%
# Filter cities where the country code exists in the WHO data
filtered_cities = {
    city: code for city, code in city_country_map.items() if code in who_country_codes
}

print(f"Cities with matching WHO data: {len(filtered_cities)}")
print(filtered_cities)
# Out:
# Cities with matching WHO data: 414
# {'tiksi': 'RU', 'waitangi': 'NZ', 'thompson': 'CA', 'punta arenas': 'CL', 'carnarvon': 'AU', 'bilibino': 'RU', 'puerto natales': 'CL', 'kulhudhuffushi': 'MV', 'albany': 'US', 'ribeira grande': 'PT', 'touros': 'BR', 'chonchi': 'CL', 'avarua': 'CK', 'hadibu': 'YE', 'arraial do cabo': 'BR', 'nguigmi': 'NE', 'ushuaia': 'AR', 'invercargill': 'NZ', 'tura': 'IN', 'vernon': 'CA', 'blackmans bay': 'AU', 'malanje': 'AO', 'bandarbeyla': 'SO', 'iqaluit': 'CA', 'mbaiki': 'CF', 'narasannapeta': 'IN', 'baley': 'RU', 'vilyuysk': 'RU', 'taulaga': 'AS', "vrangel'": 'RU', 'san fernando del valle de catamarca': 'AR', 'holualoa': 'US', 'beau vallon': 'MU', 'papatowai': 'NZ', 'polyarnyy': 'RU', 'rio grande': 'BR', 'menongue': 'AO', 'margaret river': 'AU', 'utrik': 'MH', 'harper': 'LR', 'mar del plata': 'AR', 'yatou': 'CN', 'sitka': 'US', 'hermanus': 'ZA', 'kodiak': 'US', 'petropavlovsk-kamchatsky': 'RU', 'happy valley-goose bay': 'CA', 'thunder bay': 'CA', 'bredasdorp': 'ZA', 'aasiaat': 'GL', 'basco': 'PH', 'sao joao da barra': 'BR', 'aktau': 'KZ', 'xinyuan': 'CN', 'talnakh': 'RU', 'chipata': 'ZM', 'hasaki': 'JP', 'ilulissat': 'GL', 'puerto ayora': 'EC', 'geraldton': 'AU', 'humaita': 'BR', 'isla aguada': 'MX', 'safford': 'US', 'skeldon': 'GY', 'ust-nera': 'RU', 'abong mbang': 'CM', 'yellowknife': 'CA', 'uturoa': 'PF', 'quimili': 'AR', 'gubkinskiy': 'RU', 'edinburgh of the seven seas': 'SH', 'puerto colombia': 'CO', 'villa gesell': 'AR', 'grand falls-windsor': 'CA', 'kavaratti': 'IN', 'saint-francois': 'FR', 'klaksvik': 'FO', 'lahaina': 'US', 'faya-largeau': 'TD', 'amble': 'GB', 'lorengau': 'PG', 'katsuren-haebaru': 'JP', 'nurota': 'UZ', 'weno': 'FM', 'bethel': 'US', 'aketi': 'CD', 'brandon': 'US', 'maintirano': 'MG', 'taveta': 'KE', "st. john's": 'CA', 'sagua la grande': 'CU', 'amga': 'RU', 'huanuni': 'BO', 'saipan': 'MP', 'sao tome': 'ST', 'pisco': 'PE', 'vuktyl': 'RU', 'port elizabeth': 'ZA', 'susanville': 'US', 'carloforte': 'IT', 'gizo': 'SB', 'punta del este': 'UY', 'rabo de peixe': 'PT', 'sydney mines': 'CA', 'vorgashor': 'RU', "l'isle-jourdain": 'FR', 'praia da vitoria': 'PT', 'newman': 'US', 'ulysses': 'US', 'daoukro': 'CI', 'prince albert': 'CA', 'wailua homesteads': 'US', 'cabo san lucas': 'MX', 'challapata': 'BO', 'qamdo': 'CN', 'ancud': 'CL', 'ornskoldsvik': 'SE', 'jilib': 'SO', 'al bawiti': 'EG', 'taltal': 'CL', 'kailua-kona': 'US', 'jorpeland': 'NO', 'iskateley': 'RU', 'atafu village': 'TK', 'nogliki': 'RU', 'keflavik': 'IS', 'puerto baquerizo moreno': 'EC', 'malango': 'ID', 'klyuchi': 'RU', 'tougan': 'BF', 'tual': 'ID', 'arteche': 'PH', 'acarau': 'BR', 'port-vila': 'VU', 'kavieng': 'PG', 'santarem': 'BR', 'severo-yeniseyskiy': 'RU', 'colonia': 'DE', 'posto fiscal rolim de moura': 'BR', 'fuerte olimpo': 'PY', 'palikir - national government center': 'FM', "bich'vinta": 'GE', "qarah zia' od din": 'IR', 'parfino': 'RU', 'arawa': 'PG', 'enewetak': 'MH', 'balaka': 'MW', 'kijang': 'KR', 'isafjordur': 'IS', 'aluksne': 'LV', 'coracora': 'PE', 'tezu': 'IN', 'khasab': 'OM', 'kolosovka': 'RU', 'lebu': 'CL', 'kapuskasing': 'CA', 'puerto ayacucho': 'VE', 'sidney': 'AU', 'east london': 'ZA', 'korop': 'UA', 'brookings': 'US', 'thinadhoo': 'MV', 'axim': 'GH', 'alice springs': 'AU', 'belmonte': 'BR', 'nelsonville': 'US', 'port alfred': 'ZA', 'qaqortoq': 'GL', 'poronaysk': 'RU', 'lompoc': 'US', 'nchelenge': 'ZM', 'akureyri': 'IS', 'margate': 'GB', 'anadyr': 'RU', 'el porvenir': 'HN', 'fale old settlement': 'TK', 'georgetown': 'MY', 'puerto carreno': 'CO', 'zykovo': 'RU', 'nakhon thai': 'TH', 'luganville': 'VU', 'piti village': 'GU', 'francistown': 'BW', 'kirensk': 'RU', 'xining': 'CN', 'shibirghan': 'AF', 'port lincoln': 'AU', 'yuzhno-kurilsk': 'RU', 'poiana teiului': 'RO', 'hamilton': 'US', 'karratha': 'AU', 'vorkuta': 'RU', 'san patricio': 'US', 'pacific grove': 'US', 'viitasaari': 'FI', 'great falls': 'US', 'hampton bays': 'US', 'zeya': 'RU', 'saint-philippe': 'RE', 'zakynthos': 'GR', 'camocim': 'BR', 'darwin': 'AU', 'port said': 'EG', 'port mathuri ...

# %%
# WHO API: Air pollution attributable DALYs
who_url = "https://ghoapi.azureedge.net/api/AIR_42"
response = requests.get(who_url)

# Check for valid response
if response.status_code == 200:
    data = response.json()['value']
    # Parse the data into a DataFrame
    who_data = [
        {
            'Country': entry['SpatialDim'],
            'Year': entry['TimeDim'],
            'MortalityRate_per_100k': entry['NumericValue']
        }
        for entry in data
    ]
    
    df_who = pd.DataFrame(who_data)
    print(df_who.head())
    
    df_who.to_csv('Resources/who_air_pollution_dalys.csv', index=False)
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
#   Country  Year  MortalityRate_per_100k
# 0     UGA  2016                   5.384
# 1     BIH  2017                   1.519
# 2     TCD  2012                 113.317
# 3     SVK  2016                   4.787
# 4     CIV  2010                  43.841

# %%
# Function to convert ISO-3 to ISO-2
def iso3_to_iso2(iso3_code):
    try:
        return pycountry.countries.get(alpha_3=iso3_code).alpha_2
    except AttributeError:
        return None  

df_who = pd.read_csv('Resources/who_air_pollution_dalys.csv')

# Convert WHO's ISO-3 codes to ISO-2
df_who['Country_ISO2'] = df_who['Country'].apply(iso3_to_iso2)

df_who_clean = df_who.dropna(subset=['Country_ISO2'])

df_weather = pd.read_csv('Resources/city_country_map.csv')

merged_df = pd.merge(air_quality_df, df_who_clean, left_on='Country', right_on='Country_ISO2', how='inner')

print(merged_df.head())

merged_df.to_csv('Resources/merged_air_quality_health.csv', index=False)
# Out:
#     City Country_x  PM2.5  PM10   NO2     O3   SO2      CO  NH3 Country_y  \
# 0  tiksi        RU    0.5  1.78  0.18  58.65  0.06  243.66  0.0       RUS
# 1  tiksi        RU    0.5  1.78  0.18  58.65  0.06  243.66  0.0       RUS
# 2  tiksi        RU    0.5  1.78  0.18  58.65  0.06  243.66  0.0       RUS
# 3  tiksi        RU    0.5  1.78  0.18  58.65  0.06  243.66  0.0       RUS
# 4  tiksi        RU    0.5  1.78  0.18  58.65  0.06  243.66  0.0       RUS
#
#    Year  MortalityRate_per_100k Country_ISO2
# 0  2011                   0.289           RU
# 1  2014                  11.601           RU
# 2  2012                   1.040           RU
# 3  2014                  54.595           RU
# 4  2014                   3.638           RU

# %%
count = len(merged_df)
count
# Out:
# 70020

# %%
# Drop redundant columns (dropping 'Country_ISO2' and 'Country_y')
merged_df = merged_df.drop(['Country_ISO2', 'Country_y'], axis=1)

# Rename columns for clarity
merged_df = merged_df.rename(columns={'Country_x': 'Country'})

# %%
merged_df.to_csv('Resources/merged_air_quality_health.csv', index=False)

# %%
# Load the merged dataset
df = pd.read_csv('Resources/merged_air_quality_health.csv')

# Group by City and Country to calculate average values across all years
grouped_df = df.groupby(['City', 'Country'], as_index=False).agg({
    'PM2.5': 'mean',
    'PM10': 'mean',
    'NO2': 'mean',
    'O3': 'mean',
    'SO2': 'mean',
    'CO': 'mean',
    'NH3': 'mean',
    'MortalityRate_per_100k': 'mean'
})

grouped_df = grouped_df.round(1)

grouped_df.to_csv('Resources/average_air_quality_health.csv', index=False)

print(grouped_df.head(10))
# Out:
#           City Country  PM2.5   PM10  NO2    O3  SO2     CO  NH3  \
# 0  abong mbang      CM    0.6    0.7  0.0   1.6  0.0  260.4  0.0
# 1       acarau      BR    3.2   15.2  0.2  37.9  0.2  390.5  0.0
# 2    ad dindar      SD   16.7   42.7  0.3  39.7  0.3  201.9  0.8
# 3        aioun      MR   49.0  227.2  0.1  34.0  0.0  210.3  0.2
# 4        aketi      CD    0.5    0.7  0.1   0.0  0.0  170.2  0.0
# 5        aktau      KZ   17.5   90.2  2.5  67.2  4.5  227.0  0.1
# 6     akureyri      IS    0.6    1.7  1.2  32.9  0.4  220.3  0.6
# 7    al bawiti      EG   18.5   84.1  1.0  68.7  0.2  200.3  0.0
# 8     alaghsas      NE   64.2  266.0  0.1  46.5  0.0  176.9  0.0
# 9       albany      US    0.5    0.6  2.5  79.4  0.1  217.0  0.2
#
#    MortalityRate_per_100k
# 0                    38.3
# 1                     9.6
# 2                    24.8
# 3                    21.3
# 4                    26.2
# 5                    30.5
# 6                     3.6
# 7                    36.2
# 8                    34.1
# 9                     5.7
