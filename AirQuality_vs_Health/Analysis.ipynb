# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Generate random latitude and longitude
lats = np.random.uniform(-90, 90, size=1000)
lngs = np.random.uniform(-180, 180, size=1000)


cities = []

# Use citipy to determine the nearest city for each lat-lng combination
for lat, lng in zip(lats, lngs):
    city = citipy.nearest_city(lat, lng).city_name
    if city not in cities:
        cities.append(city)

print(f"Generated {len(cities)} unique cities.")
# Out:
# Generated 452 unique cities.

# %%
# Base URLs
weather_url = "http://api.openweathermap.org/data/2.5/weather"
air_quality_url = "http://api.openweathermap.org/data/2.5/air_pollution"

# Dictionary to store valid city data with coordinates
valid_cities = {}

for city in cities:
    try:
        # Fetch city coordinates using the weather endpoint
        query_url = f"{weather_url}?q={city}&appid={weather_api_key}"
        response = requests.get(query_url)

        if response.status_code != 200:
            print(f"City {city} not found (Status Code: {response.status_code}). Skipping...")
            continue

        # Parse JSON response for coordinates
        data = response.json()
        lat = data['coord']['lat']
        lon = data['coord']['lon']
        country = data['sys']['country']

        # Store in filtered_cities dictionary
        valid_cities[city] = {'city': city, 'lat': lat, 'lon': lon, 'country': country}

        print(f"Retrieved coordinates for {city}: ({lat}, {lon})")

    except KeyError as key_err:
        print(f"KeyError: {key_err} for {city}. Skipping...")
    except requests.exceptions.RequestException as req_err:
        print(f"Request error: {req_err} for {city}. Skipping...")

    # Pause to avoid rate limiting
    time.sleep(1)

print(f"Total valid cities with coordinates: {len(valid_cities)}")
# Out:
# Retrieved coordinates for huangmei: (30.1924, 116.025)
# Retrieved coordinates for sitka: (57.0531, -135.33)
# Retrieved coordinates for badger: (64.8, -147.5333)
# Retrieved coordinates for edinburgh of the seven seas: (-37.0676, -12.3116)
# Retrieved coordinates for ballina: (-28.8667, 153.5667)
# Retrieved coordinates for wailua homesteads: (22.0669, -159.378)
# Retrieved coordinates for west island: (-12.1568, 96.8225)
# City vingt cinq not found (Status Code: 404). Skipping...
# Retrieved coordinates for tobelo: (1.7284, 128.0095)
# Retrieved coordinates for puerto ayora: (-0.7393, -90.3518)
# Retrieved coordinates for port-aux-francais: (-49.35, 70.2167)
# Retrieved coordinates for albany: (42.6001, -73.9662)
# Retrieved coordinates for gizo: (-8.103, 156.8419)
# Retrieved coordinates for angaur state: (6.906, 134.13)
# Retrieved coordinates for adamstown: (-25.066, -130.1015)
# Retrieved coordinates for tazacorte: (28.629, -17.9293)
# Retrieved coordinates for clanton: (32.8387, -86.6294)
# Retrieved coordinates for silifke: (36.3778, 33.9344)
# Retrieved coordinates for olonkinbyen: (70.9221, -8.7187)
# Retrieved coordinates for tura: (25.5198, 90.2201)
# Retrieved coordinates for solleftea: (63.1667, 17.2667)
# Retrieved coordinates for stanley: (54.868, -1.6985)
# Retrieved coordinates for mongoumba: (3.6415, 18.5936)
# Retrieved coordinates for bamboo flat: (11.7, 92.7167)
# Retrieved coordinates for nemuro: (43.3236, 145.575)
# Retrieved coordinates for bethel: (41.3712, -73.414)
# Retrieved coordinates for taroa: (8.7058, 171.2275)
# Retrieved coordinates for gopalpur: (19.2667, 84.9167)
# Retrieved coordinates for invercargill: (-46.4, 168.35)
# Retrieved coordinates for ushuaia: (-54.8, -68.3)
# Retrieved coordinates for bilibino: (68.0546, 166.4372)
# Retrieved coordinates for puerto deseado: (-47.7503, -65.8938)
# Retrieved coordinates for susuman: (62.7833, 148.1667)
# Retrieved coordinates for isafjordur: (66.0755, -23.124)
# Retrieved coordinates for cabugao: (17.7931, 120.4578)
# Retrieved coordinates for cadale: (2.7603, 46.3222)
# Retrieved coordinates for whakatane: (-37.9585, 176.9854)
# Retrieved coordinates for xiongzhou: (25.1167, 114.3)
# Retrieved coordinates for childress: (34.4264, -100.204)
# Retrieved coordinates for grytviken: (-54.2811, -36.5092)
# Retrieved coordinates for vorgashor: (67.5833, 63.95)
# Retrieved coordinates for anadyr: (64.75, 177.4833)
# Retrieved coordinates for kapa'a: (22.0752, -159.319)
# Retrieved coordinates for mastic beach: (40.7668, -72.8521)
# Retrieved coordinates for bodo: (67.28, 14.405)
# Retrieved coordinates for pacific grove: (36.6177, -121.9166)
# Retrieved coordinates for waitangi: (-43.9535, -176.5597)
# Retrieved coordinates for mammoth lakes: (37.6485, -118.9721)
# City taiohae not found (Status Code: 404). Skipping...
# Retrieved coordinates for colonia: (50.9333, 6.95)
# Retrieved coordinates for port lincoln: (-34.7333, 135.8667)
# Retrieved coordinates for qaqortoq: (60.7167, -46.0333)
# Retrieved coordinates for campoverde: (-8.4753, -74.8058)
# Retrieved coordinates for lebu: (-37.6167, -73.65)
# Retrieved coordinates for udachny: (66.4167, 112.4)
# Retrieved coordinates for kodiak: (57.79, -152.4072)
# Retrieved coordinates for big bend: (-26.8167, 31.9333)
# Retrieved coordinates for lerwick: (60.1545, -1.1494)
# Retrieved coordinates for new norfolk: (-42.7826, 147.0587)
# Retrieved coordinates for aliveri: (38.4167, 24.0333)
# Retrieved coordinates for ilulissat: (69.2167, -51.1)
# Retrieved coordinates for fisterra: (42.9049, -9.2629)
# Retrieved coordinates for mumbwa: (-14.9783, 27.0619)
# Retrieved coordinates for berriozabal: (16.8, -93.2667)
# Retrieved coordinates for utrik: (11.2278, 169.8474)
# Retrieved coordinates for port augusta: (-32.5, 137.7667)
# Retrieved coordinates for blackmans bay: (-43.0167, 147.3167)
# Retrieved coordinates for correntina: (-13.3433, -44.6367)
# Retrieved coordinates for bredasdorp: (-34.5322, 20.0403)
# Retrieved coordinates for avarua: (-21.2078, -159.775)
# Retrieved coordinates for kirakira: (-10.4544, 161.9205)
# Retrieved coordinates for amahai: (-3.3333, 128.9167)
# Retrieved coordinates for weno: (7.4515, 151.8468)
# Retrieved coordinates for cheria: (35.2731, 7.7519)
# Retrieved coordinates for enewetak: (11.3474, 162.3373)
# Retrieved coordinates for tamandare: (-8.7597, -35.1047)
# Retrieved coordinates for sao joao da barra: (-21.6403, -41.0511)
# Retrieved coordinates for aykhal: (66, 111.5)
# Retrieved coordinates for magadan: (59.5667, 150.8)
# Retrieved coordinates for umm kaddadah: (13.6017, 26.6876)
# Retrieved coordinates for sidney: (-33.8679, 151.2073)
# Retrieved coordinates for thompson: (55.7435, -97.8558)
# Retrieved coordinates for sisimiut: (66.9395, -53.6735)
# Retrieved coordinates for ponta delgada: (37.7333, -25.6667)
# Retrieved coordinates for jamestown: (42.097, -79.2353)
# Retrieved coordinates for east london: (-33.0153, 27.9116)
# Retrieved coordinates for grand forks: (47.9417, -97.4337)
# Retrieved coordinates for la passe: (45.5549, -0.8967)
# Retrieved coordinates for coquimbo: (-29.9533, -71.3436)
# Retrieved coordinates for bayt al faqih: (14.5164, 43.3245)
# Retrieved coordinates for santa sylvina: (-27.8326, -61.1375)
# Retrieved coordinates for papatowai: (-46.5619, 169.4708)
# Retrieved coordinates for hawaiian paradise park: (19.5933, -154.9731)
# Retrieved coordinates for holualoa: (19.6228, -155.9522)
# Retrieved coordinates for fale old settlement: (-9.3852, -171.2468)
# Retrieved coordinates for north platte: (41.1239, -100.7654)
# Retrieved coordinates for edd: (13.9297, 41.6925)
# City kapsowar not found (Status Code: 404). Skipping...
# Retrieved coordinates for carnarvon: (-24.8667, 113.6333)
# Retrieved coordinates for tarija: (-21.5355, -64.7296)
# Retrieved coordinates for banjarmasin: (-3.3244, 114.591)
# Retrieved coordinates for karratha: (-20.7377, 116.8463)
# Retrieved coordinates for hobyo: (5.3505, 48.5268)
# Retrieved coordinates for nuuk: (64.1835, -51.7216)
# Retrieved coordinates for soe: (-9.8607, 124.284)
# Retrieved coordinates for porto san giorgio: (43.1827, 13.7934)
# Retrieved coordinates for lapy: (52.9911, 22.8842)
# Retrieved coordinates for pyhajarvi: (67.0701, 27.2176)
# Retrieved coordinates for kibre mengist: (5.8833, 38.9833)
# Retrieved coordinates for hermanus: (-34.4187, 19.2345)
# Retrieved coordinates for puerto natales: (-51.7236, -72.4875)
# Retrieved coordinates for bam: (29.106, 58.357)
# Retrieved coordinates for port mathurin: (-19.6833, 63.4167)
# Retrieved coordinates for saint-philippe: (-21.3585, 55.7679)
# Retrieved coordinates for remire-montjoly: (4.9167, -52.2667)
# Retrieved coordinates for ambikapur: (23.1167, 83.2)
# Retrieved coordinates for alice springs: (-23.7, 133.8833)
# Retrieved coordinates for kujang-up: (39.8672, 126.0303)
# Retrieved coordinates for tonj: (7.2737, 28.6822)
# Retrieved coordinates for smithers: (54.7804, -127.1743)
# Retrieved coordinates for northam: (51.0333, -4.2167)
# Retrieved coordinates for novi di modena: (44.8905, 10.9014)
# Retrieved coordinates for kokhma: (56.9349, 41.0915)
# City kulia village not found (Status Code: 404). Skipping...
# Retrieved coordinates for mahibadhoo: (3.7833, 72.9667)
# Retrieved coordinates for florida: (28.7505, -82.5001)
# Retrieved coordinates for ca mau: (9.1769, 105.15)
# Retrieved coordinates for tralee: (52.2704, -9.7026)
# Retrieved coordinates for fuling: (29.7022, 107.3919)
# Retrieved coordinates for samamiya: (11.3487, 9.6399)
# Retrieved coordinates for hamilton: (39.1834, -84.5333)
# Retrieved coordinates for belmonte: (-15.8631, -38.8828)
# Retrieved coordinates for kharabali: (47.4196, 47.2568)
# Retrieved coordinates for iskateley: (67.6803, 53.1512)
# Retrieved coordinates for caister-on-sea: (52.6481, 1.7265)
# Retrieved coordinates for agbor: (6.2518, 6.1934)
# Retrieved coordinates for cestos city: (5.46, -9.5828)
# Retrieved coordinates for tiksi: (71.6872, 128.8694)
# Retrieved coordinates for kemijarvi: (66.7131, 27.4306)
# City 'ohonua not found (Status Code: 404). Skipping...
# Retrieved coordinates for vila franca do campo: (37.7167, -25.4333)
# Retrieved coordinates for iqaluit: (63.7506, -68.5145)
# Retrieved coordinates for talnakh: (69.4865, 88.3972)
# Retrieved coordinates for puerto carreno: (6.189, -67.4859)
# Retrieved coordinates for garoua boulai: (5.8833, 14.55)
# Retrieved coordinates for ribeira grande: (38.5167, -28.7)
# Retrieved coordinates for alotau: (-10.3069, 150.4462)
# Retrieved coordinates for yellowknife: (62.456, -114.3525)
# Retrieved coordinates for acarau: (-2.8856, -40.12)
# Retrieved coordinates for luderitz: (-26.6481, 15.1594)
# Retrieved coordinates for ancud: (-41.8697, -73.8203)
# Retrieved coordinates for hadibu: (12.65, 54.0333)
# Retrieved coordinates for guigang: (23.0964, 109.6092)
# Retrieved coordinates for yuzhno-kurilsk: (44.0306, 145.8556)
# Retrieved coordinates for nabire: (-3.3667, 135.4833)
# Retrieved coordinates for tazovsky: (67.4667, 78.7)
# Retrieved coordinates for saint john: (45.2727, -66.0677)
# Retrieved coordinates for angra do heroismo: (38.65, -27.2167)
# Retrieved coordinates for alaghsas: (17.0187, 8.0168)
# Retrieved coordinates for margaret river: (-33.95, 115.0667)
# Retrieved coordinates for mount isa: (-20.7333, 139.5)
# Retrieved coordinates for cannonvale: (-20.2833, 148.7)
# Retrieved coordinates for vilyuchinsk: (52.9306, 158.4028)
# Retrieved coordinates for vadso: (70.0744, 29.7487)
# Retrieved coordinates for punta arenas: (-53.15, -70.9167)
# Retrieved coordinates for ust-nera: (64.5667, 143.2)
# Retrieved coordinates for lihue: (21.9789, -159.3672)
# Retrieved coordinates for zaragoza: (41.6561, -0.8773)
# Retrieved coordinates for guerrero negro: (27.9769, -114.0611)
# Retrieved coordinates for usinsk: (65.9939, 57.5281)
# Retrieved coordinates for nova vicosa: (-17.8919, -39.3719)
# Retrieved coordinates for al jawf: (29.5, 38.75)
# Retrieved coordinates for taoudenni: (22.6783, -3.9836)
# Retrieved coordinates for san luis de la loma: (17.2706, -100.8939)
# Retrieved coordinates for bondoukou: (8.0333, -2.8)
# Retrieved coordinates for corund: (46.4667, 25.1833)
# Retrieved coordinates for el tocuyo: (9.7873, -69.7937)
# Retrieved coordinates for okhotsk: (59.3833, 143.3)
# Retrieved coordinates for kisarawe: (-6.9, 39.0667)
# Retrieved coordinates for praia da vitoria: (38.7333, -27.0667)
# Retrieved coordinates for masaya sur: (16.497, 121.7456)
# Retrieved coordinates for berdigestyakh: (62.0989, 126.6992)
# City tobi village not found (Status Code: 404). Skipping...
# Retrieved coordinates for uturoa: (-16.7333, -151.4333)
# Retrieved coordinates for lagos: (6.5833, 3.75)
# Retrieved coordinates for doka: (13.5167, 35.7667)
# Retrieved coordinates for hastings: (50.8552, 0.5729)
# Retrieved coordinates for isola di capo rizzuto: (38.96, 17.0933)
# Retrieved coordinates for zvishavane: (-20.3267, 30.0665)
# Retrieved coordinates for palu: (-0.8917, 119.8707)
# Retrieved coordinates for georgetown: (5.4112, 100.3354)
# Retrieved coordinates for phalaborwa: (-23.943, 31.1411)
# Retrieved coordinates for sol'-iletsk: (51.1631, 54.9918)
# Retrieved coordinates for la ronge: (55.1001, -105.2842)
# Retrieved coordinates for aasiaat: (68.7098, -52.8699)
# Retrieved coordinates for abbeville: (50.1, 1.8333)
# Retrieved coordinates for alta: (69.9689, 23.2717)
# Retrieved coordinates for hithadhoo: (-0.6, 73.0833)
# Retrieved coordinates for chonchi: (-42.6128, -73.8092)
# City puerto san carlos not found (Status Code: 404). Skipping...
# Retrieved coordinates for thinadhoo: (0.5333, 72.9333)
# Retrieved coordinates for minas de marcona: (-15.2119, -75.1103)
# Retrieved coordinates for happy valley-goose bay: (53.3168, -60.3315)
# Retrieved coordinates for ta`u: (-14.2336, -169.5144)
# Retrieved coordinates for jimenez: (28.3333, -105.4)
# Retrieved coordinates for biloela: (-24.4167, 150.5)
# Retrieved coordinates for tolanaro: (-25.0319, 46.9987)
# Retrieved coordinates for amos: (48.5669, -78.1162)
# Retrieved coordinates for xining: (36.6167, 101.7667)
# Retrieved coordinates for copiapo: (-27.3667, -70.3333)
# Retrieved coordinates for casper: (42.8666, -106.3131)
# Retrieved coordinates for miyaly: (48.8844, 53.7836)
# Retrieved coordinates for ciudad lazaro cardenas: (17.9583, -102.2)
# Retrieved coordinates for gamba: (-2.65, 10)
# Retrieved coordinates for santyoku: (37.4406, 129.1708)
# Retrieved coordinates for keflavik: (64.0049, -22.5624)
# Retrieved coordinates for mossel bay: (-34.1831, 22.146)
# Retrieved coordinates for college: (64.8569, -147.8028)
# Retrieved coordinates for pimentel: (-6.8367, -79.9342)
# Retrieved coordinates for cole harbour: (44.6724, -63.4751)
# Retrieved coordinates for dadhar: (29.4753, 67.6514)
# Retrieved coordinates for longyearbyen: (78.2186, 15.6401)
# Retrieved coordinates for mega: (4.05, 38.3)
# Retrieved coordinates for pemangkat: (1.1667, 108.9667)
# Retrieved coordinates for queenstown: (-31.8976, 26.8753)
# Retrieved coordinates for nikolayevsk-on-amure: (53.1406, 140.73)
# Retrieved coordinates for zavoronezhskoye: (52.8801, 40.5526)
# Retrieved coordinates for atafu village: (-8.5421, -172.5159)
# Retrieved coordinates for effingham: (32.3669, -81.3332)
# Retrieved coordinates for bathurst: (-33.4166, 149.5806)
# Retrieved coordinates for canmore: (51.0834, -115.3521)
# Retrieved coordinates for puerto baquerizo moreno: (-0.9, -89.6)
# Retrieved coordinates for shenkursk: (62.1091, 42.896)
# Retrieved coordinates for medina: (24.4686, 39.6142)
# Retrieved coordinates for mejit: (10.2753, 170.8646)
# Retrieved coordinates for arraial do cabo: (-22.9661, -42.0278)
# Retrieved coordinates for brookings: (44.3114, -96.7984)
# Retrieved coordinates for qingdao: (36.0986, 120.3719)
# Retrieved coordinates for tanjung pinang: (0.9167, 104.45)
# Retrieved coordinates for brisas de zicatela: (15.8369, -97.0419)
# Retrieved coordinates for alliance: (40.9153, -81.1059)
# Retrieved coordinates for petropavlovsk-kamchatsky: (53.0452, 158.6483)
# Retrieved coordinates for beyneu: (45.3167, 55.2)
# Retrieved coordinates for hosdurga: (13.7981, 76.2861)
# Retrieved coordinates for burutu: (5.3509, 5.5076)
# Retrieved coordinates for bennington: (42.8781, -73.1968)
# Retrieved coordinates for kingston: (17.997, -76.7936)
# Retrieved coordinates for igrim: (63.1906, 64.4162)
# Retrieved coordinates for puerto aysen: (-45.4, -72.7)
# Retrieved coordinates for enchanted hills: (35.3368, -106.593)
# Retrieved coordinates for macapa: (0.0389, -51.0664)
# Retrieved coordinates for vikhorevka: (56.1201, 101.1636)
# Retrieved coordinates for la'ie: (21.6477, -157.9253)
# Retrieved coordinates for filey: (54.21, -0.2892)
# Retrieved coordinates for sao jose da coroa grande: (-8.8978, -35.1478)
# Retrieved coordinates for quellon: (-43.1167, -73.6167)
# Retrieved coordinates for mutuali: (-14.8706, 37.0044)
# Retrieved coordinates for jharsuguda: (21.85, 84.0333)
# City cargados carajos not found (Status Code: 404). Skipping...
# Retrieved coordinates for lib: (8.3122, 167.3766)
# Retrieved coordinates for port douglas: (-16.4833, 145.4667)
# Retrieved coordinates for haiku-pauwela: (20.9219, -156.3051)
# Retrieved coordinates for talitsa: (56.8804, 60.0213)
# Retrieved coordinates for san antonio de pale: (-1.4014, 5.6325)
# Retrieved coordinates for almeirim: (-1.5233, -52.5817)
# City shangri-la not found (Status Code: 404). Skipping...
# Retrieved coordinates for xai-xai: (-25.0519, 33.6442)
# Retrieved coordinates for laguna: (38.421, -121.4238)
# Retrieved coordinates for whitehorse: (60.7161, -135.0538)
# Retrieved coordinates for markovo: (57.3206, 107.0881)
# Retrieved coordinates for port elizabeth: (-33.918, 25.5701)
# Retrieved coordinates for kismayo: (-0.3582, 42.5454)
# City tranovaho not found (Status Code: 404). Skipping...
# City cairns city not found (Status Code: 404). Skipping...
# Retrieved coordinates for formosa: (-26.1775, -58.1781)
# Retrieved coordinates for elverum: (60.8819, 11.5623)
# Retrieved coordinates for zag: (46.9441, 99.165)
# City ntossoni not found (Status Code: 404). Skipping...
# Retrieved coordinates for yetkul': (54.8221, 61.588)
# Retrieved coordinates for prado: (-17.3411, -39.2208)
# Retrieved coordinates for okha: (53.5739, 142.9478)
# Retrieved coordinates for san felipe: (10.3399, -68.7425)
# Retrieved coordinates for beeville: (28.4008, -97.7483)
# Retrieved coordinates for kamaishi: (39.2667, 141.8833)
# Retrieved coordinates for vorkuta: (67.5, 64)
# Retrieved coordinates for savanna-la-mar: (18.219, -78.1332)
# Retrieved coordinates for plastun: (44.7561, 136.2939)
# Retrieved coordinates for castillos: (-34.1667, -53.8333)
# Retrieved coordinates for fada: (7.25, 4.0667)
# Retrieved coordinates for saldanha: (-33.0117, 17.9442)
# Retrieved coordinates for salinopolis: (-0.6136, -47.3561)
# Retrieved coordinates for mossoro: (-5.1875, -37.3442)
# Retrieved coordinates for isangel: (-19.55, 169.2667)
# Retrieved coordinates for inirida: (3.8653, -67.9239)
# Retrieved coordinates for tegina: (10.0706, 6.1906)
# Retrieved coordinates for kuusamo: (65.9667, 29.1833)
# Retrieved coordinates for muravlenko: (63.7898, 74.523)
# Retrieved coordinates for hazleton: (40.9584, -75.9746)
# Retrieved coordinates for papao: (-17.75, -149.55)
# Retrieved coordinates for noyabrsk: (63.1994, 75.4507)
# Retrieved coordinates for safi: (32.1667, -8.8333)
# Retrieved coordinates for grand gaube: (-20.0064, 57.6608)
# Retrieved coordinates for cartagena: (10.3997, -75.5144)
# Retrieved coordinates for lata: (40.1629, -8.3327)
# Retrieved coordinates for paharpur: (32.1038, 70.9724)
# Retrieved coordinates for dunedin: (-45.8742, 170.5036)
# Retrieved coordinates for dalandzadgad: (43.5708, 104.425)
# Retrieved coordinates for xingcheng: (40.6167, 120.7167)
# Retrieved coordinates for toliara: (-23.35, 43.6667)
# Retrieved coordinates for tommot: (58.9564, 126.2925)
# Retrieved coordinates for kuchera: (26.9839, 73.9719)
# Retrieved coordinates for huarmey: (-10.0681, -78.1522)
# Retrieved coordinates for el calafate: (-50.3408, -72.2768)
# Retrieved coordinates for nea alikarnassos: (35.3333, 25.1667)
# City manuel ojinaga not found (Status Code: 404). Skipping...
# Retrieved coordinates for hanceville: (34.0607, -86.7675)
# Retrieved coordinates for belyy yar: (53.6039, 91.3903)
# Retrieved coordinates for yeniseysk: (58.4497, 92.1703)
# Retrieved coordinates for bushehr: (28.9684, 50.8385)
# Retrieved coordinates for grand falls-windsor: (48.9332, -55.6649)
# Retrieved coordinates for pierre: (44.3683, -100.351)
# Retrieved coordinates for chimore: (-16.9833, -65.1333)
# Retrieved coordinates for fuwwah: (31.2029, 30.5502)
# Retrieved coordinates for rabo de peixe: (37.8, -25.5833)
# Retrieved coordinates for nema: (57.5067, 50.5011)
# City isle of lewis not found (Status Code: 404). Skipping...
# Retrieved coordinates for miri: (4.4148, 114.0089)
# Retrieved coordinates for port alfred: (-33.5906, 26.891)
# Retrieved coordinates for zhangatas: (43.5667, 69.75)
# Retrieved coordinates for raja: (8.4596, 25.678)
# Retrieved coordinates for bereznik: (62.8551, 42.7072)
# Retrieved coordinates for sirte: (31.2089, 16.5887)
# Retrieved coordinates for smara: (26.7384, -11.6719)
# Retrieved coordinates for barclayville: (4.6797, -8.2339)
# Retrieved coordinates for vila velha: (-20.3297, -40.2925)
# Retrieved coordinates for kudymkar: (59.0173, 54.656)
# Retrieved coordinates for rawson: (-43.3002, -65.1023)
# Retrieved coordinates for cidreira: (-30.1811, -50.2056)
# Retrieved coordinates for argo: (37.6333, 22.7333)
# Retrieved coordinates for kenora: (49.8167, -94.4337)
# Retrieved coordinates for shendi: (16.6915, 33.4341)
# Retrieved coordinates for hancheng: (32.5186, 112.3522)
# Retrieved coordinates for simpang: (-1.2667, 104.0833)
# Retrieved coordinates for port blair: (11.6667, 92.75)
# Retrieved coordinates for nagqu: (31.5, 92)
# Retrieved coordinates for arkalyk: (50.2486, 66.9114)
# Retrieved coordinates for maba: (24.6841, 113.5984)
# Retrieved coordinates for ambon: (-3.6954, 128.1814)
# Retrieved coordinates for saint-flour: (45.0833, 3)
# City torteval not found (Status Code: 404). Skipping...
# Retrieved coordinates for yerbabuena: (20.9667, -101.2667)
# Retrieved coordinates for mili: (6.0815, 171.735)
# Retrieved coordinates for trairi: (-3.2778, -39.2689)
# Retrieved coordinates for ubinskoye: (55.3068, 79.6802)
# Retrieved coordinates for cabo san lucas: (22.8909, -109.9124)
# Retrieved coordinates for betioky: (-23.7167, 44.3833)
# Retrieved coordinates for malabar: (-33.9667, 151.25)
# Retrieved coordinates for lamu: (-2.2717, 40.902)
# Retrieved coordinates for balabac: (7.9868, 117.0645)
# Retrieved coordinates for bodaybo: (57.8506, 114.1933)
# Retrieved coordinates for marsa alam: (25.0757, 34.8918)
# Retrieved coordinates for santa cruz: (-17.8, -63.1667)
# Retrieved coordinates for san rafael: (-34.6177, -68.3301)
# City zangguy not found (Status Code: 404). Skipping...
# Retrieved coordinates for mount pearl: (47.5166, -52.7813)
# Retrieved coordinates for maralal: (1.0968, 36.698)
# Retrieved coordinates for kostomuksha: (64.571, 30.5767)
# Retrieved coordinates for gamay: (12.3854, 125.2979)
# Retrieved coordinates for svetlyy yar: (48.4748, 44.781)
# Retrieved coordinates for klyuchi: (52.2667, 79.1667)
# Retrieved coordinates for clovis: (36.8252, -119.7029)
# Retrieved coordinates for lampang: (18.3333, 99.5)
# Retrieved coordinates for tongouson: (5.0214, 120.1328)
# Retrieved coordinates for lahad datu: (5.0268, 118.327)
# Retrieved coordinates for inari: (68.906, 27.0288)
# Retrieved coordinates for ataq: (14.5377, 46.8319)
# Retrieved coordinates for kourou: (5.1552, -52.6478)
# Retrieved coordinates for wainwright: (52.839, -110.8572)
# Retrieved coordinates for zhangjiakou: (40.81, 114.8794)
# Retrieved coordinates for oromocto: (45.8351, -66.4792)
# Retrieved coordinates for san patricio: (28.017, -97.5169)
# Retrieved coordinates for puerto ayacucho: (5.6639, -67.6236)
# Retrieved coordinates for nacala: (-14.5428, 40.6728)
# Retrieved coordinates for wad az zaki: (14.4619, 32.2065)
# Retrieved coordinates for broken hill: (-31.95, 141.4333)
# Retrieved coordinates for igarka: (67.4667, 86.5833)
# Retrieved coordinates for kukuna: (9.4, -12.6667)
# Retrieved coordinates for cockburn town: (21.4612, -71.1419)
# Retrieved coordinates for dom pedrito: (-30.9828, -54.6731)
# Retrieved coordinates for lae: (-6.7221, 146.9847)
# Retrieved coordinates for saint-pierre: (-21.3393, 55.4781)
# Retrieved coordinates for st. john's: (47.5649, -52.7093)
# Retrieved coordinates for howrah: (22.5892, 88.3103)
# Retrieved coordinates for naze: (28.3667, 129.4833)
# Retrieved coordinates for magburaka: (8.7167, -11.95)
# Retrieved coordinates for kayar: (14.9192, -17.1211)
# City al-`ula not found (Status Code: 404). Skipping...
# Retrieved coordinates for sterling: (39.0062, -77.4286)
# Retrieved coordinates for coffs harbour: (-30.3, 153.1333)
# Retrieved coordinates for khandyga: (62.6667, 135.6)
# Retrieved coordinates for masterton: (-40.9597, 175.6575)
# Retrieved coordinates for qinhuangdao: (39.9317, 119.5883)
# Retrieved coordinates for kenai: (60.5544, -151.2583)
# Retrieved coordinates for road town: (18.4167, -64.6167)
# Retrieved coordinates for cudillero: (43.5622, -6.1459)
# Retrieved coordinates for knokke: (50.7979, 3.3628)
# Retrieved coordinates for vakhrushi: (58.6847, 50.0261)
# Retrieved coordinates for lajinha: (-20.1514, -41.6228)
# Retrieved coordinates for cidade velha: (14.9167, -23.6167)
# Retrieved coordinates for fort bragg: (35.139, -79.006)
# Retrieved coordinates for kutum: (14.2, 24.6667)
# Retrieved coordinates for afaahiti: (-17.75, -149.2833)
# Retrieved coordinates for bure: (10.7, 37.0667)
# Retrieved coordinates for jirja: (26.3383, 31.8916)
# Retrieved coordinates for hami: (42.8, 93.45)
# Retrieved coordinates for midvagur: (62.0511, -7.1939)
# Retrieved coordinates for nantucket: (41.2835, -70.0995)
# Retrieved coordinates for nong khae: (14.3406, 100.8673)
# Retrieved coordinates for mucuri: (-18.0864, -39.5508)
# Retrieved coordinates for al qusayr: (34.5091, 36.5798)
# Retrieved coordinates for constantia: (44.1833, 28.65)
# Retrieved coordinates for mezhdurechensk: (53.6942, 88.0603)
# Retrieved coordinates for kachkanar: (58.7, 59.4948)
# Retrieved coordinates for sarina: (-21.4333, 149.2167)
# Retrieved coordinates for ola: (59.5833, 151.2833)
# Retrieved coordinates for namibe: (-15.1961, 12.1522)
# Retrieved coordinates for ghat: (24.9647, 10.1728)
# Retrieved coordinates for tonghae: (37.5439, 129.1069)
# Retrieved coordinates for nar'yan-mar: (67.6713, 53.087)
# Retrieved coordinates for callao: (-12.0667, -77.15)
# Retrieved coordinates for sinabang: (2.4803, 96.3801)
# Retrieved coordinates for villa gesell: (-37.2639, -56.973)
# Retrieved coordinates for warmbad: (-28.45, 18.7333)
# Retrieved coordinates for maisi: (43.0395, 41.2621)
# Retrieved coordinates for port saint john's: (-31.6229, 29.5448)
# Retrieved coordinates for yueyang: (29.3333, 113.0919)
# Retrieved coordinates for labrador city: (52.9463, -66.9114)
# Retrieved coordinates for kertih: (4.5141, 103.4483)
# Retrieved coordinates for irbit: (57.6705, 63.071)
# Retrieved coordinates for jinchang: (38.4953, 102.1739)
# Retrieved coordinates for tarfaya: (27.9358, -12.9218)
# City ahau not found (Status Code: 404). Skipping...
# Retrieved coordinates for kingisepp: (59.3733, 28.6134)
# Retrieved coordinates for salmon arm: (50.6998, -119.3024)
# Retrieved coordinates for pordic: (48.5705, -2.8178)
# Retrieved coordinates for jining: (35.405, 116.5814)
# Retrieved coordinates for yanchep: (-31.55, 115.6833)
# Retrieved coordinates for egilsstadir: (65.2653, -14.3948)
# Retrieved coordinates for codrington: (-38.2667, 141.9667)
# Retrieved coordinates for debre tabor: (11.85, 38.0167)
# Retrieved coordinates for conceicao da barra: (-18.5933, -39.7322)
# Retrieved coordinates for wynyard: (-41, 145.7167)
# Total valid cities with coordinates: 434

# %%
print(valid_cities)
# Out:
# {'huangmei': {'city': 'huangmei', 'lat': 30.1924, 'lon': 116.025, 'country': 'CN'}, 'sitka': {'city': 'sitka', 'lat': 57.0531, 'lon': -135.33, 'country': 'US'}, 'badger': {'city': 'badger', 'lat': 64.8, 'lon': -147.5333, 'country': 'US'}, 'edinburgh of the seven seas': {'city': 'edinburgh of the seven seas', 'lat': -37.0676, 'lon': -12.3116, 'country': 'SH'}, 'ballina': {'city': 'ballina', 'lat': -28.8667, 'lon': 153.5667, 'country': 'AU'}, 'wailua homesteads': {'city': 'wailua homesteads', 'lat': 22.0669, 'lon': -159.378, 'country': 'US'}, 'west island': {'city': 'west island', 'lat': -12.1568, 'lon': 96.8225, 'country': 'CC'}, 'tobelo': {'city': 'tobelo', 'lat': 1.7284, 'lon': 128.0095, 'country': 'ID'}, 'puerto ayora': {'city': 'puerto ayora', 'lat': -0.7393, 'lon': -90.3518, 'country': 'EC'}, 'port-aux-francais': {'city': 'port-aux-francais', 'lat': -49.35, 'lon': 70.2167, 'country': 'TF'}, 'albany': {'city': 'albany', 'lat': 42.6001, 'lon': -73.9662, 'country': 'US'}, 'gizo': {'city': 'gizo', 'lat': -8.103, 'lon': 156.8419, 'country': 'SB'}, 'angaur state': {'city': 'angaur state', 'lat': 6.906, 'lon': 134.13, 'country': 'PW'}, 'adamstown': {'city': 'adamstown', 'lat': -25.066, 'lon': -130.1015, 'country': 'PN'}, 'tazacorte': {'city': 'tazacorte', 'lat': 28.629, 'lon': -17.9293, 'country': 'ES'}, 'clanton': {'city': 'clanton', 'lat': 32.8387, 'lon': -86.6294, 'country': 'US'}, 'silifke': {'city': 'silifke', 'lat': 36.3778, 'lon': 33.9344, 'country': 'TR'}, 'olonkinbyen': {'city': 'olonkinbyen', 'lat': 70.9221, 'lon': -8.7187, 'country': 'SJ'}, 'tura': {'city': 'tura', 'lat': 25.5198, 'lon': 90.2201, 'country': 'IN'}, 'solleftea': {'city': 'solleftea', 'lat': 63.1667, 'lon': 17.2667, 'country': 'SE'}, 'stanley': {'city': 'stanley', 'lat': 54.868, 'lon': -1.6985, 'country': 'GB'}, 'mongoumba': {'city': 'mongoumba', 'lat': 3.6415, 'lon': 18.5936, 'country': 'CF'}, 'bamboo flat': {'city': 'bamboo flat', 'lat': 11.7, 'lon': 92.7167, 'country': 'IN'}, 'nemuro': {'city': 'nemuro', 'lat': 43.3236, 'lon': 145.575, 'country': 'JP'}, 'bethel': {'city': 'bethel', 'lat': 41.3712, 'lon': -73.414, 'country': 'US'}, 'taroa': {'city': 'taroa', 'lat': 8.7058, 'lon': 171.2275, 'country': 'MH'}, 'gopalpur': {'city': 'gopalpur', 'lat': 19.2667, 'lon': 84.9167, 'country': 'IN'}, 'invercargill': {'city': 'invercargill', 'lat': -46.4, 'lon': 168.35, 'country': 'NZ'}, 'ushuaia': {'city': 'ushuaia', 'lat': -54.8, 'lon': -68.3, 'country': 'AR'}, 'bilibino': {'city': 'bilibino', 'lat': 68.0546, 'lon': 166.4372, 'country': 'RU'}, 'puerto deseado': {'city': 'puerto deseado', 'lat': -47.7503, 'lon': -65.8938, 'country': 'AR'}, 'susuman': {'city': 'susuman', 'lat': 62.7833, 'lon': 148.1667, 'country': 'RU'}, 'isafjordur': {'city': 'isafjordur', 'lat': 66.0755, 'lon': -23.124, 'country': 'IS'}, 'cabugao': {'city': 'cabugao', 'lat': 17.7931, 'lon': 120.4578, 'country': 'PH'}, 'cadale': {'city': 'cadale', 'lat': 2.7603, 'lon': 46.3222, 'country': 'SO'}, 'whakatane': {'city': 'whakatane', 'lat': -37.9585, 'lon': 176.9854, 'country': 'NZ'}, 'xiongzhou': {'city': 'xiongzhou', 'lat': 25.1167, 'lon': 114.3, 'country': 'CN'}, 'childress': {'city': 'childress', 'lat': 34.4264, 'lon': -100.204, 'country': 'US'}, 'grytviken': {'city': 'grytviken', 'lat': -54.2811, 'lon': -36.5092, 'country': 'GS'}, 'vorgashor': {'city': 'vorgashor', 'lat': 67.5833, 'lon': 63.95, 'country': 'RU'}, 'anadyr': {'city': 'anadyr', 'lat': 64.75, 'lon': 177.4833, 'country': 'RU'}, "kapa'a": {'city': "kapa'a", 'lat': 22.0752, 'lon': -159.319, 'country': 'US'}, 'mastic beach': {'city': 'mastic beach', 'lat': 40.7668, 'lon': -72.8521, 'country': 'US'}, 'bodo': {'city': 'bodo', 'lat': 67.28, 'lon': 14.405, 'country': 'NO'}, 'pacific grove': {'city': 'pacific grove', 'lat': 36.6177, 'lon': -121.9166, 'country': 'US'}, 'waitangi': {'city': 'waitangi', 'lat': -43.9535, 'lon': -176.5597, 'country': 'NZ'}, 'mammoth lakes': {'city': 'mammoth lakes', 'lat': 37.6485, 'lon': -118.9721, 'country': 'US'} ...

# %%
city_names = list(valid_cities.keys())
print(city_names)
# Out:
# ['huangmei', 'sitka', 'badger', 'edinburgh of the seven seas', 'ballina', 'wailua homesteads', 'west island', 'tobelo', 'puerto ayora', 'port-aux-francais', 'albany', 'gizo', 'angaur state', 'adamstown', 'tazacorte', 'clanton', 'silifke', 'olonkinbyen', 'tura', 'solleftea', 'stanley', 'mongoumba', 'bamboo flat', 'nemuro', 'bethel', 'taroa', 'gopalpur', 'invercargill', 'ushuaia', 'bilibino', 'puerto deseado', 'susuman', 'isafjordur', 'cabugao', 'cadale', 'whakatane', 'xiongzhou', 'childress', 'grytviken', 'vorgashor', 'anadyr', "kapa'a", 'mastic beach', 'bodo', 'pacific grove', 'waitangi', 'mammoth lakes', 'colonia', 'port lincoln', 'qaqortoq', 'campoverde', 'lebu', 'udachny', 'kodiak', 'big bend', 'lerwick', 'new norfolk', 'aliveri', 'ilulissat', 'fisterra', 'mumbwa', 'berriozabal', 'utrik', 'port augusta', 'blackmans bay', 'correntina', 'bredasdorp', 'avarua', 'kirakira', 'amahai', 'weno', 'cheria', 'enewetak', 'tamandare', 'sao joao da barra', 'aykhal', 'magadan', 'umm kaddadah', 'sidney', 'thompson', 'sisimiut', 'ponta delgada', 'jamestown', 'east london', 'grand forks', 'la passe', 'coquimbo', 'bayt al faqih', 'santa sylvina', 'papatowai', 'hawaiian paradise park', 'holualoa', 'fale old settlement', 'north platte', 'edd', 'carnarvon', 'tarija', 'banjarmasin', 'karratha', 'hobyo', 'nuuk', 'soe', 'porto san giorgio', 'lapy', 'pyhajarvi', 'kibre mengist', 'hermanus', 'puerto natales', 'bam', 'port mathurin', 'saint-philippe', 'remire-montjoly', 'ambikapur', 'alice springs', 'kujang-up', 'tonj', 'smithers', 'northam', 'novi di modena', 'kokhma', 'mahibadhoo', 'florida', 'ca mau', 'tralee', 'fuling', 'samamiya', 'hamilton', 'belmonte', 'kharabali', 'iskateley', 'caister-on-sea', 'agbor', 'cestos city', 'tiksi', 'kemijarvi', 'vila franca do campo', 'iqaluit', 'talnakh', 'puerto carreno', 'garoua boulai', 'ribeira grande', 'alotau', 'yellowknife', 'acarau', 'luderitz', 'ancud', 'hadibu', 'guigang', 'yuzhno-kurilsk', 'nabire', 'tazovsky', 'saint john', 'angra do heroismo', 'alaghsas', 'margaret river', 'mount isa', 'cannonvale', 'vilyuchinsk', 'vadso', 'punta arenas', 'ust-nera', 'lihue', 'zaragoza', 'guerrero negro', 'usinsk', 'nova vicosa', 'al jawf', 'taoudenni', 'san luis de la loma', 'bondoukou', 'corund', 'el tocuyo', 'okhotsk', 'kisarawe', 'praia da vitoria', 'masaya sur', 'berdigestyakh', 'uturoa', 'lagos', 'doka', 'hastings', 'isola di capo rizzuto', 'zvishavane', 'palu', 'georgetown', 'phalaborwa', "sol'-iletsk", 'la ronge', 'aasiaat', 'abbeville', 'alta', 'hithadhoo', 'chonchi', 'thinadhoo', 'minas de marcona', 'happy valley-goose bay', 'ta`u', 'jimenez', 'biloela', 'tolanaro', 'amos', 'xining', 'copiapo', 'casper', 'miyaly', 'ciudad lazaro cardenas', 'gamba', 'santyoku', 'keflavik', 'mossel bay', 'college', 'pimentel', 'cole harbour', 'dadhar', 'longyearbyen', 'mega', 'pemangkat', 'queenstown', 'nikolayevsk-on-amure', 'zavoronezhskoye', 'atafu village', 'effingham', 'bathurst', 'canmore', 'puerto baquerizo moreno', 'shenkursk', 'medina', 'mejit', 'arraial do cabo', 'brookings', 'qingdao', 'tanjung pinang', 'brisas de zicatela', 'alliance', 'petropavlovsk-kamchatsky', 'beyneu', 'hosdurga', 'burutu', 'bennington', 'kingston', 'igrim', 'puerto aysen', 'enchanted hills', 'macapa', 'vikhorevka', "la'ie", 'filey', 'sao jose da coroa grande', 'quellon', 'mutuali', 'jharsuguda', 'lib', 'port douglas', 'haiku-pauwela', 'talitsa', 'san antonio de pale', 'almeirim', 'xai-xai', 'laguna', 'whitehorse', 'markovo', 'port elizabeth', 'kismayo', 'formosa', 'elverum', 'zag', "yetkul'", 'prado', 'okha', 'san felipe', 'beeville', 'kamaishi', 'vorkuta', 'savanna-la-mar', 'plastun', 'castillos', 'fada', 'saldanha', 'salinopolis', 'mossoro', 'isangel', 'inirida', 'tegina', 'kuusamo', 'muravlenko', 'hazleton', 'papao', 'noyabrsk', 'safi', 'grand gaube', 'cartagena', 'lata', 'paharpur', 'dunedin', 'dalandzadgad', 'xingcheng', 'toliara', 'tommot', 'kuchera', 'huarmey', 'el calafate', 'nea alikarnassos', 'hanceville', 'belyy yar', 'yeniseysk', ' ...

# %%
# List to store air quality data
air_quality_data = []

# Loop through each city to get pollution data
for city, info in valid_cities.items():
    lat = info['lat']
    lon = info['lon']

    try:
        # Query the Air Pollution API
        pollution_url = f"{air_quality_url}?lat={lat}&lon={lon}&appid={weather_api_key}"
        pollution_response = requests.get(pollution_url).json()

        # Extract pollution components
        components = pollution_response['list'][0]['components']
        pm25 = components.get('pm2_5', None)
        pm10 = components.get('pm10', None)
        no2 = components.get('no2', None)
        o3 = components.get('o3', None)
        so2 = components.get('so2', None)
        co = components.get('co', None)
        nh3 = components.get('nh3', None)

        # Store the pollution data
        air_quality_data.append({
            'City': city,
            'Country': info['country'],
            'PM2.5': pm25,
            'PM10': pm10,
            'NO2': no2,
            'O3': o3,
            'SO2': so2,
            'CO': co,
            'NH3': nh3
        })

        print(f"Retrieved pollution data for {city}, {info['country']}")

    except Exception as e:
        print(f"Error retrieving data for {city}: {e}")

    # Pause to avoid rate limiting
    time.sleep(1)

# Convert the collected data into a DataFrame
air_quality_df = pd.DataFrame(air_quality_data)
print(air_quality_df.head())
# Out:
# Retrieved pollution data for huangmei, CN
# Retrieved pollution data for sitka, US
# Retrieved pollution data for badger, US
# Retrieved pollution data for edinburgh of the seven seas, SH
# Retrieved pollution data for ballina, AU
# Retrieved pollution data for wailua homesteads, US
# Retrieved pollution data for west island, CC
# Retrieved pollution data for tobelo, ID
# Retrieved pollution data for puerto ayora, EC
# Retrieved pollution data for port-aux-francais, TF
# Retrieved pollution data for albany, US
# Retrieved pollution data for gizo, SB
# Retrieved pollution data for angaur state, PW
# Retrieved pollution data for adamstown, PN
# Retrieved pollution data for tazacorte, ES
# Retrieved pollution data for clanton, US
# Retrieved pollution data for silifke, TR
# Retrieved pollution data for olonkinbyen, SJ
# Retrieved pollution data for tura, IN
# Retrieved pollution data for solleftea, SE
# Retrieved pollution data for stanley, GB
# Retrieved pollution data for mongoumba, CF
# Retrieved pollution data for bamboo flat, IN
# Retrieved pollution data for nemuro, JP
# Retrieved pollution data for bethel, US
# Retrieved pollution data for taroa, MH
# Retrieved pollution data for gopalpur, IN
# Retrieved pollution data for invercargill, NZ
# Retrieved pollution data for ushuaia, AR
# Retrieved pollution data for bilibino, RU
# Retrieved pollution data for puerto deseado, AR
# Retrieved pollution data for susuman, RU
# Retrieved pollution data for isafjordur, IS
# Retrieved pollution data for cabugao, PH
# Retrieved pollution data for cadale, SO
# Retrieved pollution data for whakatane, NZ
# Retrieved pollution data for xiongzhou, CN
# Retrieved pollution data for childress, US
# Retrieved pollution data for grytviken, GS
# Retrieved pollution data for vorgashor, RU
# Retrieved pollution data for anadyr, RU
# Retrieved pollution data for kapa'a, US
# Retrieved pollution data for mastic beach, US
# Retrieved pollution data for bodo, NO
# Retrieved pollution data for pacific grove, US
# Retrieved pollution data for waitangi, NZ
# Retrieved pollution data for mammoth lakes, US
# Retrieved pollution data for colonia, DE
# Retrieved pollution data for port lincoln, AU
# Retrieved pollution data for qaqortoq, GL
# Retrieved pollution data for campoverde, PE
# Retrieved pollution data for lebu, CL
# Retrieved pollution data for udachny, RU
# Retrieved pollution data for kodiak, US
# Retrieved pollution data for big bend, SZ
# Retrieved pollution data for lerwick, GB
# Retrieved pollution data for new norfolk, AU
# Retrieved pollution data for aliveri, GR
# Retrieved pollution data for ilulissat, GL
# Retrieved pollution data for fisterra, ES
# Retrieved pollution data for mumbwa, ZM
# Retrieved pollution data for berriozabal, MX
# Retrieved pollution data for utrik, MH
# Retrieved pollution data for port augusta, AU
# Retrieved pollution data for blackmans bay, AU
# Retrieved pollution data for correntina, BR
# Retrieved pollution data for bredasdorp, ZA
# Retrieved pollution data for avarua, CK
# Retrieved pollution data for kirakira, SB
# Retrieved pollution data for amahai, ID
# Retrieved pollution data for weno, FM
# Retrieved pollution data for cheria, DZ
# Retrieved pollution data for enewetak, MH
# Retrieved pollution data for tamandare, BR
# Retrieved pollution data for sao joao da barra, BR
# Retrieved pollution data for aykhal, RU
# Retrieved pollution data for magadan, RU
# Retrieved pollution data for umm kaddadah, SD
# Retrieved pollution data for sidney, AU
# Retrieved pollution data for thompson, CA
# Retrieved pollution data for sisimiut, GL
# Retrieved pollution data for ponta delgada, PT
# Retrieved pollution data for jamestown, US
# Retrieved pollution data for east london, ZA
# Retrieved pollution data for grand forks, US
# Retrieved pollution data for la passe, FR
# Retrieved pollution data for coquimbo, CL
# Retrieved pollution data for bayt al faqih, YE
# Retrieved pollution data for santa sylvina, AR
# Retrieved pollution data for papatowai, NZ
# Retrieved pollution data for hawaiian paradise park, US
# Retrieved pollution data for holualoa, US
# Retrieved pollution data for fale old settlement, TK
# Retrieved pollution data for north platte, US
# Retrieved pollution data for edd, ER
# Retrieved pollution data for carnarvon, AU
# Retrieved pollution data for tarija, BO
# Retrieved pollution data for banjarmasin, ID
# Retrieved pollution data for karratha, AU
# Retrieved pollution data for hobyo, SO
# Retrieved pollution data for nuuk, GL
# Retrieved pollution data for soe, ID
# Retrieved pollution data for porto san giorgio, IT
# Retrieved pollution data for lapy, PL
# Retrieved pollution data for pyhajarvi, FI
# Retrieved pollution data for kibre mengist, ET
# Retrieved pollution data for hermanus, ZA
# Retrieved pollution data for puerto natales, CL
# Retrieved pollution data for bam, IR
# Retrieved pollution data for port mathurin, MU
# Retrieved pollution data for saint-philippe, RE
# Retrieved pollution data for remire-montjoly, GF
# Retrieved pollution data for ambikapur, IN
# Retrieved pollution data for alice springs, AU
# Retrieved pollution data for kujang-up, KP
# Retrieved pollution data for tonj, SS
# Retrieved pollution data for smithers, CA
# Retrieved pollution data for northam, GB
# Retrieved pollution data for novi di modena, IT
# Retrieved pollution data for kokhma, RU
# Retrieved pollution data for mahibadhoo, MV
# Retrieved pollution data for florida, US
# Retrieved pollution data for ca mau, VN
# Retrieved pollution data for tralee, IE
# Retrieved pollution data for fuling, CN
# Retrieved pollution data for samamiya, NG
# Retrieved pollution data for hamilton, US
# Retrieved pollution data for belmonte, BR
# Retrieved pollution data for kharabali, RU
# Retrieved pollution data for iskateley, RU
# Retrieved pollution data for caister-on-sea, GB
# Retrieved pollution data for agbor, NG
# Retrieved pollution data for cestos city, LR
# Retrieved pollution data for tiksi, RU
# Retrieved pollution data for kemijarvi, FI
# Retrieved pollution data for vila franca do campo, PT
# Retrieved pollution data for iqaluit, CA
# Retrieved pollution data for talnakh, RU
# Retrieved pollution data for puerto carreno, CO
# Retrieved pollution data for garoua boulai, CM
# Retrieved pollution data for ribeira grande, PT
# Retrieved pollution data for alotau, PG
# Retrieved pollution data for yellowknife, CA
# Retrieved pollution data for acarau, BR
# Retrieved pollution data for luderitz, NA
# Retrieved pollution data for ancud, CL
# Retrieved pollution data for hadibu, YE
# Retrieved pollution data for guigang, CN
# Retrieved pollution data for yuzhno-kurilsk, RU
# Retrieved pollution data for nabire, ID
# Retrieved pollution data for tazovsky, RU
# Retrieved pollution data for saint john, CA
# Retrieved pollution data for angra do heroismo, PT
# Retrieved pollution data for alaghsas, NE
# Retrieved pollution data for margaret river, AU
# Retrieved pollution data for mount isa, AU
# Retrieved pollution data for cannonvale, AU
# Retrieved pollution data for vilyuchinsk, RU
# Retrieved pollution data for vadso, NO
# Retrieved pollution data for punta arenas, CL
# Retrieved pollution data for ust-nera, RU
# Retrieved pollution data for lihue, US
# Retrieved pollution data for zaragoza, ES
# Retrieved pollution data for guerrero negro, MX
# Retrieved pollution data for usinsk, RU
# Retrieved pollution data for nova vicosa, BR
# Retrieved pollution data for al jawf, SA
# Retrieved pollution data for taoudenni, ML
# Retrieved pollution data for san luis de la loma, MX
# Retrieved pollution data for bondoukou, CI
# Retrieved pollution data for corund, RO
# Retrieved pollution data for el tocuyo, VE
# Retrieved pollution data for okhotsk, RU
# Retrieved pollution data for kisarawe, TZ
# Retrieved pollution data for praia da vitoria, PT
# Retrieved pollution data for masaya sur, PH
# Retrieved pollution data for berdigestyakh, RU
# Retrieved pollution data for uturoa, PF
# Retrieved pollution data for lagos, NG
# Retrieved pollution data for doka, SD
# Retrieved pollution data for hastings, GB
# Retrieved pollution data for isola di capo rizzuto, IT
# Retrieved pollution data for zvishavane, ZW
# Retrieved pollution data for palu, ID
# Retrieved pollution data for georgetown, MY
# Retrieved pollution data for phalaborwa, ZA
# Retrieved pollution data for sol'-iletsk, RU
# Retrieved pollution data for la ronge, CA
# Retrieved pollution data for aasiaat, GL
# Retrieved pollution data for abbeville, FR
# Retrieved pollution data for alta, NO
# Retrieved pollution data for hithadhoo, MV
# Retrieved pollution data for chonchi, CL
# Retrieved pollution data for thinadhoo, MV
# Retrieved pollution data for minas de marcona, PE
# Retrieved pollution data for happy valley-goose bay, CA
# Retrieved pollution data for ta`u, AS
# Retrieved pollution data for jimenez, MX
# Retrieved pollution data for biloela, AU
# Retrieved pollution data for tolanaro, MG
# Retrieved pollution data for amos, CA
# Retrieved pollution data for xining, CN
# Retrieved pollution data for copiapo, CL
# Retrieved pollution data for casper, US
# Retrieved pollution data for miyaly, KZ
# Retrieved pollution data for ciudad lazaro cardenas, MX
# Retrieved pollution data for gamba, GA
# Retrieved pollution data for santyoku, KR
# Retrieved pollution data for keflavik, IS
# Retrieved pollution data for mossel bay, ZA
# Retrieved pollution data for college, US
# Retrieved pollution data for pimentel, PE
# Retrieved pollution data for cole harbour, CA
# Retrieved pollution data for dadhar, PK
# Retrieved pollution data for longyearbyen, SJ
# Retrieved pollution data for mega, ET
# Retrieved pollution data for pemangkat, ID
# Retrieved pollution data for queenstown, ZA
# Retrieved pollution data for nikolayevsk-on-amure, RU
# Retrieved pollution data for zavoronezhskoye, RU
# Retrieved pollution data for atafu village, TK
# Retrieved pollution data for effingham, US
# Retrieved pollution data for bathurst, AU
# Retrieved pollution data for canmore, CA
# Retrieved pollution data for puerto baquerizo moreno, EC
# Retrieved pollution data for shenkursk, RU
# Retrieved pollution data for medina, SA
# Retrieved pollution data for mejit, MH
# Retrieved pollution data for arraial do cabo, BR
# Retrieved pollution data for brookings, US
# Retrieved pollution data for qingdao, CN
# Retrieved pollution data for tanjung pinang, ID
# Retrieved pollution data for brisas de zicatela, MX
# Retrieved pollution data for alliance, US
# Retrieved pollution data for petropavlovsk-kamchatsky, RU
# Retrieved pollution data for beyneu, KZ
# Retrieved pollution data for hosdurga, IN
# Retrieved pollution data for burutu, NG
# Retrieved pollution data for bennington, US
# Retrieved pollution data for kingston, JM
# Retrieved pollution data for igrim, RU
# Retrieved pollution data for puerto aysen, CL
# Retrieved pollution data for enchanted hills, US
# Retrieved pollution data for macapa, BR
# Retrieved pollution data for vikhorevka, RU
# Retrieved pollution data for la'ie, US
# Retrieved pollution data for filey, GB
# Retrieved pollution data for sao jose da coroa grande, BR
# Retrieved pollution data for quellon, CL
# Retrieved pollution data for mutuali, MZ
# Retrieved pollution data for jharsuguda, IN
# Retrieved pollution data for lib, MH
# Retrieved pollution data for port douglas, AU
# Retrieved pollution data for haiku-pauwela, US
# Retrieved pollution data for talitsa, RU
# Retrieved pollution data for san antonio de pale, GQ
# Retrieved pollution data for almeirim, BR
# Retrieved pollution data for xai-xai, MZ
# Retrieved pollution data for laguna, US
# Retrieved pollution data for whitehorse, CA
# Retrieved pollution data for markovo, RU
# Retrieved pollution data for port elizabeth, ZA
# Retrieved pollution data for kismayo, SO
# Retrieved pollution data for formosa, AR
# Retrieved pollution data for elverum, NO
# Retrieved pollution data for zag, MN
# Retrieved pollution data for yetkul', RU
# Retrieved pollution data for prado, BR
# Retrieved pollution data for okha, RU
# Retrieved pollution data for san felipe, VE
# Retrieved pollution data for beeville, US
# Retrieved pollution data for kamaishi, JP
# Retrieved pollution data for vorkuta, RU
# Retrieved pollution data for savanna-la-mar, JM
# Retrieved pollution data for plastun, RU
# Retrieved pollution data for castillos, UY
# Retrieved pollution data for fada, NG
# Retrieved pollution data for saldanha, ZA
# Retrieved pollution data for salinopolis, BR
# Retrieved pollution data for mossoro, BR
# Retrieved pollution data for isangel, VU
# Retrieved pollution data for inirida, CO
# Retrieved pollution data for tegina, NG
# Retrieved pollution data for kuusamo, FI
# Retrieved pollution data for muravlenko, RU
# Retrieved pollution data for hazleton, US
# Retrieved pollution data for papao, PF
# Retrieved pollution data for noyabrsk, RU
# Retrieved pollution data for safi, MA
# Retrieved pollution data for grand gaube, MU
# Retrieved pollution data for cartagena, CO
# Retrieved pollution data for lata, PT
# Retrieved pollution data for paharpur, PK
# Retrieved pollution data for dunedin, NZ
# Retrieved pollution data for dalandzadgad, MN
# Retrieved pollution data for xingcheng, CN
# Retrieved pollution data for toliara, MG
# Retrieved pollution data for tommot, RU
# Retrieved pollution data for kuchera, IN
# Retrieved pollution data for huarmey, PE
# Retrieved pollution data for el calafate, AR
# Retrieved pollution data for nea alikarnassos, GR
# Retrieved pollution data for hanceville, US
# Retrieved pollution data for belyy yar, RU
# Retrieved pollution data for yeniseysk, RU
# Retrieved pollution data for bushehr, IR
# Retrieved pollution data for grand falls-windsor, CA
# Retrieved pollution data for pierre, US
# Retrieved pollution data for chimore, BO
# Retrieved pollution data for fuwwah, EG
# Retrieved pollution data for rabo de peixe, PT
# Retrieved pollution data for nema, RU
# Retrieved pollution data for miri, MY
# Retrieved pollution data for port alfred, ZA
# Retrieved pollution data for zhangatas, KZ
# Retrieved pollution data for raja, SS
# Retrieved pollution data for bereznik, RU
# Retrieved pollution data for sirte, LY
# Retrieved pollution data for smara, EH
# Retrieved pollution data for barclayville, LR
# Retrieved pollution data for vila velha, BR
# Retrieved pollution data for kudymkar, RU
# Retrieved pollution data for rawson, AR
# Retrieved pollution data for cidreira, BR
# Retrieved pollution data for argo, GR
# Retrieved pollution data for kenora, CA
# Retrieved pollution data for shendi, SD
# Retrieved pollution data for hancheng, CN
# Retrieved pollution data for simpang, ID
# Retrieved pollution data for port blair, IN
# Retrieved pollution data for nagqu, CN
# Retrieved pollution data for arkalyk, KZ
# Retrieved pollution data for maba, CN
# Retrieved pollution data for ambon, ID
# Retrieved pollution data for saint-flour, FR
# Retrieved pollution data for yerbabuena, MX
# Retrieved pollution data for mili, MH
# Retrieved pollution data for trairi, BR
# Retrieved pollution data for ubinskoye, RU
# Retrieved pollution data for cabo san lucas, MX
# Retrieved pollution data for betioky, MG
# Retrieved pollution data for malabar, AU
# Retrieved pollution data for lamu, KE
# Retrieved pollution data for balabac, PH
# Retrieved pollution data for bodaybo, RU
# Retrieved pollution data for marsa alam, EG
# Retrieved pollution data for santa cruz, BO
# Retrieved pollution data for san rafael, AR
# Retrieved pollution data for mount pearl, CA
# Retrieved pollution data for maralal, KE
# Retrieved pollution data for kostomuksha, RU
# Retrieved pollution data for gamay, PH
# Retrieved pollution data for svetlyy yar, RU
# Retrieved pollution data for klyuchi, RU
# Retrieved pollution data for clovis, US
# Retrieved pollution data for lampang, TH
# Retrieved pollution data for tongouson, PH
# Retrieved pollution data for lahad datu, MY
# Retrieved pollution data for inari, FI
# Retrieved pollution data for ataq, YE
# Retrieved pollution data for kourou, GF
# Retrieved pollution data for wainwright, CA
# Retrieved pollution data for zhangjiakou, CN
# Retrieved pollution data for oromocto, CA
# Retrieved pollution data for san patricio, US
# Retrieved pollution data for puerto ayacucho, VE
# Retrieved pollution data for nacala, MZ
# Retrieved pollution data for wad az zaki, SD
# Retrieved pollution data for broken hill, AU
# Retrieved pollution data for igarka, RU
# Retrieved pollution data for kukuna, SL
# Retrieved pollution data for cockburn town, TC
# Retrieved pollution data for dom pedrito, BR
# Retrieved pollution data for lae, PG
# Retrieved pollution data for saint-pierre, RE
# Retrieved pollution data for st. john's, CA
# Retrieved pollution data for howrah, IN
# Retrieved pollution data for naze, JP
# Retrieved pollution data for magburaka, SL
# Retrieved pollution data for kayar, SN
# Retrieved pollution data for sterling, US
# Retrieved pollution data for coffs harbour, AU
# Retrieved pollution data for khandyga, RU
# Retrieved pollution data for masterton, NZ
# Retrieved pollution data for qinhuangdao, CN
# Retrieved pollution data for kenai, US
# Retrieved pollution data for road town, VG
# Retrieved pollution data for cudillero, ES
# Retrieved pollution data for knokke, BE
# Retrieved pollution data for vakhrushi, RU
# Retrieved pollution data for lajinha, BR
# Retrieved pollution data for cidade velha, CV
# Retrieved pollution data for fort bragg, US
# Retrieved pollution data for kutum, SD
# Retrieved pollution data for afaahiti, PF
# Retrieved pollution data for bure, ET
# Retrieved pollution data for jirja, EG
# Retrieved pollution data for hami, CN
# Retrieved pollution data for midvagur, FO
# Retrieved pollution data for nantucket, US
# Retrieved pollution data for nong khae, TH
# Retrieved pollution data for mucuri, BR
# Retrieved pollution data for al qusayr, SY
# Retrieved pollution data for constantia, RO
# Retrieved pollution data for mezhdurechensk, RU
# Retrieved pollution data for kachkanar, RU
# Retrieved pollution data for sarina, AU
# Retrieved pollution data for ola, RU
# Retrieved pollution data for namibe, AO
# Retrieved pollution data for ghat, LY
# Retrieved pollution data for tonghae, KR
# Retrieved pollution data for nar'yan-mar, RU
# Retrieved pollution data for callao, PE
# Retrieved pollution data for sinabang, ID
# Retrieved pollution data for villa gesell, AR
# Retrieved pollution data for warmbad, NA
# Retrieved pollution data for maisi, GE
# Retrieved pollution data for port saint john's, ZA
# Retrieved pollution data for yueyang, CN
# Retrieved pollution data for labrador city, CA
# Retrieved pollution data for kertih, MY
# Retrieved pollution data for irbit, RU
# Retrieved pollution data for jinchang, CN
# Retrieved pollution data for tarfaya, MA
# Retrieved pollution data for kingisepp, RU
# Retrieved pollution data for salmon arm, CA
# Retrieved pollution data for pordic, FR
# Retrieved pollution data for jining, CN
# Retrieved pollution data for yanchep, AU
# Retrieved pollution data for egilsstadir, IS
# Retrieved pollution data for codrington, AU
# Retrieved pollution data for debre tabor, ET
# Retrieved pollution data for conceicao da barra, BR
# Retrieved pollution data for wynyard, AU
#                           City Country  PM2.5   PM10    NO2     O3    SO2  \
# 0                     huangmei      CN  49.51  54.46  48.67  22.17  12.99
# 1                        sitka      US   0.63   0.80   0.41  77.25   0.30
# 2                       badger      US   0.50   0.63   5.14  51.50   1.10
# 3  edinburgh of the seven seas      SH   0.50   1.50   0.03  51.50   0.03
# 4                      ballina      AU   2.57   6.26   0.80  66.52   1.07
#
#         CO   NH3
# 0  1161.58  0.00
# 1   216.96  0.00
# 2   257.02  0.22
# 3   233.65  0.00
# 4   230.31  0.67

# %%
air_quality_df.to_csv('Resources/air_quality_data.csv', index=False)

# %%
# Create a dictionary to store city-country pairs
city_country_map = {}

for city in city_names:
    try:
        query_url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}"
        response = requests.get(query_url).json()
        
        # Store the city and corresponding country code
        country = response['sys']['country']
        city_country_map[city] = country

        # Print city and country
        print(f"City: {city}, Country: {country}")

    except KeyError as key_err:
        print(f"KeyError: {key_err} for {city}. Skipping...")
    except requests.exceptions.RequestException as req_err:
        print(f"Request error: {req_err} for {city}. Skipping...")

    # Pause to avoid rate limiting
    time.sleep(1)

print(city_country_map)
# Out:
# City: huangmei, Country: CN
# City: sitka, Country: US
# City: badger, Country: US
# City: edinburgh of the seven seas, Country: SH
# City: ballina, Country: AU
# City: wailua homesteads, Country: US
# City: west island, Country: CC
# City: tobelo, Country: ID
# City: puerto ayora, Country: EC
# City: port-aux-francais, Country: TF
# City: albany, Country: US
# City: gizo, Country: SB
# City: angaur state, Country: PW
# City: adamstown, Country: PN
# City: tazacorte, Country: ES
# City: clanton, Country: US
# City: silifke, Country: TR
# City: olonkinbyen, Country: SJ
# City: tura, Country: IN
# City: solleftea, Country: SE
# City: stanley, Country: GB
# City: mongoumba, Country: CF
# City: bamboo flat, Country: IN
# City: nemuro, Country: JP
# City: bethel, Country: US
# City: taroa, Country: MH
# City: gopalpur, Country: IN
# City: invercargill, Country: NZ
# City: ushuaia, Country: AR
# City: bilibino, Country: RU
# City: puerto deseado, Country: AR
# City: susuman, Country: RU
# City: isafjordur, Country: IS
# City: cabugao, Country: PH
# City: cadale, Country: SO
# City: whakatane, Country: NZ
# City: xiongzhou, Country: CN
# City: childress, Country: US
# City: grytviken, Country: GS
# City: vorgashor, Country: RU
# City: anadyr, Country: RU
# City: kapa'a, Country: US
# City: mastic beach, Country: US
# City: bodo, Country: NO
# City: pacific grove, Country: US
# City: waitangi, Country: NZ
# City: mammoth lakes, Country: US
# City: colonia, Country: DE
# City: port lincoln, Country: AU
# City: qaqortoq, Country: GL
# City: campoverde, Country: PE
# City: lebu, Country: CL
# City: udachny, Country: RU
# City: kodiak, Country: US
# City: big bend, Country: SZ
# City: lerwick, Country: GB
# City: new norfolk, Country: AU
# City: aliveri, Country: GR
# City: ilulissat, Country: GL
# City: fisterra, Country: ES
# City: mumbwa, Country: ZM
# City: berriozabal, Country: MX
# City: utrik, Country: MH
# City: port augusta, Country: AU
# City: blackmans bay, Country: AU
# City: correntina, Country: BR
# City: bredasdorp, Country: ZA
# City: avarua, Country: CK
# City: kirakira, Country: SB
# City: amahai, Country: ID
# City: weno, Country: FM
# City: cheria, Country: DZ
# City: enewetak, Country: MH
# City: tamandare, Country: BR
# City: sao joao da barra, Country: BR
# City: aykhal, Country: RU
# City: magadan, Country: RU
# City: umm kaddadah, Country: SD
# City: sidney, Country: AU
# City: thompson, Country: CA
# City: sisimiut, Country: GL
# City: ponta delgada, Country: PT
# City: jamestown, Country: US
# City: east london, Country: ZA
# City: grand forks, Country: US
# City: la passe, Country: FR
# City: coquimbo, Country: CL
# City: bayt al faqih, Country: YE
# City: santa sylvina, Country: AR
# City: papatowai, Country: NZ
# City: hawaiian paradise park, Country: US
# City: holualoa, Country: US
# City: fale old settlement, Country: TK
# City: north platte, Country: US
# City: edd, Country: ER
# City: carnarvon, Country: AU
# City: tarija, Country: BO
# City: banjarmasin, Country: ID
# City: karratha, Country: AU
# City: hobyo, Country: SO
# City: nuuk, Country: GL
# City: soe, Country: ID
# City: porto san giorgio, Country: IT
# City: lapy, Country: PL
# City: pyhajarvi, Country: FI
# City: kibre mengist, Country: ET
# City: hermanus, Country: ZA
# City: puerto natales, Country: CL
# City: bam, Country: IR
# City: port mathurin, Country: MU
# City: saint-philippe, Country: RE
# City: remire-montjoly, Country: GF
# City: ambikapur, Country: IN
# City: alice springs, Country: AU
# City: kujang-up, Country: KP
# City: tonj, Country: SS
# City: smithers, Country: CA
# City: northam, Country: GB
# City: novi di modena, Country: IT
# City: kokhma, Country: RU
# City: mahibadhoo, Country: MV
# City: florida, Country: US
# City: ca mau, Country: VN
# City: tralee, Country: IE
# City: fuling, Country: CN
# City: samamiya, Country: NG
# City: hamilton, Country: US
# City: belmonte, Country: BR
# City: kharabali, Country: RU
# City: iskateley, Country: RU
# City: caister-on-sea, Country: GB
# City: agbor, Country: NG
# City: cestos city, Country: LR
# City: tiksi, Country: RU
# City: kemijarvi, Country: FI
# City: vila franca do campo, Country: PT
# City: iqaluit, Country: CA
# City: talnakh, Country: RU
# City: puerto carreno, Country: CO
# City: garoua boulai, Country: CM
# City: ribeira grande, Country: PT
# City: alotau, Country: PG
# City: yellowknife, Country: CA
# City: acarau, Country: BR
# City: luderitz, Country: NA
# City: ancud, Country: CL
# City: hadibu, Country: YE
# City: guigang, Country: CN
# City: yuzhno-kurilsk, Country: RU
# City: nabire, Country: ID
# City: tazovsky, Country: RU
# City: saint john, Country: CA
# City: angra do heroismo, Country: PT
# City: alaghsas, Country: NE
# City: margaret river, Country: AU
# City: mount isa, Country: AU
# City: cannonvale, Country: AU
# City: vilyuchinsk, Country: RU
# City: vadso, Country: NO
# City: punta arenas, Country: CL
# City: ust-nera, Country: RU
# City: lihue, Country: US
# City: zaragoza, Country: ES
# City: guerrero negro, Country: MX
# City: usinsk, Country: RU
# City: nova vicosa, Country: BR
# City: al jawf, Country: SA
# City: taoudenni, Country: ML
# City: san luis de la loma, Country: MX
# City: bondoukou, Country: CI
# City: corund, Country: RO
# City: el tocuyo, Country: VE
# City: okhotsk, Country: RU
# City: kisarawe, Country: TZ
# City: praia da vitoria, Country: PT
# City: masaya sur, Country: PH
# City: berdigestyakh, Country: RU
# City: uturoa, Country: PF
# City: lagos, Country: NG
# City: doka, Country: SD
# City: hastings, Country: GB
# City: isola di capo rizzuto, Country: IT
# City: zvishavane, Country: ZW
# City: palu, Country: ID
# City: georgetown, Country: MY
# City: phalaborwa, Country: ZA
# City: sol'-iletsk, Country: RU
# City: la ronge, Country: CA
# City: aasiaat, Country: GL
# City: abbeville, Country: FR
# City: alta, Country: NO
# City: hithadhoo, Country: MV
# City: chonchi, Country: CL
# City: thinadhoo, Country: MV
# City: minas de marcona, Country: PE
# City: happy valley-goose bay, Country: CA
# City: ta`u, Country: AS
# City: jimenez, Country: MX
# City: biloela, Country: AU
# City: tolanaro, Country: MG
# City: amos, Country: CA
# City: xining, Country: CN
# City: copiapo, Country: CL
# City: casper, Country: US
# City: miyaly, Country: KZ
# City: ciudad lazaro cardenas, Country: MX
# City: gamba, Country: GA
# City: santyoku, Country: KR
# City: keflavik, Country: IS
# City: mossel bay, Country: ZA
# City: college, Country: US
# City: pimentel, Country: PE
# City: cole harbour, Country: CA
# City: dadhar, Country: PK
# City: longyearbyen, Country: SJ
# City: mega, Country: ET
# City: pemangkat, Country: ID
# City: queenstown, Country: ZA
# City: nikolayevsk-on-amure, Country: RU
# City: zavoronezhskoye, Country: RU
# City: atafu village, Country: TK
# City: effingham, Country: US
# City: bathurst, Country: AU
# City: canmore, Country: CA
# City: puerto baquerizo moreno, Country: EC
# City: shenkursk, Country: RU
# City: medina, Country: SA
# City: mejit, Country: MH
# City: arraial do cabo, Country: BR
# City: brookings, Country: US
# City: qingdao, Country: CN
# City: tanjung pinang, Country: ID
# City: brisas de zicatela, Country: MX
# City: alliance, Country: US
# City: petropavlovsk-kamchatsky, Country: RU
# City: beyneu, Country: KZ
# City: hosdurga, Country: IN
# City: burutu, Country: NG
# City: bennington, Country: US
# City: kingston, Country: JM
# City: igrim, Country: RU
# City: puerto aysen, Country: CL
# City: enchanted hills, Country: US
# City: macapa, Country: BR
# City: vikhorevka, Country: RU
# City: la'ie, Country: US
# City: filey, Country: GB
# City: sao jose da coroa grande, Country: BR
# City: quellon, Country: CL
# City: mutuali, Country: MZ
# City: jharsuguda, Country: IN
# City: lib, Country: MH
# City: port douglas, Country: AU
# City: haiku-pauwela, Country: US
# City: talitsa, Country: RU
# City: san antonio de pale, Country: GQ
# City: almeirim, Country: BR
# City: xai-xai, Country: MZ
# City: laguna, Country: US
# City: whitehorse, Country: CA
# City: markovo, Country: RU
# City: port elizabeth, Country: ZA
# City: kismayo, Country: SO
# City: formosa, Country: AR
# City: elverum, Country: NO
# City: zag, Country: MN
# City: yetkul', Country: RU
# City: prado, Country: BR
# City: okha, Country: RU
# City: san felipe, Country: VE
# City: beeville, Country: US
# City: kamaishi, Country: JP
# City: vorkuta, Country: RU
# City: savanna-la-mar, Country: JM
# City: plastun, Country: RU
# City: castillos, Country: UY
# City: fada, Country: NG
# City: saldanha, Country: ZA
# City: salinopolis, Country: BR
# City: mossoro, Country: BR
# City: isangel, Country: VU
# City: inirida, Country: CO
# City: tegina, Country: NG
# City: kuusamo, Country: FI
# City: muravlenko, Country: RU
# City: hazleton, Country: US
# City: papao, Country: PF
# City: noyabrsk, Country: RU
# City: safi, Country: MA
# City: grand gaube, Country: MU
# City: cartagena, Country: CO
# City: lata, Country: PT
# City: paharpur, Country: PK
# City: dunedin, Country: NZ
# City: dalandzadgad, Country: MN
# City: xingcheng, Country: CN
# City: toliara, Country: MG
# City: tommot, Country: RU
# City: kuchera, Country: IN
# City: huarmey, Country: PE
# City: el calafate, Country: AR
# City: nea alikarnassos, Country: GR
# City: hanceville, Country: US
# City: belyy yar, Country: RU
# City: yeniseysk, Country: RU
# City: bushehr, Country: IR
# City: grand falls-windsor, Country: CA
# City: pierre, Country: US
# City: chimore, Country: BO
# City: fuwwah, Country: EG
# City: rabo de peixe, Country: PT
# City: nema, Country: RU
# City: miri, Country: MY
# City: port alfred, Country: ZA
# City: zhangatas, Country: KZ
# City: raja, Country: SS
# City: bereznik, Country: RU
# City: sirte, Country: LY
# City: smara, Country: EH
# City: barclayville, Country: LR
# City: vila velha, Country: BR
# City: kudymkar, Country: RU
# City: rawson, Country: AR
# City: cidreira, Country: BR
# City: argo, Country: GR
# City: kenora, Country: CA
# City: shendi, Country: SD
# City: hancheng, Country: CN
# City: simpang, Country: ID
# City: port blair, Country: IN
# City: nagqu, Country: CN
# City: arkalyk, Country: KZ
# City: maba, Country: CN
# City: ambon, Country: ID
# City: saint-flour, Country: FR
# City: yerbabuena, Country: MX
# City: mili, Country: MH
# City: trairi, Country: BR
# City: ubinskoye, Country: RU
# City: cabo san lucas, Country: MX
# City: betioky, Country: MG
# City: malabar, Country: AU
# City: lamu, Country: KE
# City: balabac, Country: PH
# City: bodaybo, Country: RU
# City: marsa alam, Country: EG
# City: santa cruz, Country: BO
# City: san rafael, Country: AR
# City: mount pearl, Country: CA
# City: maralal, Country: KE
# City: kostomuksha, Country: RU
# City: gamay, Country: PH
# City: svetlyy yar, Country: RU
# City: klyuchi, Country: RU
# City: clovis, Country: US
# City: lampang, Country: TH
# City: tongouson, Country: PH
# City: lahad datu, Country: MY
# City: inari, Country: FI
# City: ataq, Country: YE
# City: kourou, Country: GF
# City: wainwright, Country: CA
# City: zhangjiakou, Country: CN
# City: oromocto, Country: CA
# City: san patricio, Country: US
# City: puerto ayacucho, Country: VE
# City: nacala, Country: MZ
# City: wad az zaki, Country: SD
# City: broken hill, Country: AU
# City: igarka, Country: RU
# City: kukuna, Country: SL
# City: cockburn town, Country: TC
# City: dom pedrito, Country: BR
# City: lae, Country: PG
# City: saint-pierre, Country: RE
# City: st. john's, Country: CA
# City: howrah, Country: IN
# City: naze, Country: JP
# City: magburaka, Country: SL
# City: kayar, Country: SN
# City: sterling, Country: US
# City: coffs harbour, Country: AU
# City: khandyga, Country: RU
# City: masterton, Country: NZ
# City: qinhuangdao, Country: CN
# City: kenai, Country: US
# City: road town, Country: VG
# City: cudillero, Country: ES
# City: knokke, Country: BE
# City: vakhrushi, Country: RU
# City: lajinha, Country: BR
# City: cidade velha, Country: CV
# City: fort bragg, Country: US
# City: kutum, Country: SD
# City: afaahiti, Country: PF
# City: bure, Country: ET
# City: jirja, Country: EG
# City: hami, Country: CN
# City: midvagur, Country: FO
# City: nantucket, Country: US
# City: nong khae, Country: TH
# City: mucuri, Country: BR
# City: al qusayr, Country: SY
# City: constantia, Country: RO
# City: mezhdurechensk, Country: RU
# City: kachkanar, Country: RU
# City: sarina, Country: AU
# City: ola, Country: RU
# City: namibe, Country: AO
# City: ghat, Country: LY
# City: tonghae, Country: KR
# City: nar'yan-mar, Country: RU
# City: callao, Country: PE
# City: sinabang, Country: ID
# City: villa gesell, Country: AR
# City: warmbad, Country: NA
# City: maisi, Country: GE
# City: port saint john's, Country: ZA
# City: yueyang, Country: CN
# City: labrador city, Country: CA
# City: kertih, Country: MY
# City: irbit, Country: RU
# City: jinchang, Country: CN
# City: tarfaya, Country: MA
# City: kingisepp, Country: RU
# City: salmon arm, Country: CA
# City: pordic, Country: FR
# City: jining, Country: CN
# City: yanchep, Country: AU
# City: egilsstadir, Country: IS
# City: codrington, Country: AU
# City: debre tabor, Country: ET
# City: conceicao da barra, Country: BR
# City: wynyard, Country: AU
# {'huangmei': 'CN', 'sitka': 'US', 'badger': 'US', 'edinburgh of the seven seas': 'SH', 'ballina': 'AU', 'wailua homesteads': 'US', 'west island': 'CC', 'tobelo': 'ID', 'puerto ayora': 'EC', 'port-aux-francais': 'TF', 'albany': 'US', 'gizo': 'SB', 'angaur state': 'PW', 'adamstown': 'PN', 'tazacorte': 'ES', 'clanton': 'US', 'silifke': 'TR', 'olonkinbyen': 'SJ', 'tura': 'IN', 'solleftea': 'SE', 'stanley': 'GB', 'mongoumba': 'CF', 'bamboo flat': 'IN', 'nemuro': 'JP', 'bethel': 'US', 'taroa': 'MH', 'gopalpur': 'IN', 'invercargill': 'NZ', 'ushuaia': 'AR', 'bilibino': 'RU', 'puerto deseado': 'AR', 'susuman': 'RU', 'isafjordur': 'IS', 'cabugao': 'PH', 'cadale': 'SO', 'whakatane': 'NZ', 'xiongzhou': 'CN', 'childress': 'US', 'grytviken': 'GS', 'vorgashor': 'RU', 'anadyr': 'RU', "kapa'a": 'US', 'mastic beach': 'US', 'bodo': 'NO', 'pacific grove': 'US', 'waitangi': 'NZ', 'mammoth lakes': 'US', 'colonia': 'DE', 'port lincoln': 'AU', 'qaqortoq': 'GL', 'campoverde': 'PE', 'lebu': 'CL', 'udachny': 'RU', 'kodiak': 'US', 'big bend': 'SZ', 'lerwick': 'GB', 'new norfolk': 'AU', 'aliveri': 'GR', 'ilulissat': 'GL', 'fisterra': 'ES', 'mumbwa': 'ZM', 'berriozabal': 'MX', 'utrik': 'MH', 'port augusta': 'AU', 'blackmans bay': 'AU', 'correntina': 'BR', 'bredasdorp': 'ZA', 'avarua': 'CK', 'kirakira': 'SB', 'amahai': 'ID', 'weno': 'FM', 'cheria': 'DZ', 'enewetak': 'MH', 'tamandare': 'BR', 'sao joao da barra': 'BR', 'aykhal': 'RU', 'magadan': 'RU', 'umm kaddadah': 'SD', 'sidney': 'AU', 'thompson': 'CA', 'sisimiut': 'GL', 'ponta delgada': 'PT', 'jamestown': 'US', 'east london': 'ZA', 'grand forks': 'US', 'la passe': 'FR', 'coquimbo': 'CL', 'bayt al faqih': 'YE', 'santa sylvina': 'AR', 'papatowai': 'NZ', 'hawaiian paradise park': 'US', 'holualoa': 'US', 'fale old settlement': 'TK', 'north platte': 'US', 'edd': 'ER', 'carnarvon': 'AU', 'tarija': 'BO', 'banjarmasin': 'ID', 'karratha': 'AU', 'hobyo': 'SO', 'nuuk': 'GL', 'soe': 'ID', 'porto san giorgio': 'IT', 'lapy': 'PL', 'pyhajarvi': 'FI', 'kibre mengist': 'ET', 'hermanus': 'ZA', 'puerto natales': 'CL', 'bam': 'IR', 'port mathurin': 'MU', 'saint-philippe': 'RE', 'remire-montjoly': 'GF', 'ambikapur': 'IN', 'alice springs': 'AU', 'kujang-up': 'KP', 'tonj': 'SS', 'smithers': 'CA', 'northam': 'GB', 'novi di modena': 'IT', 'kokhma': 'RU', 'mahibadhoo': 'MV', 'florida': 'US', 'ca mau': 'VN', 'tralee': 'IE', 'fuling': 'CN', 'samamiya': 'NG', 'hamilton': 'US', 'belmonte': 'BR', 'kharabali': 'RU', 'iskateley': 'RU', 'caister-on-sea': 'GB', 'agbor': 'NG', 'cestos city': 'LR', 'tiksi': 'RU', 'kemijarvi': 'FI', 'vila franca do campo': 'PT', 'iqaluit': 'CA', 'talnakh': 'RU', 'puerto carreno': 'CO', 'garoua boulai': 'CM', 'ribeira grande': 'PT', 'alotau': 'PG', 'yellowknife': 'CA', 'acarau': 'BR', 'luderitz': 'NA', 'ancud': 'CL', 'hadibu': 'YE', 'guigang': 'CN', 'yuzhno-kurilsk': 'RU', 'nabire': 'ID', 'tazovsky': 'RU', 'saint john': 'CA', 'angra do heroismo': 'PT', 'alaghsas': 'NE', 'margaret river': 'AU', 'mount isa': 'AU', 'cannonvale': 'AU', 'vilyuchinsk': 'RU', 'vadso': 'NO', 'punta arenas': 'CL', 'ust-nera': 'RU', 'lihue': 'US', 'zaragoza': 'ES', 'guerrero negro': 'MX', 'usinsk': 'RU', 'nova vicosa': 'BR', 'al jawf': 'SA', 'taoudenni': 'ML', 'san luis de la loma': 'MX', 'bondoukou': 'CI', 'corund': 'RO', 'el tocuyo': 'VE', 'okhotsk': 'RU', 'kisarawe': 'TZ', 'praia da vitoria': 'PT', 'masaya sur': 'PH', 'berdigestyakh': 'RU', 'uturoa': 'PF', 'lagos': 'NG', 'doka': 'SD', 'hastings': 'GB', 'isola di capo rizzuto': 'IT', 'zvishavane': 'ZW', 'palu': 'ID', 'georgetown': 'MY', 'phalaborwa': 'ZA', "sol'-iletsk": 'RU', 'la ronge': 'CA', 'aasiaat': 'GL', 'abbeville': 'FR', 'alta': 'NO', 'hithadhoo': 'MV', 'chonchi': 'CL', 'thinadhoo': 'MV', 'minas de marcona': 'PE', 'happy valley-goose bay': 'CA', 'ta`u': 'AS', 'jimenez': 'MX', 'biloela': 'AU', 'tolanaro': 'MG', 'amos': 'CA', 'xining': 'CN', 'copiapo': 'CL', 'casper': 'US', 'miyaly': 'KZ', 'ciudad lazaro cardenas': 'MX', 'gamba': 'GA', 'santyoku': 'KR', 'keflavik': 'IS', 'mosse ...

# %%
print(f"Total cities: {len(city_country_map)}")
# Out:
# Total cities: 434

# %%
data = list(city_country_map.items())

# Create the DataFrame
df = pd.DataFrame(data, columns=['City', 'Country'])

# Save the DataFrame to a CSV file
df.to_csv('Resources/city_country_map.csv', index=False, encoding='utf-8')

# %%
# Get all the unique countries from the city-country map
unique_countries = set(city_country_map.values())

# Print the count and the list of unique countries
print(f"Total unique countries: {len(unique_countries)}")
print(unique_countries)
# Out:
# Total unique countries: 106
# {'ZA', 'JP', 'IE', 'GE', 'IS', 'NG', 'BE', 'KE', 'MU', 'CK', 'GB', 'NO', 'FO', 'GF', 'VU', 'SE', 'DZ', 'MX', 'MH', 'SS', 'RO', 'GA', 'ER', 'ET', 'SH', 'DE', 'PF', 'EH', 'KP', 'CL', 'CN', 'PE', 'CI', 'BR', 'TH', 'GL', 'PN', 'FR', 'LY', 'VG', 'NZ', 'SY', 'AU', 'KZ', 'SA', 'CF', 'RU', 'MY', 'IR', 'MZ', 'YE', 'IT', 'NA', 'VN', 'AR', 'SB', 'AS', 'PL', 'MG', 'SZ', 'BO', 'KR', 'SO', 'NE', 'ID', 'ZW', 'CO', 'CA', 'CM', 'ES', 'SD', 'FM', 'PK', 'CC', 'SJ', 'VE', 'PT', 'RE', 'GS', 'ZM', 'FI', 'GQ', 'PW', 'MN', 'AO', 'UY', 'TK', 'MA', 'ML', 'JM', 'EG', 'US', 'PH', 'SL', 'CV', 'TR', 'MV', 'TZ', 'IN', 'TF', 'PG', 'TC', 'SN', 'LR', 'EC', 'GR'}

# %%
import pycountry

# WHO API: Get all available countries and their alpha-3 codes
who_url = "https://ghoapi.azureedge.net/api/DIMENSION/COUNTRY/DimensionValues"
who_response = requests.get(who_url).json()

# Convert WHO countries from alpha-3 to alpha-2 codes to be matched withOpenWeather Country Code
who_countries_alpha2 = {}

for entry in who_response['value']:
    alpha_3 = entry['Code']
    country_name = entry['Title']

    # Convert alpha-3 to alpha-2 code using pycountry
    try:
        alpha_2 = pycountry.countries.get(alpha_3=alpha_3).alpha_2
        who_countries_alpha2[alpha_2] = country_name
    except AttributeError:
        print(f"Skipping {alpha_3} - No matching alpha-2 code found.")

print(f"WHO Countries (alpha-2): {who_countries_alpha2}")

who_country_codes = who_countries_alpha2.keys()
print(f"WHO Country Codes: {list(who_country_codes)}")
# Out:
# Skipping CHI - No matching alpha-2 code found.
# Skipping ME1 - No matching alpha-2 code found.
# Skipping SDN736 - No matching alpha-2 code found.
# Skipping XKX - No matching alpha-2 code found.
# WHO Countries (alpha-2): {'AW': 'Aruba', 'AF': 'Afghanistan', 'AO': 'Angola', 'AI': 'Anguilla', 'AL': 'Albania', 'AD': 'Andorra', 'AE': 'United Arab Emirates', 'AR': 'Argentina', 'AM': 'Armenia', 'AS': 'American Samoa', 'AG': 'Antigua and Barbuda', 'AU': 'Australia', 'AT': 'Austria', 'AZ': 'Azerbaijan', 'BI': 'Burundi', 'BE': 'Belgium', 'BJ': 'Benin', 'BQ': 'Bonaire, Saint Eustatius and Saba', 'BF': 'Burkina Faso', 'BD': 'Bangladesh', 'BG': 'Bulgaria', 'BH': 'Bahrain', 'BS': 'Bahamas', 'BA': 'Bosnia and Herzegovina', 'BY': 'Belarus', 'BZ': 'Belize', 'BM': 'Bermuda', 'BO': 'Bolivia (Plurinational State of)', 'BR': 'Brazil', 'BB': 'Barbados', 'BN': 'Brunei Darussalam', 'BT': 'Bhutan', 'BW': 'Botswana', 'CF': 'Central African Republic', 'CA': 'Canada', 'CH': 'Switzerland', 'CL': 'Chile', 'CN': 'China', 'CI': "Cote d'Ivoire", 'CM': 'Cameroon', 'CD': 'Democratic Republic of the Congo', 'CG': 'Congo', 'CK': 'Cook Islands', 'CO': 'Colombia', 'KM': 'Comoros', 'CV': 'Cabo Verde', 'CR': 'Costa Rica', 'CU': 'Cuba', 'CW': 'Curaçao', 'KY': 'Cayman Islands', 'CY': 'Cyprus', 'CZ': 'Czechia', 'DE': 'Germany', 'DJ': 'Djibouti', 'DM': 'Dominica', 'DK': 'Denmark', 'DO': 'Dominican Republic', 'DZ': 'Algeria', 'EC': 'Ecuador', 'EG': 'Egypt', 'ER': 'Eritrea', 'ES': 'Spain', 'EE': 'Estonia', 'ET': 'Ethiopia', 'FI': 'Finland', 'FJ': 'Fiji', 'FK': 'Falkland Islands (Malvinas)', 'FR': 'France', 'FO': 'Faroe Islands', 'FM': 'Micronesia (Federated States of)', 'GA': 'Gabon', 'GB': 'United Kingdom of Great Britain and Northern Ireland', 'GE': 'Georgia', 'GH': 'Ghana', 'GI': 'Gibraltar', 'GN': 'Guinea', 'GP': 'Guadeloupe', 'GM': 'Gambia', 'GW': 'Guinea-Bissau', 'GQ': 'Equatorial Guinea', 'GR': 'Greece', 'GD': 'Grenada', 'GL': 'Greenland', 'GT': 'Guatemala', 'GF': 'French Guiana', 'GU': 'Guam', 'GY': 'Guyana', 'HK': 'China, Hong Kong Special Administrative Region', 'HN': 'Honduras', 'HR': 'Croatia', 'HT': 'Haiti', 'HU': 'Hungary', 'ID': 'Indonesia', 'IM': 'Isle of Man', 'IN': 'India', 'IE': 'Ireland', 'IR': 'Iran (Islamic Republic of)', 'IQ': 'Iraq', 'IS': 'Iceland', 'IL': 'Israel', 'IT': 'Italy', 'JM': 'Jamaica', 'JO': 'Jordan', 'JP': 'Japan', 'KZ': 'Kazakhstan', 'KE': 'Kenya', 'KG': 'Kyrgyzstan', 'KH': 'Cambodia', 'KI': 'Kiribati', 'KN': 'Saint Kitts and Nevis', 'KR': 'Republic of Korea', 'KW': 'Kuwait', 'LA': "Lao People's Democratic Republic", 'LB': 'Lebanon', 'LR': 'Liberia', 'LY': 'Libya', 'LC': 'Saint Lucia', 'LI': 'Liechtenstein', 'LK': 'Sri Lanka', 'LS': 'Lesotho', 'LT': 'Lithuania', 'LU': 'Luxembourg', 'LV': 'Latvia', 'MO': 'China, Macao Special Administrative Region', 'MA': 'Morocco', 'MC': 'Monaco', 'MD': 'Republic of Moldova', 'MG': 'Madagascar', 'MV': 'Maldives', 'MX': 'Mexico', 'MH': 'Marshall Islands', 'MK': 'North Macedonia', 'ML': 'Mali', 'MT': 'Malta', 'MM': 'Myanmar', 'ME': 'Montenegro', 'MN': 'Mongolia', 'MP': 'Northern Mariana Islands', 'MZ': 'Mozambique', 'MR': 'Mauritania', 'MS': 'Montserrat', 'MQ': 'Martinique', 'MU': 'Mauritius', 'MW': 'Malawi', 'MY': 'Malaysia', 'YT': 'Mayotte', 'NA': 'Namibia', 'NC': 'New Caledonia', 'NE': 'Niger', 'NG': 'Nigeria', 'NI': 'Nicaragua', 'NU': 'Niue', 'NL': 'Netherlands (Kingdom of the)', 'NO': 'Norway', 'NP': 'Nepal', 'NR': 'Nauru', 'NZ': 'New Zealand', 'OM': 'Oman', 'PK': 'Pakistan', 'PA': 'Panama', 'PE': 'Peru', 'PH': 'Philippines', 'PW': 'Palau', 'PG': 'Papua New Guinea', 'PL': 'Poland', 'PR': 'Puerto Rico', 'KP': "Democratic People's Republic of Korea", 'PT': 'Portugal', 'PY': 'Paraguay', 'PS': 'occupied Palestinian territory, including east Jerusalem', 'PF': 'French Polynesia', 'QA': 'Qatar', 'RE': 'Reunion', 'RO': 'Romania', 'RU': 'Russian Federation', 'RW': 'Rwanda', 'SA': 'Saudi Arabia', 'SD': 'Sudan', 'SN': 'Senegal', 'SG': 'Singapore', 'SH': 'Saint Helena', 'SB': 'Solomon Islands', 'SL': 'Sierra Leone', 'SV': 'El Salvador', 'SM': 'San Marino', 'SO': 'Somalia', 'PM': 'Saint Pierre and Miquelon', 'RS': 'Serbia', 'SS': 'South Sudan', 'ST': 'Sao Tome and Principe', 'SR': 'Suriname', 'SK': 'Slo ...
# WHO Country Codes: ['AW', 'AF', 'AO', 'AI', 'AL', 'AD', 'AE', 'AR', 'AM', 'AS', 'AG', 'AU', 'AT', 'AZ', 'BI', 'BE', 'BJ', 'BQ', 'BF', 'BD', 'BG', 'BH', 'BS', 'BA', 'BY', 'BZ', 'BM', 'BO', 'BR', 'BB', 'BN', 'BT', 'BW', 'CF', 'CA', 'CH', 'CL', 'CN', 'CI', 'CM', 'CD', 'CG', 'CK', 'CO', 'KM', 'CV', 'CR', 'CU', 'CW', 'KY', 'CY', 'CZ', 'DE', 'DJ', 'DM', 'DK', 'DO', 'DZ', 'EC', 'EG', 'ER', 'ES', 'EE', 'ET', 'FI', 'FJ', 'FK', 'FR', 'FO', 'FM', 'GA', 'GB', 'GE', 'GH', 'GI', 'GN', 'GP', 'GM', 'GW', 'GQ', 'GR', 'GD', 'GL', 'GT', 'GF', 'GU', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IM', 'IN', 'IE', 'IR', 'IQ', 'IS', 'IL', 'IT', 'JM', 'JO', 'JP', 'KZ', 'KE', 'KG', 'KH', 'KI', 'KN', 'KR', 'KW', 'LA', 'LB', 'LR', 'LY', 'LC', 'LI', 'LK', 'LS', 'LT', 'LU', 'LV', 'MO', 'MA', 'MC', 'MD', 'MG', 'MV', 'MX', 'MH', 'MK', 'ML', 'MT', 'MM', 'ME', 'MN', 'MP', 'MZ', 'MR', 'MS', 'MQ', 'MU', 'MW', 'MY', 'YT', 'NA', 'NC', 'NE', 'NG', 'NI', 'NU', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PK', 'PA', 'PE', 'PH', 'PW', 'PG', 'PL', 'PR', 'KP', 'PT', 'PY', 'PS', 'PF', 'QA', 'RE', 'RO', 'RU', 'RW', 'SA', 'SD', 'SN', 'SG', 'SH', 'SB', 'SL', 'SV', 'SM', 'SO', 'PM', 'RS', 'SS', 'ST', 'SR', 'SK', 'SI', 'SE', 'SZ', 'SX', 'SC', 'SY', 'TC', 'TD', 'TG', 'TH', 'TJ', 'TK', 'TM', 'TL', 'TO', 'TT', 'TN', 'TR', 'TV', 'TZ', 'UG', 'UA', 'UY', 'US', 'UZ', 'VC', 'VE', 'VG', 'VI', 'VN', 'VU', 'WF', 'WS', 'YE', 'ZA', 'ZM', 'ZW']

# %%
# Filter cities where the country code exists in the WHO data
filtered_cities = {
    city: code for city, code in city_country_map.items() if code in who_country_codes
}

print(f"Cities with matching WHO data: {len(filtered_cities)}")
print(filtered_cities)
# Out:
# Cities with matching WHO data: 427
# {'huangmei': 'CN', 'sitka': 'US', 'badger': 'US', 'edinburgh of the seven seas': 'SH', 'ballina': 'AU', 'wailua homesteads': 'US', 'tobelo': 'ID', 'puerto ayora': 'EC', 'albany': 'US', 'gizo': 'SB', 'angaur state': 'PW', 'tazacorte': 'ES', 'clanton': 'US', 'silifke': 'TR', 'tura': 'IN', 'solleftea': 'SE', 'stanley': 'GB', 'mongoumba': 'CF', 'bamboo flat': 'IN', 'nemuro': 'JP', 'bethel': 'US', 'taroa': 'MH', 'gopalpur': 'IN', 'invercargill': 'NZ', 'ushuaia': 'AR', 'bilibino': 'RU', 'puerto deseado': 'AR', 'susuman': 'RU', 'isafjordur': 'IS', 'cabugao': 'PH', 'cadale': 'SO', 'whakatane': 'NZ', 'xiongzhou': 'CN', 'childress': 'US', 'vorgashor': 'RU', 'anadyr': 'RU', "kapa'a": 'US', 'mastic beach': 'US', 'bodo': 'NO', 'pacific grove': 'US', 'waitangi': 'NZ', 'mammoth lakes': 'US', 'colonia': 'DE', 'port lincoln': 'AU', 'qaqortoq': 'GL', 'campoverde': 'PE', 'lebu': 'CL', 'udachny': 'RU', 'kodiak': 'US', 'big bend': 'SZ', 'lerwick': 'GB', 'new norfolk': 'AU', 'aliveri': 'GR', 'ilulissat': 'GL', 'fisterra': 'ES', 'mumbwa': 'ZM', 'berriozabal': 'MX', 'utrik': 'MH', 'port augusta': 'AU', 'blackmans bay': 'AU', 'correntina': 'BR', 'bredasdorp': 'ZA', 'avarua': 'CK', 'kirakira': 'SB', 'amahai': 'ID', 'weno': 'FM', 'cheria': 'DZ', 'enewetak': 'MH', 'tamandare': 'BR', 'sao joao da barra': 'BR', 'aykhal': 'RU', 'magadan': 'RU', 'umm kaddadah': 'SD', 'sidney': 'AU', 'thompson': 'CA', 'sisimiut': 'GL', 'ponta delgada': 'PT', 'jamestown': 'US', 'east london': 'ZA', 'grand forks': 'US', 'la passe': 'FR', 'coquimbo': 'CL', 'bayt al faqih': 'YE', 'santa sylvina': 'AR', 'papatowai': 'NZ', 'hawaiian paradise park': 'US', 'holualoa': 'US', 'fale old settlement': 'TK', 'north platte': 'US', 'edd': 'ER', 'carnarvon': 'AU', 'tarija': 'BO', 'banjarmasin': 'ID', 'karratha': 'AU', 'hobyo': 'SO', 'nuuk': 'GL', 'soe': 'ID', 'porto san giorgio': 'IT', 'lapy': 'PL', 'pyhajarvi': 'FI', 'kibre mengist': 'ET', 'hermanus': 'ZA', 'puerto natales': 'CL', 'bam': 'IR', 'port mathurin': 'MU', 'saint-philippe': 'RE', 'remire-montjoly': 'GF', 'ambikapur': 'IN', 'alice springs': 'AU', 'kujang-up': 'KP', 'tonj': 'SS', 'smithers': 'CA', 'northam': 'GB', 'novi di modena': 'IT', 'kokhma': 'RU', 'mahibadhoo': 'MV', 'florida': 'US', 'ca mau': 'VN', 'tralee': 'IE', 'fuling': 'CN', 'samamiya': 'NG', 'hamilton': 'US', 'belmonte': 'BR', 'kharabali': 'RU', 'iskateley': 'RU', 'caister-on-sea': 'GB', 'agbor': 'NG', 'cestos city': 'LR', 'tiksi': 'RU', 'kemijarvi': 'FI', 'vila franca do campo': 'PT', 'iqaluit': 'CA', 'talnakh': 'RU', 'puerto carreno': 'CO', 'garoua boulai': 'CM', 'ribeira grande': 'PT', 'alotau': 'PG', 'yellowknife': 'CA', 'acarau': 'BR', 'luderitz': 'NA', 'ancud': 'CL', 'hadibu': 'YE', 'guigang': 'CN', 'yuzhno-kurilsk': 'RU', 'nabire': 'ID', 'tazovsky': 'RU', 'saint john': 'CA', 'angra do heroismo': 'PT', 'alaghsas': 'NE', 'margaret river': 'AU', 'mount isa': 'AU', 'cannonvale': 'AU', 'vilyuchinsk': 'RU', 'vadso': 'NO', 'punta arenas': 'CL', 'ust-nera': 'RU', 'lihue': 'US', 'zaragoza': 'ES', 'guerrero negro': 'MX', 'usinsk': 'RU', 'nova vicosa': 'BR', 'al jawf': 'SA', 'taoudenni': 'ML', 'san luis de la loma': 'MX', 'bondoukou': 'CI', 'corund': 'RO', 'el tocuyo': 'VE', 'okhotsk': 'RU', 'kisarawe': 'TZ', 'praia da vitoria': 'PT', 'masaya sur': 'PH', 'berdigestyakh': 'RU', 'uturoa': 'PF', 'lagos': 'NG', 'doka': 'SD', 'hastings': 'GB', 'isola di capo rizzuto': 'IT', 'zvishavane': 'ZW', 'palu': 'ID', 'georgetown': 'MY', 'phalaborwa': 'ZA', "sol'-iletsk": 'RU', 'la ronge': 'CA', 'aasiaat': 'GL', 'abbeville': 'FR', 'alta': 'NO', 'hithadhoo': 'MV', 'chonchi': 'CL', 'thinadhoo': 'MV', 'minas de marcona': 'PE', 'happy valley-goose bay': 'CA', 'ta`u': 'AS', 'jimenez': 'MX', 'biloela': 'AU', 'tolanaro': 'MG', 'amos': 'CA', 'xining': 'CN', 'copiapo': 'CL', 'casper': 'US', 'miyaly': 'KZ', 'ciudad lazaro cardenas': 'MX', 'gamba': 'GA', 'santyoku': 'KR', 'keflavik': 'IS', 'mossel bay': 'ZA', 'college': 'US', 'pimentel': 'PE', 'cole harbour': 'CA', 'dadhar': 'PK', 'mega': 'ET', 'peman ...

# %%
# WHO API: Air pollution attributable DALYs
who_url = "https://ghoapi.azureedge.net/api/AIR_42"
response = requests.get(who_url)

# Check for valid response
if response.status_code == 200:
    data = response.json()['value']
    # Parse the data into a DataFrame
    who_data = [
        {
            'Country': entry['SpatialDim'],
            'Year': entry['TimeDim'],
            'MortalityRate_per_100k': entry['NumericValue']
        }
        for entry in data
    ]
    
    df_who = pd.DataFrame(who_data)
    print(df_who.head())
    
    df_who.to_csv('Resources/who_air_pollution_dalys.csv', index=False)
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
#   Country  Year  MortalityRate_per_100k
# 0     CIV  2015                  40.103
# 1     SOM  2011                  53.318
# 2     GRD  2012                   0.567
# 3     BRN  2015                   1.440
# 4     HND  2016                  32.081

# %%
# Function to convert ISO-3 to ISO-2
def iso3_to_iso2(iso3_code):
    try:
        return pycountry.countries.get(alpha_3=iso3_code).alpha_2
    except AttributeError:
        return None  

df_who = pd.read_csv('Resources/who_air_pollution_dalys.csv')

# Convert WHO's ISO-3 codes to ISO-2
df_who['Country_ISO2'] = df_who['Country'].apply(iso3_to_iso2)

df_who_clean = df_who.dropna(subset=['Country_ISO2'])

df_weather = pd.read_csv('Resources/city_country_map.csv')

merged_df = pd.merge(air_quality_df, df_who_clean, left_on='Country', right_on='Country_ISO2', how='inner')

print(merged_df.head())

merged_df.to_csv('Resources/merged_air_quality_health.csv', index=False)
# Out:
#        City Country_x  PM2.5   PM10    NO2     O3    SO2       CO  NH3  \
# 0  huangmei        CN  49.51  54.46  48.67  22.17  12.99  1161.58  0.0
# 1  huangmei        CN  49.51  54.46  48.67  22.17  12.99  1161.58  0.0
# 2  huangmei        CN  49.51  54.46  48.67  22.17  12.99  1161.58  0.0
# 3  huangmei        CN  49.51  54.46  48.67  22.17  12.99  1161.58  0.0
# 4  huangmei        CN  49.51  54.46  48.67  22.17  12.99  1161.58  0.0
#
#   Country_y  Year  MortalityRate_per_100k Country_ISO2
# 0       CHN  2017                  53.760           CN
# 1       CHN  2018                  50.178           CN
# 2       CHN  2014                   4.470           CN
# 3       CHN  2010                  18.528           CN
# 4       CHN  2014                  25.500           CN

# %%
count = len(merged_df)
count
# Out:
# 72000

# %%
# Drop redundant columns (dropping 'Country_ISO2' and 'Country_y')
merged_df = merged_df.drop(['Country_ISO2', 'Country_y'], axis=1)

# Rename columns for clarity
merged_df = merged_df.rename(columns={'Country_x': 'Country'})

# %%
merged_df.to_csv('Resources/merged_air_quality_health.csv', index=False)

# %%
# Load the merged dataset
df = pd.read_csv('Resources/merged_air_quality_health.csv')

# Group by City and Country to calculate average values across all years
grouped_df = df.groupby(['City', 'Country'], as_index=False).agg({
    'PM2.5': 'mean',
    'PM10': 'mean',
    'NO2': 'mean',
    'O3': 'mean',
    'SO2': 'mean',
    'CO': 'mean',
    'NH3': 'mean',
    'MortalityRate_per_100k': 'mean'
})

grouped_df = grouped_df.round(1)

grouped_df.to_csv('Resources/average_air_quality_health.csv', index=False)

print(grouped_df.head(10))
# Out:
#             City Country  PM2.5   PM10   NO2     O3  SO2     CO  NH3  \
# 0      abbeville      FR    4.7    8.8   4.7   36.8  0.8  210.3  1.3
# 1         acarau      BR    2.1    9.6   0.2   52.2  0.1  353.8  0.1
# 2          agbor      NG   29.9   39.2   5.7    2.5  0.4  894.6  0.6
# 3        al jawf      SA   11.1   39.2   1.0  101.6  1.7  193.6  0.5
# 4      al qusayr      SY    7.9   10.0   4.7   40.8  2.5  210.3  2.7
# 5       alaghsas      NE   63.9  271.8   0.0   53.6  0.0  196.9  0.0
# 6         albany      US    2.1    2.6  12.8   24.7  0.1  253.7  0.1
# 7  alice springs      AU   14.5   61.3   0.1   50.1  0.0  283.7  0.2
# 8        aliveri      GR    1.1    4.3   0.4   78.0  0.2  200.3  0.2
# 9       alliance      US   13.4   16.2  21.9   24.3  0.5  367.2  0.6
#
#    MortalityRate_per_100k
# 0                     4.1
# 1                     9.6
# 2                    29.6
# 3                    33.5
# 4                    26.6
# 5                    34.1
# 6                     5.7
# 7                     3.2
# 8                     9.8
# 9                     5.7
